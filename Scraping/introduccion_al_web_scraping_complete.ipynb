# %% [markdown]
# # Introducción al webscraping

# %% [markdown]
# ## Introducción
#
# ### ¿De qué se compone una web?
#
# [HTML](https://developer.mozilla.org/es/docs/Web/HTML), [CSS](https://developer.mozilla.org/es/docs/Web/CSS) y [Javascript](https://developer.mozilla.org/es/docs/Web/JavaScript)
#
# ### [PETICIONES HTTP](https://developer.mozilla.org/es/docs/Web/HTTP/Methods)
#
# GET, POST, PUT, DELETE, PATCH, ...
#
#
# ### [HTML](https://developer.mozilla.org/es/docs/Web/HTML)
#
# ETIQUETAS, ATRIBUTOS, ...
#
# ### [SELECTORES CSS](https://www.w3schools.com/cssref/css_selectors.php)
#
# . # > +

# %%
import bs4
bs4.__version__
# Out:
# '4.12.2'

# %% [markdown]
# ## Importamos librerías
#
# En primer lugar importamos las librerías sys, csv y statistics, que vienen por defecto en Python.

# %%
import sys 
import csv
import statistics

# %% [markdown]
# Comprobamos ahora si tenemos instaladas las librerías Beautiful Soup, Request y Pandas. Si no es así las instalamos

# %%
# %%capture
if 'BeautifulSoup' not in sys.modules:
    # !{sys.executable} -m pip install beautifulsoup4
    
if 'requests' not in sys.modules:
    # !{sys.executable} -m pip install requests
    
if 'requests' not in sys.modules:
    # !{sys.executable} -m pip install pandas

# %% [markdown]
# Importamos ahora Beautiful Soup, Requests y Pandas

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ## Funciones auxiliares
#
# Ponemos un par de funciones auxiliares que usaremos un poco más adelante

# %%
# Para exportar listas a archivos csv
def export_list_to_csv(rows, columns=None, filename="output", delimiter=";"):

    if type(rows[0]) == str:
        rows = [[row] for row in rows]

    if columns:
        assert len(columns) == len(rows[0]), "There should be the same number of columns and rows elements"
 
    with open(f"{filename}.csv", 'w') as f:
        write = csv.writer(f, delimiter=delimiter)

        if columns:
            write.writerow(columns)

        write.writerows(rows)

# %%
# Para dividir una lista en trozos más pequeños
def chunks(lst, n):
    return [lst[i:i + n] for i in range(0, len(lst), n)]

# %% [markdown]
# ## Bloque 1 - Extrayendo los titulares de un periódico

# %%
WEB_BLOQUE1 = 'https://www.elconfidencial.com'

# %% [markdown]
# En primer lugar usamos la librería requests para bajarnos el HTML de la web que queremos descargar

# %%
x = requests.get(WEB_BLOQUE1)

# %% [markdown]
# Podemos ver el [status code de nuestra petición web](https://developer.mozilla.org/es/docs/Web/HTTP/Status). Si el status code es 200, es que todo ha ido bien

# %%
x.status_code
# Out:
# 200

# %% [markdown]
# Para consultar el código HTML descargado usamos la propiedad text

# %%
x.text
# Out:
# '<!DOCTYPE html><html lang="es"><head><script type="application/json" id="EC_hosts">{"name": "El Confidencial","id": "1","enviroment": "production","host": "www.elconfidencial.com","api": "api.elconfidencial.com","secure": "secure.elconfidencial.com","image": "","useridentity": "useridentity.elconfidencial.com"}</script><meta http-equiv="Content-Type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><!--[if IE 8]><script src="/javascript/v2/plugins/html5-shim/html5shiv-printshiv.js"></script><![endif]--><title>El Confidencial - El diario de los lectores influyentes</title><meta name="msapplication-config" content="none"/><meta name="verify-v1" content="zaF1JNxc7UQaY6aOtg5/g3MYrxKOipO3XWaUNnhtBgQ=" /><meta name="google-site-verification" content="e4XcvLCkuMSwwudpCP7hG5oi7Odb9VJ4U9207IpyvBk" /><link rel="canonical" href="https://www.elconfidencial.com/" /><meta name="twitter:dnt" content="on" /><meta name="lang" content="es"  /><meta name="title" content="El confidencial: Toda la actualidad e información de España y del mundo"  /><meta name="description" content="El confidencial - El diario de los lectores influyentes. Encuentra todas las noticias al minuto: España, Europa, Mundo, Economía, Cultura, Ecología y la mejor opinión"  /><meta name="keywords" content="Todas las noticias y columnas de Opinión sobre España, Mundo, Deportes, Bienestar, Tecnología, Cultura y Famosos"  /><meta name="robots" content="all"  /><meta name="locality" content="Madrid, Spain"  /><meta name="verify-v1" content="zaF1JNxc7UQaY6aOtg5/g3MYrxKOipO3XWaUNnhtBgQ="  /><meta name="author" content="Titania Cía. Editorial, S.L."  /><meta name="distribution" content="global"  /><meta name="resource-type" content="document"  /><meta name="organization" content="Titania Cía. Editorial, S.L"  /><meta name="viewport" content="user-scalable=yes, maximum-scale=2.5,width=996"  /><meta name="twitter:card" content=""  /><meta name="twitter:title" content="El Confidencial - El diario de los lectores influyentes"  /><meta name="twitter:description" content="El Confidencial - El diaro referente en economía, información nacional, internacional, opinión...; el diario para los lectores influyentes"  /><meta name="twitter:image:width" content="640"  /><meta name="twitter:image:height" content="360"  /><meta name="twitter:player:width" content=""  /><meta name="twitter:player:height" content=""  /><meta name="twitter:player:stream:content_type" content=""  /><meta name="referrer" content="no-referrer-when-downgrade"  /><meta name="og:site_name" content="El Confidencial"  /><meta name="twitter:site" content="@elconfidencial"  /><meta name="twitter:url" content="https://www.elconfidencial.com"  /><meta name="twitter:creator" content="@elconfidencial"  /><meta name="twitter:image" content="https://www.ecestaticos.com/file/112f2e89248dc42a8b8a772deca96eee/1629790198-el-confidencial.jpg"  /><meta name="twitter:domain" content="https://www.elconfidencial.com"  /><meta name="fb:page_id" content="63830851925"  /><meta name="fb:app_id" content="1482570825397489"  /><meta name="fb:pages" content="63830851925"  /><meta http-equiv="refresh" content="500"  /><meta http-equiv="expires" content="Tue, 16 Jan 2024 15:50:25 GMT"  /><meta http-equiv="cache-control" content="public, s-maxage=60, max-age=59, stale-while-revalidate=60, stale-if-error=259200"  /><meta property="og:title" content="El Confidencial - El diario de los lectores influyentes"  /><meta property="og:type" content="website"  /><meta property="og:description" content="El Confidencial - El diaro referente en economía, información nacional, internacional, opinión...; el diario para los lectores influyentes"  /><meta property="og:url" content="https://www.elconfidencial.com/"  /><meta property="og:image" content="https://www.ecestaticos.com/file/112f2e89248dc42a8b8a772deca96eee/1629790198-el-confidencial.jpg"  /><meta property="og:site_name" content="elconfidencial.com"  /><meta property="f ...

# %% [markdown]
# El siguiente paso es parsear el documento. El parseo es el proceso de analizar un texto para identificar su estructura y poder extraer información de ella. Existen diferentes parseadores que pueden usarse. En nuestro caso usaremos html.parser

# %%
parsed_document = BeautifulSoup(x.text, "html.parser")

# %% [markdown]
# Tras revisar la web, vemos que los artículos del periódico comparten la clase titleArticleEditable. Utilizamos el selector CSS de clases (el .) para seleccionarlos.

# %%
all_titles_nodes = parsed_document.css.select(".titleArticleEditable")

# %% [markdown]
# Comprobamos que estamos extrayendo el titular

# %%
all_titles_nodes[0].text
# Out:
# '        El Gobierno se abre a que Rajoy y otros dirigentes del PP vayan al Congreso por espiar a Cataluña    '

# %% [markdown]
# Extraemos ahora todos los artículos, reemplazamos los saltos de línea por espacios en blanco y quitamos los espacios en blanco al principio y al final

# %%
all_titles = [article.text.replace("\n", " ").lstrip().rstrip() for article in all_titles_nodes]

# %% [markdown]
# Veamos ahora todos los titulares

# %%
all_titles
# Out:
# ['El Gobierno se abre a que Rajoy y otros dirigentes del PP vayan al Congreso por espiar a Cataluña',
#  'Moncloa desclasifica los autos que avalaron el pinchazo a Aragonès',
#  'Generación porno: el sexo extremo, nuevo tutor de niños y jóvenes',
#  'Sumar y Podemos piden al Ejecutivo que vete a BlackRock la entrada en Naturgy',
#  'Cuerpo analiza si la gestora debe pedir el plácet para tomar el 20% de la gasista',
#  'Santander pide precio a las Big Four para el mayor contrato de la historia',
#  'Moncloa iguala el tabaco calentado al tradicional y prohíbe aromatizantes',
#  'Sánchez da galones a Puente, Saiz, Redondo y Hereu en la ejecutiva',
#  "Feijóo impone tres plenos al mes en el Senado y lo convierte en su 'fortín'",
#  'Ayuso alerta de que "ETA está ganando el relato" y pide llevar a Bildu al TS',
#  'El PNV pide a Junts "rebajar los decibelios" del debate migratorio',
#  "Mazón pone el ventilador al Botànic: denuncia 713 M en pagos a dedo y anuncia una auditoría 'forensic'",
#  'Cataluña prohíbe llenar piscinas y usar duchas deportivas por la sequía',
#  'El PSOE desmonta la locomotora económica de Moreno y atribuye el empuje a Sánchez',
#  'El TC da la razón a Alberto Rodríguez más de dos años después de perder su escaño',
#  'Grifols estudia avanzar los resultados de 2023 para recuperar el terreno perdido tras el ataque de los bajistas',
#  "El 'holding' ligado a\xa0los Grifols negocia con Botín la refinanciación de 400 millones",
#  'El Corte Inglés cierra el centro comercial Méndez Álvaro tras la sentencia judicial',
#  "El otro 'genocidio' de Alemania: ¿qué pinta Namibia en la demanda a Israel en la CIJ?",
#  'Trump gana en Iowa y confirma su dominio del campo republicano',
#  '"La pregunta no es si habrá violencia en EEUU, sino cuánta sangre habrá"',
#  'Irán bombardea "centros de espionaje antiiraní" en Irak con misiles balísticos',
#  'Roures propone sacar a bolsa el Barça como solución a sus males financieros y deportivos',
#  'Apple, que ya era la que más ganaba con móviles, logra lo que se le resistía',
#  '¿Por qué Europa es un 27% más pobre que EEUU? Esto es lo que piensa McKinsey',
#  'Los yihadistas de Cataluña y Mérida están liderados por un checheno preso que traficaba con armas',
#  'La generación Z (y no los amigos de Sánchez) es el problema del feminismo',
#  'Expertos en guerra asimétrica: por qué los misiles no frenarán a los hutíes en mar Rojo',
#  'Atacan a un carguero griego frente a Yemen y EEUU incauta armas iraníes',
#  "Elecciones gallegas: los 'pellets', el pronóstico y lo posterior",
#  "La estrategia 'black' de Junts: el discurso antimigración",
#  'Estreno del ministro del buen rollo económico',
#  'Un nuevo acuerdo industrial para garantizar la disponibilidad de medicamentos esenciales',
#  'El enfado encapsulado de Coalición Canaria',
#  'Tiene 103 años, grabó el entierro de Durruti y este 2024 recibe el Goya de Honor',
#  '¿Qué socios cotizan al alza en fichajes? Energía y M&A, los deseados',
#  'Martín (GA_P) se jubila: "Es difícil pasar de socio director a socio raso"',
#  'Políticas DEIB y LGTBI en bufetes: nuevas formas de retener talento',
#  'Cambios en Clyde & Co: Relaño y Navarro relevan a Figuerol y Garrido',
#  'Así será el Chinatown de Madrid: una reforma de Usera, turismo y dragones',
#  'Estas son las multas si te caza el nuevo radar de tramo de Sinesio Delgado',
#  'Vuelven los tambores de guerra por el trasvase del Ebro, pero Azcón dice no',
#  'Collboni anuncia un "alcalde de noche" para la actividad nocturna en Barcelona',
#  'Dos detenidos en la operación contrael yihadismo en Cataluña y Mérida',
#  'Vuelven los fantasmas de Díaz: Beiras y Pablo Iglesias ponen en jaque a Sumar',
#  'JP Morgan oscurece el camino de la banca: "El crecimiento de las ganancias se acaba"',
#  'Grifols relanza su cotización en medio de las caídas en el Ibex',
#  'Telefónica aprueba una subida salarial del 3,1% y un plus de 150 euros',
#  'El Gobierno nombra a Paula Conthe secretaria general del Tesoro',
#  'Los minoritarios complican a Ferrovial la venta de Heathrow por 2.748 millones',
#  'Crescenta, con Albella y Arrola, lanza dos fondos para levantar 45 M',
#  'La banca ya recorta la rentabilidad de fondos superventas de renta fija',
#  "Sharing Co prevé invertir 300 M para 'coliving' en Madrid y Málaga",
#  'Momento clave para Teleperformance (Carlos Doblado)',
#  'Los \'crossfiteros\' se rebelan contra CrossFit: "La marca nos lleva al límite"',
#  "'The Succession' y 'The Bear' se consagran en los premios Emmy con un empate a seis galardones",
#  'Alcaraz revienta a Gasquet y da el primer paso hacia el sueño de ganar el Open de Australia',
#  'Esta científica española se va a aislar en el desierto de Utah para simular un viaje a Marte',
#  "La alfombra roja de la 75 edición\xa0de los galardones a la industria de la televisión: los mejores 'looks'",
#  'La familia del soldado muerto en Cerro Muriano denuncia a Defensa',
#  'Premios a la Abogacía de los Negocios: arranca el plazo para presentarse',
#  'A merced de la borrasca Irene: dejará tormentas con granizo en España',
#  'Con 71 años, ¿si compro un garaje, debo ponerlo a nombre de mis hijos?',
#  'EC Jurídico | ¿Qué socios serán los más deseados en el baile de sillas?',
#  'Cotizalia AM | Grifols y el efecto quién se ha llevado mi OPV',
#  'El Confidencial lanza su canal en WhatsApp: ¡únete ya gratis!',
#  'La fortuna del olvido selectivo, que las autoridades sanitarias no deben permitir',
#  'Esto es lo que dice la ciencia sobre tomar aguacate en el desayuno',
#  'Los riesgos para la salud\xa0 (que no conocías) de las dietas hiperproteicas',
#  'Ucrania ordena la evacuación de más de 3.000 personas de localidades cercanas al frente',
#  'Irán y el Eje de la Resistencia: los riesgos para Israel, de Líbano a Yemen',
#  'Arévalo es investido presidente de Guatemala pese a los intentos de evitarlo',
#  'Una victoria amarga en Taiwán: relato en primera persona de una observadora electoral',
#  'Un muerto y 17 heridos en un ataque múltiple por atropello en Ranana, centro de Israel',
#  'El negocio millonario de construir tiendas de campaña de lujo',
#  'Por qué esta famosa presentadora acabó vendiendo pasteles en BCN',
#  'Las ideas más innovadoras de los emprendedores españoles',
#  'Hallan en Egipto una tumba de hace 4.500 años con enterramientos de distintas épocas',
#  'Unamuno se hace detective andante (y resuelve un crimen en la España vaciada de 1905)',
#  'Mala Fama | El fantasma de las novedades pasadas',
#  'Las dos arquitecturas enfrentadas en Berlín por la Guerra Fría',
#  '¿Dónde están los balcones? La conquista de las casas cerradas',
#  'Descubre las últimas novedades del mundo del arte en El Grito',
#  'Hallan un extraordinario anillo estelar que rompe nuestra teoría de formación del cosmos',
#  'Lo que el éxito de La Casa de las Carcasas revela sobre el negocio fallido de la tecnología',
#  'TheGrefg, sobre el desahucio de una mujer de 80 años: "Es una ocupación abusiva"',
#  'Revelan el gran plan de Arabia Saudí para su utopía futurista en el desierto',
#  'Una nueva tecnología de aleación con láser rompe los límites conocidos de los metales',
#  'La posibilidad real de que una civilización alienígena detecte vida en la Tierra',
#  'El despido fulminante de Mourinho de la Roma por no ser competitivo y atacar a los jugadores',
#  '"Como me diga algo, le meto una h.....": la fea reacción de un jugador del Barcelona en la Supercopa',
#  'El \'zasca\' a Iker Casillas por las críticas al The Best que ha ganado Messi: "Lo que hiciste en el 2012..."',
#  'Carlos Sainz aguanta el ritmo de Loeb, que sigue a 20 minutos a pesar de volver a ganar la etapa',
#  'Por qué Carles Falcón siguió el camino del corazón y encarna el verdadero "espíritu del Dakar"',
#  'Del espectacular punto de Alcaraz provocando la risa en el palco al "cállate la boca" de John McEnroe',
#  'Rafael Nadal se vende a Arabia Saudí y se convierte en el nuevo embajador de la federación saudí',
#  "El 'modelo Roig' para su Villarreal: Europa y cantera como 'must' tras usar el flotador de Mercadona",
#  'Toyota evoluciona el GR Yaris: más potencia, mejoras mecánicas y cambios en el interior',
#  'Estos son los cascos que la DGT no permitirá utilizar en 2024: fíchalos para evitar multas',
#  'Hyundai y Nissan presentan en Tokio opciones más deportivas de sus familiares eléctricos',
#  '¿Se te da bien perdonar, aunque nunca olvides la afrenta? Hacia una teoría de las disculpas',
#  '¿Tu pareja es infiel por naturaleza? Descubre las señales más claras que delatan el posible engaño',
#  'Un profesor español que trabaja en Irlanda cuenta cómo reaccionaron sus alumnos al saber su nombre',
#  'Descubre estos 10 alimentos que son geniales para adelgazar y los puedes comer hasta hartarte',
#  'La respuesta de un bar a un cliente que se queja porque el café para llevar es mucho más caro',
#  'Una española que vive en Australia enseña lo diferentes que son la escoba y la fregona en este país',
#  '¿Qué ocurre en nuestro cerebro cuando nos ponemos a hablar con nosotros mismos?',
#  '"Ese yogur no es un yogur": el terror de los supermercados son los lectores de etiquetas',
#  'Así metí un virus soviético ilegalmente en España para salvar la vida de mi padre',
#  "Santa Teresa, la 'rockstar' del siglo XVI reivindicada por el catolicismo y (ahora) el feminismo",
#  "En 2024 aumentarán todos los salarios (y más en el  sector 'retail')",
#  'Enfermedad de Alzheimer: factores de riesgo y diagnóstico precoz',
#  'Así es el plan del Gobierno vasco para impulsar el comercio local',
#  "Anne Igartiburu dice adiós a 'Corazón', tras 27 años, con una emotiva despedida",
#  '"Lo sabemos todos": Gonzalo Miró, rotundo en \'EP\' ante la polémica de Itziar Ituño',
#  "Polémica en 'OT 2023': señalan el injusto trato a Cris, nominado esta semana",
#  "10 grandes titulares de Jenni Hermoso en 'Planeta Calleja': del caso Rubiales al ictus",
#  "Destapado el caché de Carmen Borrego, último escollo para fichar por 'SV'",
#  'Audiencias TV: Franganillo no inquieta a Vicente Vallés en su estreno en Telecinco',
#  '"Me da un miedo atroz": Mariló Montero, atónita ante una escena machista',
#  "Terelu Campos, sorprendida por los jueces saltándose las normas de 'Bake Off' (TVE)",
#  'El segundo vestido de novia de Tamara Falcó, parejas conjuntadas y otros detalles de moda en los Emmy',
#  "El nuevo 'look' de Letizia: guiño a Dinamarca con sus pendientes y una original chaqueta austriaca",
#  'Nuevo divorcio en la realeza: la poca amistosa separación de Leka y Elia de Albania',
#  '¿Hubo cobra? El beso de Federico y Mary de Dinamarca, según un experto en lenguaje corporal',
#  'Karina desvela este duro momento de su vida personal sobre el escenario del teatro',
#  'Sergio Rico y Alba Silva vuelven a la alfombra roja en Sevilla por un buen motivo familiar',
#  "De Guardiola con su mujer e hija a los 'looks' de Bonmatí o Hermoso: la gala FIFA The Best 2024",
#  'Los 10 mejores estuches de Lékué que debes conocer para cocinar sano, pero con todo el sabor',
#  'Esta es la lista de los productos más recomendados del mes y los enlaces para comprarlos baratos',
#  'Los complejos vitamínicos que necesitan estudiantes y deportistas para enfrentarse al invierno',
#  'Las chimeneas eléctricas con las que podrás calentar tu hogar en invierno con todo el estilo',
#  "'Gadgets' de belleza: estas son las máscaras de luz led más recomendadas por los expertos",
#  'Con este armario portátil podrás llevar todo lo que necesitas en tu maleta de mano y sobrará espacio',
#  'Rusia prepara una nueva ofensiva contra Ucrania con más tanques, aviones y soldados',
#  'La jugada inesperada de los piratas de Yemen en el mar Rojo',
#  'El meteorito no es lo peor: modos de destruirel planeta Tierra',
#  'Jerusalén: la clave de la paz imposible entre Israel y Palestina']

# %% [markdown]
# ## Bloque 2 - Descargar los datos diarios de la bolsa

# %%
WEB_BLOQUE2 = "https://www.expansion.com/mercados/cotizaciones/indices/igbolsamadrid_I.MA.html"

# %% [markdown]
# Nos bajamos el HTML de la web donde tenemos los datos de la bolsa

# %%
x = requests.get(WEB_BLOQUE2)

# %% [markdown]
# Parseamos el documento

# %%
parsed_cotiz = BeautifulSoup(x.text, "html.parser")

# %% [markdown]
# Extraemos los nombres de las columnas

# %%
all_header_nodes = parsed_cotiz.css.select("#listado_valores th")
all_header = [article.text.replace("\n", " ").lstrip().rstrip() for article in all_header_nodes if article.text]

# %%
all_header
# Out:
# ['Valor',
#  'Último',
#  'Var. %',
#  'Var.',
#  'Ac. % año',
#  'Máx.',
#  'Mín.',
#  'Vol.',
#  'Capit.',
#  'Hora',
#  '']

# %% [markdown]
# Extraemos los datos

# %%
all_values_nodes = parsed_cotiz.css.select("#listado_valores td")
all_values = [article.text for article in all_values_nodes]

# %%
all_values
# Out:
# ['ACCIONA',
#  '122,350',
#  '-4,23',
#  '-5,40',
#  '-8,21',
#  '126,650',
#  '122,100',
#  '71.279',
#  '6.712',
#  '16:32',
#  '',
#  'ACCIONA ENER',
#  '23,980',
#  '-3,46',
#  '-0,86',
#  '-14,60',
#  '24,620',
#  '23,920',
#  '231.352',
#  '7.895',
#  '16:32',
#  '',
#  'ACERINOX',
#  '10,135',
#  '-2,55',
#  '-0,26',
#  '-4,88',
#  '10,400',
#  '10,125',
#  '544.593',
#  '2.742',
#  '16:29',
#  '',
#  'ACS',
#  '39,620',
#  '-1,59',
#  '-0,64',
#  '-1,34',
#  '40,080',
#  '39,500',
#  '172.874',
#  '11.021',
#  '16:31',
#  '',
#  'ADOLFO DOMÍNGUEZ',
#  '4,840',
#  '-1,63',
#  '-0,08',
#  '-3,20',
#  '4,900',
#  '4,840',
#  '133',
#  '45',
#  '12:42',
#  '',
#  'AEDAS HOMES',
#  '18,260',
#  '-1,51',
#  '-0,28',
#  '0,22',
#  '18,640',
#  '18,260',
#  '4.511',
#  '855',
#  '16:00',
#  '',
#  'AENA',
#  '166,300',
#  '-1,48',
#  '-2,50',
#  '1,34',
#  '167,550',
#  '164,100',
#  '42.131',
#  '24.945',
#  '16:31',
#  '',
#  'AIRBUS',
#  '147,940',
#  '-0,14',
#  '-0,20',
#  '5,40',
#  '148,400',
#  '146,920',
#  '798',
#  '116.293',
#  '16:03',
#  '',
#  'AIRTIFICIAL',
#  '0,145',
#  '-2,03',
#  '-0,00',
#  '12,02',
#  '0,149',
#  '0,142',
#  '3.446.195',
#  '193',
#  '16:29',
#  '',
#  'ALANTRA',
#  '9,220',
#  '-0,22',
#  '-0,02',
#  '9,24',
#  '9,500',
#  '9,180',
#  '1.524',
#  '356',
#  '16:15',
#  '',
#  'ALBA',
#  '50,200',
#  '1,41',
#  '0,70',
#  '4,58',
#  '50,200',
#  '49,050',
#  '5.701',
#  '3.027',
#  '16:11',
#  '',
#  'ALMIRALL',
#  '8,590',
#  '-0,23',
#  '-0,02',
#  '1,96',
#  '8,615',
#  '8,525',
#  '67.900',
#  '1.799',
#  '16:31',
#  '',
#  'AMADEUS IT GROUP',
#  '63,700',
#  '0,35',
#  '0,22',
#  '-1,82',
#  '63,740',
#  '62,960',
#  '139.470',
#  '28.697',
#  '16:31',
#  '',
#  'AMPER',
#  '0,091',
#  '2,83',
#  '0,00',
#  '8,73',
#  '0,091',
#  '0,087',
#  '3.746.110',
#  '136',
#  '16:26',
#  '',
#  'AMREST HOLDINGS',
#  '5,840',
#  '-1,85',
#  '-0,11',
#  '-5,35',
#  '5,850',
#  '5,840',
#  '3.104',
#  '1.282',
#  '14:48',
#  '',
#  'APERAM',
#  '28,930',
#  '2,33',
#  '0,66',
#  '-12,28',
#  '29,100',
#  '28,760',
#  '85',
#  '2.314',
#  '13:07',
#  '',
#  'APPLUS',
#  '10,170',
#  '-0,78',
#  '-0,08',
#  '1,70',
#  '10,340',
#  '10,150',
#  '50.864',
#  '1.454',
#  '16:17',
#  '',
#  'ARCELORMITTAL',
#  '24,230',
#  '-0,82',
#  '-0,20',
#  '-5,59',
#  '24,405',
#  '24,050',
#  '134.467',
#  '21.269',
#  '16:31',
#  '',
#  'ARIMA',
#  '6,450',
#  '2,38',
#  '0,15',
#  '1,57',
#  '6,450',
#  '6,200',
#  '730',
#  '183',
#  '14:39',
#  '',
#  'ATRESMEDIA',
#  '3,650',
#  '-0,60',
#  '-0,02',
#  '1,56',
#  '3,680',
#  '3,638',
#  '105.518',
#  '824',
#  '16:18',
#  '',
#  'ATRYS HEALTH',
#  '3,700',
#  '-0,27',
#  '-0,01',
#  '0,82',
#  '3,750',
#  '3,630',
#  '3.160',
#  '281',
#  '14:18',
#  '',
#  'AUDAX RENOVABLES',
#  '1,280',
#  '-2,29',
#  '-0,03',
#  '-1,54',
#  '1,316',
#  '1,272',
#  '130.201',
#  '564',
#  '16:05',
#  '',
#  'AZKOYEN',
#  '6,240',
#  '0,00',
#  '0,00',
#  '-1,89',
#  '6,360',
#  '6,240',
#  '11.349',
#  '153',
#  '11:55',
#  '',
#  'BANCO SABADELL',
#  '1,121',
#  '-2,73',
#  '-0,03',
#  '0,72',
#  '1,140',
#  '1,112',
#  '23.808.426',
#  '6.098',
#  '16:32',
#  '',
#  'BANKINTER',
#  '5,986',
#  '-2,19',
#  '-0,13',
#  '3,28',
#  '6,120',
#  '5,962',
#  '1.102.221',
#  '5.381',
#  '16:32',
#  '',
#  'BAVIERA',
#  '24,800',
#  '2,90',
#  '0,70',
#  '7,83',
#  '25,000',
#  '23,800',
#  '9.028',
#  '404',
#  '16:24',
#  '',
#  'BBVA',
#  '8,126',
#  '-1,53',
#  '-0,13',
#  '-1,22',
#  '8,202',
#  '8,086',
#  '3.579.395',
#  '47.439',
#  '16:32',
#  '',
#  'BERKELEY ENERGIA LTD',
#  '0,182',
#  '1,45',
#  '0,00',
#  '4,35',
#  '0,187',
#  '0,180',
#  '2.849.546',
#  '81',
#  '16:31',
#  '',
#  'BODEGAS RIOJANAS',
#  '4,580',
#  '-2,55',
#  '-0,12',
#  '-0,87',
#  '4,780',
#  '4,580',
#  '5.100',
#  '23',
#  '11:00',
#  '',
#  'BORGES AGRI BR',
#  '2,540',
#  '0,00',
#  '0,00',
#  '-1,55',
#  '2,540',
#  '2,540',
#  '209',
#  '59',
#  '16:00',
#  '',
#  'C.A.F.',
#  '32,400',
#  '-1,67',
#  '-0,55',
#  '-0,61',
#  '32,800',
#  '32,300',
#  '20.212',
#  '1.111',
#  '16:23',
#  '',
#  'CAIXABANK',
#  '3,890',
#  '-0,94',
#  '-0,04',
#  '4,40',
#  '3,922',
#  '3,863',
#  '3.551.231',
#  '31.356',
#  '16:31',
#  '',
#  'CAM',
#  '1,340',
#  '0,00',
#  '0,00',
#  '0,00',
#  '1,340',
#  '1,340',
#  '',
#  '67',
#  '15/01',
#  '',
#  'CATALANA OCCIDENTE',
#  '32,000',
#  '-1,84',
#  '-0,60',
#  '3,56',
#  '32,450',
#  '31,950',
#  '15.662',
#  '3.840',
#  '16:31',
#  '',
#  'CELLNEX TELECOM',
#  '35,210',
#  '-1,01',
#  '-0,36',
#  '-1,26',
#  '35,500',
#  '35,120',
#  '291.491',
#  '23.919',
#  '16:32',
#  '',
#  'CEVASA',
#  '6,000',
#  '0,00',
#  '0,00',
#  '0,00',
#  '6,000',
#  '6,000',
#  '361',
#  '140',
#  '16:00',
#  '',
#  'CIE. AUTOMOTIVE',
#  '24,180',
#  '-0,58',
#  '-0,14',
#  '-4,38',
#  '24,400',
#  '24,120',
#  '28.945',
#  '2.963',
#  '16:22',
#  '',
#  'CLEOP',
#  '1,150',
#  '0,00',
#  '0,00',
#  '0,00',
#  '1,150',
#  '1,100',
#  '6.500',
#  '11',
#  '15/01',
#  '',
#  'COCA-COLA EUROP',
#  '61,100',
#  '-0,16',
#  '-0,10',
#  '1,16',
#  '61,400',
#  '60,900',
#  '115',
#  '28.044',
#  '14:59',
#  '',
#  'COLONIAL',
#  '5,895',
#  '-1,09',
#  '-0,07',
#  '-10,00',
#  '5,945',
#  '5,860',
#  '539.296',
#  '3.181',
#  '16:28',
#  '',
#  'DEOLEO',
#  '0,221',
#  '0,68',
#  '0,00',
#  '-3,29',
#  '0,222',
#  '0,219',
#  '360.433',
#  '110',
#  '16:23',
#  '',
#  'DESA',
#  '12,000',
#  '0,00',
#  '0,00',
#  '0,00',
#  '12,400',
#  '12,400',
#  '7',
#  '21',
#  '16:00',
#  '',
#  'DIA',
#  '0,013',
#  '0,00',
#  '0,00',
#  '10,17',
#  '0,013',
#  '0,013',
#  '10.354.146',
#  '755',
#  '16:22',
#  '',
#  'DURO FELGUERA',
#  '0,654',
#  '0,46',
#  '0,00',
#  '0,31',
#  '0,655',
#  '0,645',
#  '15.132',
#  '63',
#  '16:19',
#  '',
#  'EBRO FOODS',
#  '15,360',
#  '-0,26',
#  '-0,04',
#  '-1,03',
#  '15,440',
#  '15,320',
#  '23.847',
#  '2.363',
#  '16:30',
#  '',
#  'ECOENER',
#  '4,120',
#  '-3,96',
#  '-0,17',
#  '-2,83',
#  '4,290',
#  '4,060',
#  '4.546',
#  '235',
#  '15:17',
#  '',
#  'EDREAMS ODIGEO',
#  '7,170',
#  '3,17',
#  '0,22',
#  '-6,52',
#  '7,170',
#  '6,950',
#  '34.878',
#  '915',
#  '16:29',
#  '',
#  'ELECNOR',
#  '18,900',
#  '-0,79',
#  '-0,15',
#  '-3,32',
#  '19,100',
#  '18,400',
#  '34.460',
#  '1.644',
#  '16:31',
#  '',
#  'ENAGAS',
#  '15,800',
#  '-0,35',
#  '-0,05',
#  '3,50',
#  '15,940',
#  '15,735',
#  '302.644',
#  '4.139',
#  '16:32',
#  '',
#  'ENCE',
#  '2,734',
#  '-1,37',
#  '-0,04',
#  '-3,46',
#  '2,774',
#  '2,728',
#  '275.652',
#  '673',
#  '16:31',
#  '',
#  'ENDESA',
#  '19,570',
#  '-1,01',
#  '-0,20',
#  '6,01',
#  '19,780',
#  '19,565',
#  '329.266',
#  '20.720',
#  '16:31',
#  '',
#  'ERCROS',
#  '2,505',
#  '-2,34',
#  '-0,06',
#  '-5,11',
#  '2,565',
#  '2,495',
#  '125.158',
#  '229',
#  '16:31',
#  '',
#  'EZENTIS',
#  '0,089',
#  '0,00',
#  '0,00',
#  '0,00',
#  '0,102',
#  '0,088',
#  '9.821.974',
#  '41',
#  '15/01',
#  '',
#  'FAES',
#  '3,145',
#  '-0,16',
#  '-0,01',
#  '0,63',
#  '3,155',
#  '3,115',
#  '59.039',
#  '995',
#  '15:36',
#  '',
#  'FCC',
#  '14,100',
#  '0,00',
#  '0,00',
#  '-3,16',
#  '14,240',
#  '13,680',
#  '15.889',
#  '6.149',
#  '16:21',
#  '',
#  'FERROVIAL',
#  '34,960',
#  '0,14',
#  '0,05',
#  '5,88',
#  '34,980',
#  '34,470',
#  '474.175',
#  '25.894',
#  '16:32',
#  '',
#  'FLUIDRA',
#  '18,840',
#  '-0,63',
#  '-0,12',
#  '-0,05',
#  '18,910',
#  '18,580',
#  '148.826',
#  '3.620',
#  '16:31',
#  '',
#  'GAM',
#  '1,230',
#  '-0,81',
#  '-0,01',
#  '4,24',
#  '1,230',
#  '1,210',
#  '19.629',
#  '116',
#  '16:01',
#  '',
#  'GESTAMP',
#  '3,184',
#  '-0,93',
#  '-0,03',
#  '-7,34',
#  '3,240',
#  '3,174',
#  '498.751',
#  '1.832',
#  '16:32',
#  '',
#  'GLOBAL DOMINION ACCESS',
#  '3,380',
#  '0,45',
#  '0,02',
#  '0,60',
#  '3,395',
#  '3,350',
#  '43.618',
#  '543',
#  '16:31',
#  '',
#  'GRENERGY RENOVABLES',
#  '31,960',
#  '-1,60',
#  '-0,52',
#  '-6,66',
#  '32,840',
#  '31,580',
#  '16.131',
#  '978',
#  '16:25',
#  '',
#  'GRIFOLS',
#  '9,068',
#  '1,93',
#  '0,17',
#  '-41,33',
#  '9,280',
#  '8,830',
#  '4.084.692',
#  '3.864',
#  '16:32',
#  '',
#  'GRIFOLS CL.B',
#  '6,650',
#  '2,07',
#  '0,14',
#  '-36,97',
#  '6,770',
#  '6,395',
#  '388.330',
#  '1.738',
#  '16:32',
#  '',
#  'GRUPO EMP. SAN JOSE',
#  '3,960',
#  '0,00',
#  '0,00',
#  '14,45',
#  '4,030',
#  '3,960',
#  '130.897',
#  '258',
#  '16:28',
#  '',
#  'IAG',
#  '1,663',
#  '-1,77',
#  '-0,03',
#  '-6,63',
#  '1,681',
#  '1,657',
#  '7.295.239',
#  '8.268',
#  '16:31',
#  '',
#  'IBERDROLA',
#  '11,560',
#  '-0,90',
#  '-0,10',
#  '-0,96',
#  '11,640',
#  '11,555',
#  '3.642.349',
#  '73.409',
#  '16:32',
#  '',
#  'IBERPAPEL',
#  '18,200',
#  '0,28',
#  '0,05',
#  '1,11',
#  '18,200',
#  '18,150',
#  '651',
#  '196',
#  '16:12',
#  '',
#  'INDITEX',
#  '38,760',
#  '-0,33',
#  '-0,13',
#  '-1,70',
#  '38,810',
#  '38,100',
#  '478.543',
#  '120.801',
#  '16:31',
#  '',
#  'INDRA',
#  '15,230',
#  '-0,52',
#  '-0,08',
#  '8,79',
#  '15,370',
#  '15,080',
#  '230.773',
#  '2.690',
#  '16:29',
#  '',
#  'INMOBILIARIA DEL SUR',
#  '7,000',
#  '0,00',
#  '0,00',
#  '1,42',
#  '7,000',
#  '7,000',
#  '1.000',
#  '131',
#  '12:00',
#  '',
#  'INNOVATIVE SOLUTIONS ECOSYSTEM',
#  '0,564',
#  '0,00',
#  '0,00',
#  '0,00',
#  '0,576',
#  '0,564',
#  '301',
#  '33',
#  '15/01',
#  '',
#  'LABORATORIO REIG JOFRE',
#  '2,360',
#  '0,85',
#  '0,02',
#  '4,89',
#  '2,380',
#  '2,330',
#  '5.362',
#  '188',
#  '16:17',
#  '',
#  'LAR ESPAÑA',
#  '6,380',
#  '-0,31',
#  '-0,02',
#  '3,74',
#  '6,400',
#  '6,330',
#  '10.225',
#  '534',
#  '16:12',
#  '',
#  'LIBERTAS 7',
#  '1,040',
#  '1,96',
#  '0,02',
#  '1,96',
#  '1,040',
#  '1,040',
#  '2.000',
#  '23',
#  '16:00',
#  '',
#  'LINEA DIRECTA BR',
#  '0,919',
#  '0,11',
#  '0,00',
#  '7,99',
#  '0,922',
#  '0,909',
#  '76.986',
#  '1.000',
#  '16:25',
#  '',
#  'LINGOTES',
#  '6,840',
#  '-2,84',
#  '-0,20',
#  '11,76',
#  '7,200',
#  '6,800',
#  '1.618',
#  '68',
#  '13:43',
#  '',
#  'LOGISTA',
#  '25,760',
#  '-0,16',
#  '-0,04',
#  '5,23',
#  '25,860',
#  '25,660',
#  '91.355',
#  '3.420',
#  '16:32',
#  '',
#  'MAPFRE',
#  '2,010',
#  '-0,50',
#  '-0,01',
#  '3,45',
#  '2,014',
#  '2,000',
#  '975.047',
#  '6.190',
#  '16:30',
#  '',
#  'MEDIAFOREUROPE',
#  '2,385',
#  '0,00',
#  '0,00',
#  '2,23',
#  '2,385',
#  '2,385',
#  '19',
#  '791',
#  '15/01',
#  '',
#  'MELIÁ HOTELS',
#  '5,795',
#  '-1,02',
#  '-0,06',
#  '-2,77',
#  '5,835',
#  '5,770',
#  '341.539',
#  '1.277',
#  '16:32',
#  '',
#  'MERLIN PROP.',
#  '9,520',
#  '-0,05',
#  '-0,00',
#  '-5,37',
#  '9,530',
#  '9,440',
#  '221.187',
#  '4.472',
#  '16:32',
#  '',
#  'METROVACESA',
#  '8,070',
#  '-0,49',
#  '-0,04',
#  '-0,12',
#  '8,140',
#  '8,050',
#  '4.534',
#  '1.224',
#  '16:27',
#  '',
#  'MIQUEL COSTAS',
#  '11,440',
#  '0,00',
#  '0,00',
#  '-2,89',
#  '11,740',
#  '11,400',
#  '1.644',
#  '458',
#  '16:17',
#  '',
#  'MONTEBALITO',
#  '1,420',
#  '0,71',
#  '0,01',
#  '-2,74',
#  '1,430',
#  '1,420',
#  '3.500',
#  '45',
#  '14:20',
#  '',
#  'NATURGY',
#  '26,720',
#  '-1,47',
#  '-0,40',
#  '-1,04',
#  '27,040',
#  '26,720',
#  '79.886',
#  '25.908',
#  '16:28',
#  '',
#  'NATURHOUSE HEALTH',
#  '1,610',
#  '-1,83',
#  '-0,03',
#  '2,25',
#  '1,620',
#  '1,600',
#  '13.381',
#  '97',
#  '16:27',
#  '',
#  'NEINOR HOMES',
#  '10,420',
#  '-1,51',
#  '-0,16',
#  '-1,33',
#  '10,600',
#  '10,340',
#  '13.450',
#  '781',
#  '16:23',
#  '',
#  'NEXTIL',
#  '0,375',
#  '1,63',
#  '0,01',
#  '-1,32',
#  '0,375',
#  '0,370',
#  '11.500',
#  '123',
#  '09:40',
#  '',
#  'NH HOTEL GROUP',
#  '4,100',
#  '-0,24',
#  '-0,01',
#  '-2,15',
#  '4,155',
#  '4,075',
#  '8.385',
#  '1.787',
#  '15:15',
#  '',
#  'NICOLÁS CORREA',
#  '6,350',
#  '0,00',
#  '0,00',
#  '-2,31',
#  '6,600',
#  '6,350',
#  '2.482',
#  '78',
#  '16:25',
#  '',
#  'NYESA',
#  '0,005',
#  '-3,57',
#  '-0,00',
#  '12,50',
#  '0,006',
#  '0,005',
#  '9.471.430',
#  '5',
#  '14:07',
#  ...]

# %% [markdown]
# Dividimos los datos por filas

# %%
all_values = chunks(all_values, 11)

# %%
all_values
# Out:
# [['ACCIONA',
#   '122,350',
#   '-4,23',
#   '-5,40',
#   '-8,21',
#   '126,650',
#   '122,100',
#   '71.279',
#   '6.712',
#   '16:32',
#   ''],
#  ['ACCIONA ENER',
#   '23,980',
#   '-3,46',
#   '-0,86',
#   '-14,60',
#   '24,620',
#   '23,920',
#   '231.352',
#   '7.895',
#   '16:32',
#   ''],
#  ['ACERINOX',
#   '10,135',
#   '-2,55',
#   '-0,26',
#   '-4,88',
#   '10,400',
#   '10,125',
#   '544.593',
#   '2.742',
#   '16:29',
#   ''],
#  ['ACS',
#   '39,620',
#   '-1,59',
#   '-0,64',
#   '-1,34',
#   '40,080',
#   '39,500',
#   '172.874',
#   '11.021',
#   '16:31',
#   ''],
#  ['ADOLFO DOMÍNGUEZ',
#   '4,840',
#   '-1,63',
#   '-0,08',
#   '-3,20',
#   '4,900',
#   '4,840',
#   '133',
#   '45',
#   '12:42',
#   ''],
#  ['AEDAS HOMES',
#   '18,260',
#   '-1,51',
#   '-0,28',
#   '0,22',
#   '18,640',
#   '18,260',
#   '4.511',
#   '855',
#   '16:00',
#   ''],
#  ['AENA',
#   '166,300',
#   '-1,48',
#   '-2,50',
#   '1,34',
#   '167,550',
#   '164,100',
#   '42.131',
#   '24.945',
#   '16:31',
#   ''],
#  ['AIRBUS',
#   '147,940',
#   '-0,14',
#   '-0,20',
#   '5,40',
#   '148,400',
#   '146,920',
#   '798',
#   '116.293',
#   '16:03',
#   ''],
#  ['AIRTIFICIAL',
#   '0,145',
#   '-2,03',
#   '-0,00',
#   '12,02',
#   '0,149',
#   '0,142',
#   '3.446.195',
#   '193',
#   '16:29',
#   ''],
#  ['ALANTRA',
#   '9,220',
#   '-0,22',
#   '-0,02',
#   '9,24',
#   '9,500',
#   '9,180',
#   '1.524',
#   '356',
#   '16:15',
#   ''],
#  ['ALBA',
#   '50,200',
#   '1,41',
#   '0,70',
#   '4,58',
#   '50,200',
#   '49,050',
#   '5.701',
#   '3.027',
#   '16:11',
#   ''],
#  ['ALMIRALL',
#   '8,590',
#   '-0,23',
#   '-0,02',
#   '1,96',
#   '8,615',
#   '8,525',
#   '67.900',
#   '1.799',
#   '16:31',
#   ''],
#  ['AMADEUS IT GROUP',
#   '63,700',
#   '0,35',
#   '0,22',
#   '-1,82',
#   '63,740',
#   '62,960',
#   '139.470',
#   '28.697',
#   '16:31',
#   ''],
#  ['AMPER',
#   '0,091',
#   '2,83',
#   '0,00',
#   '8,73',
#   '0,091',
#   '0,087',
#   '3.746.110',
#   '136',
#   '16:26',
#   ''],
#  ['AMREST HOLDINGS',
#   '5,840',
#   '-1,85',
#   '-0,11',
#   '-5,35',
#   '5,850',
#   '5,840',
#   '3.104',
#   '1.282',
#   '14:48',
#   ''],
#  ['APERAM',
#   '28,930',
#   '2,33',
#   '0,66',
#   '-12,28',
#   '29,100',
#   '28,760',
#   '85',
#   '2.314',
#   '13:07',
#   ''],
#  ['APPLUS',
#   '10,170',
#   '-0,78',
#   '-0,08',
#   '1,70',
#   '10,340',
#   '10,150',
#   '50.864',
#   '1.454',
#   '16:17',
#   ''],
#  ['ARCELORMITTAL',
#   '24,230',
#   '-0,82',
#   '-0,20',
#   '-5,59',
#   '24,405',
#   '24,050',
#   '134.467',
#   '21.269',
#   '16:31',
#   ''],
#  ['ARIMA',
#   '6,450',
#   '2,38',
#   '0,15',
#   '1,57',
#   '6,450',
#   '6,200',
#   '730',
#   '183',
#   '14:39',
#   ''],
#  ['ATRESMEDIA',
#   '3,650',
#   '-0,60',
#   '-0,02',
#   '1,56',
#   '3,680',
#   '3,638',
#   '105.518',
#   '824',
#   '16:18',
#   ''],
#  ['ATRYS HEALTH',
#   '3,700',
#   '-0,27',
#   '-0,01',
#   '0,82',
#   '3,750',
#   '3,630',
#   '3.160',
#   '281',
#   '14:18',
#   ''],
#  ['AUDAX RENOVABLES',
#   '1,280',
#   '-2,29',
#   '-0,03',
#   '-1,54',
#   '1,316',
#   '1,272',
#   '130.201',
#   '564',
#   '16:05',
#   ''],
#  ['AZKOYEN',
#   '6,240',
#   '0,00',
#   '0,00',
#   '-1,89',
#   '6,360',
#   '6,240',
#   '11.349',
#   '153',
#   '11:55',
#   ''],
#  ['BANCO SABADELL',
#   '1,121',
#   '-2,73',
#   '-0,03',
#   '0,72',
#   '1,140',
#   '1,112',
#   '23.808.426',
#   '6.098',
#   '16:32',
#   ''],
#  ['BANKINTER',
#   '5,986',
#   '-2,19',
#   '-0,13',
#   '3,28',
#   '6,120',
#   '5,962',
#   '1.102.221',
#   '5.381',
#   '16:32',
#   ''],
#  ['BAVIERA',
#   '24,800',
#   '2,90',
#   '0,70',
#   '7,83',
#   '25,000',
#   '23,800',
#   '9.028',
#   '404',
#   '16:24',
#   ''],
#  ['BBVA',
#   '8,126',
#   '-1,53',
#   '-0,13',
#   '-1,22',
#   '8,202',
#   '8,086',
#   '3.579.395',
#   '47.439',
#   '16:32',
#   ''],
#  ['BERKELEY ENERGIA LTD',
#   '0,182',
#   '1,45',
#   '0,00',
#   '4,35',
#   '0,187',
#   '0,180',
#   '2.849.546',
#   '81',
#   '16:31',
#   ''],
#  ['BODEGAS RIOJANAS',
#   '4,580',
#   '-2,55',
#   '-0,12',
#   '-0,87',
#   '4,780',
#   '4,580',
#   '5.100',
#   '23',
#   '11:00',
#   ''],
#  ['BORGES AGRI BR',
#   '2,540',
#   '0,00',
#   '0,00',
#   '-1,55',
#   '2,540',
#   '2,540',
#   '209',
#   '59',
#   '16:00',
#   ''],
#  ['C.A.F.',
#   '32,400',
#   '-1,67',
#   '-0,55',
#   '-0,61',
#   '32,800',
#   '32,300',
#   '20.212',
#   '1.111',
#   '16:23',
#   ''],
#  ['CAIXABANK',
#   '3,890',
#   '-0,94',
#   '-0,04',
#   '4,40',
#   '3,922',
#   '3,863',
#   '3.551.231',
#   '31.356',
#   '16:31',
#   ''],
#  ['CAM',
#   '1,340',
#   '0,00',
#   '0,00',
#   '0,00',
#   '1,340',
#   '1,340',
#   '',
#   '67',
#   '15/01',
#   ''],
#  ['CATALANA OCCIDENTE',
#   '32,000',
#   '-1,84',
#   '-0,60',
#   '3,56',
#   '32,450',
#   '31,950',
#   '15.662',
#   '3.840',
#   '16:31',
#   ''],
#  ['CELLNEX TELECOM',
#   '35,210',
#   '-1,01',
#   '-0,36',
#   '-1,26',
#   '35,500',
#   '35,120',
#   '291.491',
#   '23.919',
#   '16:32',
#   ''],
#  ['CEVASA',
#   '6,000',
#   '0,00',
#   '0,00',
#   '0,00',
#   '6,000',
#   '6,000',
#   '361',
#   '140',
#   '16:00',
#   ''],
#  ['CIE. AUTOMOTIVE',
#   '24,180',
#   '-0,58',
#   '-0,14',
#   '-4,38',
#   '24,400',
#   '24,120',
#   '28.945',
#   '2.963',
#   '16:22',
#   ''],
#  ['CLEOP',
#   '1,150',
#   '0,00',
#   '0,00',
#   '0,00',
#   '1,150',
#   '1,100',
#   '6.500',
#   '11',
#   '15/01',
#   ''],
#  ['COCA-COLA EUROP',
#   '61,100',
#   '-0,16',
#   '-0,10',
#   '1,16',
#   '61,400',
#   '60,900',
#   '115',
#   '28.044',
#   '14:59',
#   ''],
#  ['COLONIAL',
#   '5,895',
#   '-1,09',
#   '-0,07',
#   '-10,00',
#   '5,945',
#   '5,860',
#   '539.296',
#   '3.181',
#   '16:28',
#   ''],
#  ['DEOLEO',
#   '0,221',
#   '0,68',
#   '0,00',
#   '-3,29',
#   '0,222',
#   '0,219',
#   '360.433',
#   '110',
#   '16:23',
#   ''],
#  ['DESA',
#   '12,000',
#   '0,00',
#   '0,00',
#   '0,00',
#   '12,400',
#   '12,400',
#   '7',
#   '21',
#   '16:00',
#   ''],
#  ['DIA',
#   '0,013',
#   '0,00',
#   '0,00',
#   '10,17',
#   '0,013',
#   '0,013',
#   '10.354.146',
#   '755',
#   '16:22',
#   ''],
#  ['DURO FELGUERA',
#   '0,654',
#   '0,46',
#   '0,00',
#   '0,31',
#   '0,655',
#   '0,645',
#   '15.132',
#   '63',
#   '16:19',
#   ''],
#  ['EBRO FOODS',
#   '15,360',
#   '-0,26',
#   '-0,04',
#   '-1,03',
#   '15,440',
#   '15,320',
#   '23.847',
#   '2.363',
#   '16:30',
#   ''],
#  ['ECOENER',
#   '4,120',
#   '-3,96',
#   '-0,17',
#   '-2,83',
#   '4,290',
#   '4,060',
#   '4.546',
#   '235',
#   '15:17',
#   ''],
#  ['EDREAMS ODIGEO',
#   '7,170',
#   '3,17',
#   '0,22',
#   '-6,52',
#   '7,170',
#   '6,950',
#   '34.878',
#   '915',
#   '16:29',
#   ''],
#  ['ELECNOR',
#   '18,900',
#   '-0,79',
#   '-0,15',
#   '-3,32',
#   '19,100',
#   '18,400',
#   '34.460',
#   '1.644',
#   '16:31',
#   ''],
#  ['ENAGAS',
#   '15,800',
#   '-0,35',
#   '-0,05',
#   '3,50',
#   '15,940',
#   '15,735',
#   '302.644',
#   '4.139',
#   '16:32',
#   ''],
#  ['ENCE',
#   '2,734',
#   '-1,37',
#   '-0,04',
#   '-3,46',
#   '2,774',
#   '2,728',
#   '275.652',
#   '673',
#   '16:31',
#   ''],
#  ['ENDESA',
#   '19,570',
#   '-1,01',
#   '-0,20',
#   '6,01',
#   '19,780',
#   '19,565',
#   '329.266',
#   '20.720',
#   '16:31',
#   ''],
#  ['ERCROS',
#   '2,505',
#   '-2,34',
#   '-0,06',
#   '-5,11',
#   '2,565',
#   '2,495',
#   '125.158',
#   '229',
#   '16:31',
#   ''],
#  ['EZENTIS',
#   '0,089',
#   '0,00',
#   '0,00',
#   '0,00',
#   '0,102',
#   '0,088',
#   '9.821.974',
#   '41',
#   '15/01',
#   ''],
#  ['FAES',
#   '3,145',
#   '-0,16',
#   '-0,01',
#   '0,63',
#   '3,155',
#   '3,115',
#   '59.039',
#   '995',
#   '15:36',
#   ''],
#  ['FCC',
#   '14,100',
#   '0,00',
#   '0,00',
#   '-3,16',
#   '14,240',
#   '13,680',
#   '15.889',
#   '6.149',
#   '16:21',
#   ''],
#  ['FERROVIAL',
#   '34,960',
#   '0,14',
#   '0,05',
#   '5,88',
#   '34,980',
#   '34,470',
#   '474.175',
#   '25.894',
#   '16:32',
#   ''],
#  ['FLUIDRA',
#   '18,840',
#   '-0,63',
#   '-0,12',
#   '-0,05',
#   '18,910',
#   '18,580',
#   '148.826',
#   '3.620',
#   '16:31',
#   ''],
#  ['GAM',
#   '1,230',
#   '-0,81',
#   '-0,01',
#   '4,24',
#   '1,230',
#   '1,210',
#   '19.629',
#   '116',
#   '16:01',
#   ''],
#  ['GESTAMP',
#   '3,184',
#   '-0,93',
#   '-0,03',
#   '-7,34',
#   '3,240',
#   '3,174',
#   '498.751',
#   '1.832',
#   '16:32',
#   ''],
#  ['GLOBAL DOMINION ACCESS',
#   '3,380',
#   '0,45',
#   '0,02',
#   '0,60',
#   '3,395',
#   '3,350',
#   '43.618',
#   '543',
#   '16:31',
#   ''],
#  ['GRENERGY RENOVABLES',
#   '31,960',
#   '-1,60',
#   '-0,52',
#   '-6,66',
#   '32,840',
#   '31,580',
#   '16.131',
#   '978',
#   '16:25',
#   ''],
#  ['GRIFOLS',
#   '9,068',
#   '1,93',
#   '0,17',
#   '-41,33',
#   '9,280',
#   '8,830',
#   '4.084.692',
#   '3.864',
#   '16:32',
#   ''],
#  ['GRIFOLS CL.B',
#   '6,650',
#   '2,07',
#   '0,14',
#   '-36,97',
#   '6,770',
#   '6,395',
#   '388.330',
#   '1.738',
#   '16:32',
#   ''],
#  ['GRUPO EMP. SAN JOSE',
#   '3,960',
#   '0,00',
#   '0,00',
#   '14,45',
#   '4,030',
#   '3,960',
#   '130.897',
#   '258',
#   '16:28',
#   ''],
#  ['IAG',
#   '1,663',
#   '-1,77',
#   '-0,03',
#   '-6,63',
#   '1,681',
#   '1,657',
#   '7.295.239',
#   '8.268',
#   '16:31',
#   ''],
#  ['IBERDROLA',
#   '11,560',
#   '-0,90',
#   '-0,10',
#   '-0,96',
#   '11,640',
#   '11,555',
#   '3.642.349',
#   '73.409',
#   '16:32',
#   ''],
#  ['IBERPAPEL',
#   '18,200',
#   '0,28',
#   '0,05',
#   '1,11',
#   '18,200',
#   '18,150',
#   '651',
#   '196',
#   '16:12',
#   ''],
#  ['INDITEX',
#   '38,760',
#   '-0,33',
#   '-0,13',
#   '-1,70',
#   '38,810',
#   '38,100',
#   '478.543',
#   '120.801',
#   '16:31',
#   ''],
#  ['INDRA',
#   '15,230',
#   '-0,52',
#   '-0,08',
#   '8,79',
#   '15,370',
#   '15,080',
#   '230.773',
#   '2.690',
#   '16:29',
#   ''],
#  ['INMOBILIARIA DEL SUR',
#   '7,000',
#   '0,00',
#   '0,00',
#   '1,42',
#   '7,000',
#   '7,000',
#   '1.000',
#   '131',
#   '12:00',
#   ''],
#  ['INNOVATIVE SOLUTIONS ECOSYSTEM',
#   '0,564',
#   '0,00',
#   '0,00',
#   '0,00',
#   '0,576',
#   '0,564',
#   '301',
#   '33',
#   '15/01',
#   ''],
#  ['LABORATORIO REIG JOFRE',
#   '2,360',
#   '0,85',
#   '0,02',
#   '4,89',
#   '2,380',
#   '2,330',
#   '5.362',
#   '188',
#   '16:17',
#   ''],
#  ['LAR ESPAÑA',
#   '6,380',
#   '-0,31',
#   '-0,02',
#   '3,74',
#   '6,400',
#   '6,330',
#   '10.225',
#   '534',
#   '16:12',
#   ''],
#  ['LIBERTAS 7',
#   '1,040',
#   '1,96',
#   '0,02',
#   '1,96',
#   '1,040',
#   '1,040',
#   '2.000',
#   '23',
#   '16:00',
#   ''],
#  ['LINEA DIRECTA BR',
#   '0,919',
#   '0,11',
#   '0,00',
#   '7,99',
#   '0,922',
#   '0,909',
#   '76.986',
#   '1.000',
#   '16:25',
#   ''],
#  ['LINGOTES',
#   '6,840',
#   '-2,84',
#   '-0,20',
#   '11,76',
#   '7,200',
#   '6,800',
#   '1.618',
#   '68',
#   '13:43',
#   ''],
#  ['LOGISTA',
#   '25,760',
#   '-0,16',
#   '-0,04',
#   '5,23',
#   '25,860',
#   '25,660',
#   '91.355',
#   '3.420',
#   '16:32',
#   ''],
#  ['MAPFRE',
#   '2,010',
#   '-0,50',
#   '-0,01',
#   '3,45',
#   '2,014',
#   '2,000',
#   '975.047',
#   '6.190',
#   '16:30',
#   ''],
#  ['MEDIAFOREUROPE',
#   '2,385',
#   '0,00',
#   '0,00',
#   '2,23',
#   '2,385',
#   '2,385',
#   '19',
#   '791',
#   '15/01',
#   ''],
#  ['MELIÁ HOTELS',
#   '5,795',
#   '-1,02',
#   '-0,06',
#   '-2,77',
#   '5,835',
#   '5,770',
#   '341.539',
#   '1.277',
#   '16:32',
#   ''],
#  ['MERLIN PROP.',
#   '9,520',
#   '-0,05',
#   '-0,00',
#   '-5,37',
#   '9,530',
#   '9,440',
#   '221.187',
#   '4.472',
#   '16:32',
#   ''],
#  ['METROVACESA',
#   '8,070',
#   '-0,49',
#   '-0,04',
#   '-0,12',
#   '8,140',
#   '8,050',
#   '4.534',
#   '1.224',
#   '16:27',
#   ''],
#  ['MIQUEL COSTAS',
#   '11,440',
#   '0,00',
#   '0,00',
#   '-2,89',
#   '11,740',
#   '11,400',
#   '1.644',
#   '458',
#   '16:17',
#   ''],
#  ['MONTEBALITO',
#   '1,420',
#   '0,71',
#   '0,01',
#   '-2,74',
#   '1,430',
#   '1,420',
#   '3.500',
#   '45',
#   '14:20',
#   ''],
#  ['NATURGY',
#   '26,720',
#   '-1,47',
#   '-0,40',
#   '-1,04',
#   '27,040',
#   '26,720',
#   '79.886',
#   '25.908',
#   '16:28',
#   ''],
#  ['NATURHOUSE HEALTH',
#   '1,610',
#   '-1,83',
#   '-0,03',
#   '2,25',
#   '1,620',
#   '1,600',
#   '13.381',
#   '97',
#   '16:27',
#   ''],
#  ['NEINOR HOMES',
#   '10,420',
#   '-1,51',
#   '-0,16',
#   '-1,33',
#   '10,600',
#   '10,340',
#   '13.450',
#   '781',
#   '16:23',
#   ''],
#  ['NEXTIL',
#   '0,375',
#   '1,63',
#   '0,01',
#   '-1,32',
#   '0,375',
#   '0,370',
#   '11.500',
#   '123',
#   '09:40',
#   ''],
#  ['NH HOTEL GROUP',
#   '4,100',
#   '-0,24',
#   '-0,01',
#   '-2,15',
#   '4,155',
#   '4,075',
#   '8.385',
#   '1.787',
#   '15:15',
#   ''],
#  ['NICOLÁS CORREA',
#   '6,350',
#   '0,00',
#   '0,00',
#   '-2,31',
#   '6,600',
#   '6,350',
#   '2.482',
#   '78',
#   '16:25',
#   ''],
#  ['NYESA',
#   '0,005',
#   '-3,57',
#   '-0,00',
#   '12,50',
#   '0,006',
#   '0,005',
#   '9.471.430',
#   '5',
#   '14:07',
#   ''],
#  ['OHLA',
#   '0,419',
#   '1,80',
#   '0,01',
#   '-6,81',
#   '0,428',
#   '0,409',
#   '3.029.782',
#   '248',
#   '16:31',
#   ''],
#  ['OPDEnergy',
#   '5,780',
#   '-0,17',
#   '-0,01',
#   '-0,17',
#   '5,780',
#   '5,770',
#   '45.077',
#   '856',
#   '16:27',
#   ''],
#  ['ORYZON GENOMICS',
#   '1,904',
#   '-1,04',
#   '-0,02',
#   '0,85',
#   '1,956',
#   '1,900',
#   '146.205',
#   '114',
#   '16:32',
#   ''],
#  ['PESCANOVA',
#   '0,215',
#   '0,47',
#   '0,00',
#   '4,88',
#   '0,215',
#   '0,214',
#   '4.559',
#   '6',
#   '14:55',
#   ''],
#  ['PHARMAMAR',
#   '39,580',
#   '-0,60',
#   '-0,24',
#   '-3,65',
#   '40,000',
#   '39,140',
#   '20.993',
#   '726',
#   '16:24',
#   ''],
#  ['PRIM',
#   '10,250',
#   '0,00',
#   '0,00',
#   '-1,91',
#   '10,250',
#   '10,050',
#   '2.596',
#   '175',
#   '14:25',
#   ''],
#  ['PRISA',
#   '0,281',
#   '0,00',
#   '0,00',
#   '-3,10',
#   '0,290',
#   '0,281',
#   '4.812',
#   '283',
#   '14:07',
#   ''],
#  ['PROSEGUR',
#   '1,746',
#   '0,34',
#   '0,01',
#   '-0,80',
#   '1,746',
#   '1,734',
#   '313.602',
#   '958',
#   '16:21',
#   ''],
#  ['PROSEGUR CASH',
#   '0,502',
#   '-1,57',
#   '-0,01',
#   '-6,52',
#   '0,507',
#   '0,501',
#   '305.170',
#   '765',
#   '15:45',
#   ''],
#  ['REALIA',
#   '1,060',
#   '-0,93',
#   '-0,01',
#   '0,00',
#   '1,060',
#   '1,060',
#   '25.121',
#   '869',
#   '14:54',
#   ''],
#  ['REDEIA',
#   '15,110',
#   '-0,72',
#   '-0,11',
#   '3,21',
#   '15,260',
#   '15,100',
#   '193.653',
#   '8.176',
#   '16:31',
#   ''],
#  ['RENTA CORPORACION',
#   '0,792',
#   '0,25',
#   '0,00',
#   '-1,00',
#   '0,792',
#   '0,790',
#   '10.055',
#   '26',
#   '15:18',
#   ''],
#  ['RENTA 4',
#   '10,100',
#   '0,00',
#   '0,00',
#   '-0,98',
#   '10,200',
#   '10,000',
#   '692',
#   '411',
#   '16:27',
#   ''],
#  ['REPSOL',
#   '13,260',
#   '0,15',
#   '0,02',
#   '1,58',
#   '13,315',
#   '13,125',
#   '1.021.239',
#   '16.275',
#   '16:32',
#   ''],
#  ['ROVI',
#   '62,050',
#   '0,24',
#   '0,15',
#   '3,07',
#   '62,100',
#   '61,100',
#   '28.314',
#   '3.352',
#   '16:32',
#   ''],
#  ['SACYR',
#   '3,098',
#   '-1,59',
#   '-0,05',
#   '1,04',
#   '3,140',
#   '3,096',
#   '988.841',
#   '2.116',
#   '16:30',
#   ''],
#  ['SANTANDER',
#   '3,711',
#   '-1,30',
#   '-0,05',
#   '-1,81',
#   '3,744',
#   '3,693',
#   '16.510.558',
#   '60.059',
#   '16:32',
#   ''],
#  ['SOLARIA',
#   '15,685',
#   '-4,88',
#   '-0,80',
#   '-15,72',
#   '16,340',
#   '15,670',
#   '357.973',
#   '1.960',
#   '16:32',
#   ''],
#  ['SOLTEC POWER HOLDINGS',
#   '2,960',
#   '-2,31',
#   '-0,07',
#   '-14,00',
#   '3,034',
#   '2,940',
#   '131.615',
#   '283',
#   '16:20',
#   ''],
#  ['SQUIRREL',
#   '1,400',
#   '4,48',
#   '0,06',
#   '-6,04',
#   '1,420',
#   '1,340',
#   '5.758',
#   '127',
#   '15/01',
#   ''],
#  ['TALGO',
#   '4,405',
#   '-0,45',
#   '-0,02',
#   '0,34',
#   '4,440',
#   '4,385',
#   '79.188',
#   '557',
#   '16:22',
#   ''],
#  ['TECNICAS REUNIDAS',
#   '7,455',
#   '-0,73',
#   '-0,06',
#   '-10,72',
#   '7,580',
#   '7,385',
#   '172.371',
#   '599',
#   '16:32',
#   ''],
#  ['TELEFÓNICA',
#   '3,791',
#   '0,50',
#   '0,02',
#   '7,27',
#   '3,802',
#   '3,742',
#   '4.013.915',
#   '21.800',
#   '16:32',
#   ''],
#  ['TUBACEX',
#   '3,380',
#   '-2,87',
#   '-0,10',
#   '-3,43',
#   '3,490',
#   '3,330',
#   '185.627',
#   '428',
#   '16:30',
#   ''],
#  ['TUBOS REUNIDOS',
#   '0,870',
#   '0,00',
#   '0,00',
#   '34,88',
#   '0,909',
#   '0,853',
#   '4.575.252',
#   '152',
#   '16:23',
#   ''],
#  ['UNICAJA BANCO',
#   '0,898',
#   '-1,21',
#   '-0,01',
#   '0,90',
#   '0,906',
#   '0,893',
#   '5.084.168',
#   '2.384',
#   '16:31',
#   ''],
#  ['URBAS',
#   '0,005',
#   '-2,04',
#   '-0,00',
#   '11,63',
#   '0,005',
#   '0,005',
#   '49.642.888',
#   '67',
#   '16:15',
#   ''],
#  ['VIDRALA',
#   '90,300',
#   '-1,31',
#   '-1,20',
#   '-3,73',
#   '90,500',
#   '89,700',
#   '9.595',
#   '2.913',
#   '16:15',
#   ''],
#  ['VISCOFAN',
#   '54,400',
#   '0,93',
#   '0,50',
#   '1,49',
#   '54,500',
#   '53,800',
#   '21.301',
#   '2.530',
#   '16:27',
#   ''],
#  ['VOCENTO',
#   '0,548',
#   '-1,08',
#   '-0,01',
#   '-0,36',
#   '0,564',
#   '0,544',
#   '68.581',
#   '68',
#   '15:44',
#   '']]

# %%
pd.DataFrame(data=all_values, columns=all_header).iloc[:,:10].set_index('Valor')
# Out:
#                    Último Var. %   Var. Ac. % año     Máx.     Mín.  \
# Valor
# ACCIONA           122,350  -4,23  -5,40     -8,21  126,650  122,100
# ACCIONA ENER       23,980  -3,46  -0,86    -14,60   24,620   23,920
# ACERINOX           10,135  -2,55  -0,26     -4,88   10,400   10,125
# ACS                39,620  -1,59  -0,64     -1,34   40,080   39,500
# ADOLFO DOMÍNGUEZ    4,840  -1,63  -0,08     -3,20    4,900    4,840
# ...                   ...    ...    ...       ...      ...      ...
# UNICAJA BANCO       0,898  -1,21  -0,01      0,90    0,906    0,893
# URBAS               0,005  -2,04  -0,00     11,63    0,005    0,005
# VIDRALA            90,300  -1,31  -1,20     -3,73   90,500   89,700
# VISCOFAN           54,400   0,93   0,50      1,49   54,500   53,800
# VOCENTO             0,548  -1,08  -0,01     -0,36    0,564    0,544
#
#                         Vol.  Capit.   Hora
# Valor
# ACCIONA               71.279   6.712  16:32
# ACCIONA ENER         231.352   7.895  16:32
# ACERINOX             544.593   2.742  16:29
# ACS                  172.874  11.021  16:31
# ADOLFO DOMÍNGUEZ         133      45  12:42
# ...                      ...     ...    ...
# UNICAJA BANCO      5.084.168   2.384  16:31
# URBAS             49.642.888      67  16:15
# VIDRALA                9.595   2.913  16:15
# VISCOFAN              21.301   2.530  16:27
# VOCENTO               68.581      68  15:44
#
# [121 rows x 9 columns]

# %% [markdown]
# ## Bloque 3 - ¿Quién utiliza más palabras en sus canciones?

# %% [markdown]
# Localizamos en primer lugar una página web con letras de artistas que sea fácilmente parseable y le damos al opción de

# %%
WEB_BLOQUE3 = "https://www.letras.com"
GRUPO = "sfdk"

# %% [markdown]
# Extraemos ahora todos los links con canciones de un artista

# %%
x = requests.get(WEB_BLOQUE3 + "/" + GRUPO)

# %%
WEB_BLOQUE3 + "/" + GRUPO
# Out:
# 'https://www.letras.com/sfdk'

# %%
parsed_song_links = BeautifulSoup(x.text, "html.parser")
all_links_nodes = parsed_song_links.css.select("#cnt-artist-songlist a.songList-table-songName")
all_links = [[article.text, f"{WEB_BLOQUE3}{article.attrs['href']}"] for article in all_links_nodes]
all_links
# Out:
# [['2005', 'https://www.letras.com/sfdk/367297/'],
#  ['3 Hombres Y Un Destino', 'https://www.letras.com/sfdk/367298/'],
#  ['35 Rimas', 'https://www.letras.com/sfdk/610726/'],
#  ['41.008 (nivel Pino Montano)', 'https://www.letras.com/sfdk/367299/'],
#  ['A Donde Van', 'https://www.letras.com/sfdk/367300/'],
#  ['A mi no me lo cuentes', 'https://www.letras.com/sfdk/610727/'],
#  ['Abuchea!!', 'https://www.letras.com/sfdk/367301/'],
#  ['Ahora Yo Les Traigo El Sabor', 'https://www.letras.com/sfdk/367302/'],
#  ['Al Filo', 'https://www.letras.com/sfdk/367303/'],
#  ['Bailes de Salón (con Juaninacka)', 'https://www.letras.com/sfdk/367304/'],
#  ['Baobab (part. Escoberito)',
#   'https://www.letras.com/sfdk/baobab-part-escoberito/'],
#  ['Crossover', 'https://www.letras.com/sfdk/367305/'],
#  ['Cruzcampo', 'https://www.letras.com/sfdk/610728/'],
#  ['Cuarta Sinfonia', 'https://www.letras.com/sfdk/286089/'],
#  ['Defectos y Taras', 'https://www.letras.com/sfdk/defectos-y-taras/'],
#  ['Del Barrio Para El Barrio (part. El Límite y Karvoh)',
#   'https://www.letras.com/sfdk/del-barrio-para-el-barrio/'],
#  ['Desafío Total', 'https://www.letras.com/sfdk/367306/'],
#  ['Desde Los Chiqueros', 'https://www.letras.com/sfdk/367307/'],
#  ['Desde Pinomontano Hasta Los Vestuarios',
#   'https://www.letras.com/sfdk/desde-pinomontano-hasta-los-vestuarios/'],
#  ['Desde Sevilla Hasta Tu Tierra', 'https://www.letras.com/sfdk/367308/'],
#  ['Despedida Y Cierre (que Os Follen', 'https://www.letras.com/sfdk/367309/'],
#  ['Después de...', 'https://www.letras.com/sfdk/610729/'],
#  ['Diana Fácil', 'https://www.letras.com/sfdk/367310/'],
#  ['Dolar Mas Euro (con Tote King)', 'https://www.letras.com/sfdk/367311/'],
#  ['Donde Esta Wifly', 'https://www.letras.com/sfdk/367312/'],
#  ['Duelo de Vikingos', 'https://www.letras.com/sfdk/367313/'],
#  ['El Blues Del Condenado (part. Lia Kali)',
#   'https://www.letras.com/sfdk/el-blues-del-condenado-part-lia-kali/'],
#  ['El despreocupado', 'https://www.letras.com/sfdk/610730/'],
#  ['El Diablo de Alma Buena', 'https://www.letras.com/sfdk/367314/'],
#  ['El Doctor', 'https://www.letras.com/sfdk/367315/'],
#  ['El Liricista En El Tejado', 'https://www.letras.com/sfdk/268051/'],
#  ['El Niño Güei', 'https://www.letras.com/sfdk/367316/'],
#  ['El Perro Anda Suelto', 'https://www.letras.com/sfdk/367317/'],
#  ['En La Oscuridad (con Legendario)', 'https://www.letras.com/sfdk/367318/'],
#  ['Esta Canción Va Dedicada (Odisea En El Lodo)',
#   'https://www.letras.com/sfdk/esta-cancion-va-dedicada-odisea-en-el-lodo/'],
#  ['Esta cancion va dedicada Feat Morodo',
#   'https://www.letras.com/sfdk/937500/'],
#  ['Fuera de Lugar', 'https://www.letras.com/sfdk/367319/'],
#  ['Fuera, Cuantos Miran Por Mi', 'https://www.letras.com/sfdk/367320/'],
#  ['Fumar Cagando', 'https://www.letras.com/sfdk/367321/'],
#  ['Hoy no... (con el Loko de H Mafia)', 'https://www.letras.com/sfdk/367322/'],
#  ['Instituto de Bup de Pinomontano', 'https://www.letras.com/sfdk/610731/'],
#  ['Interludio', 'https://www.letras.com/sfdk/367323/'],
#  ['La 4ª sinfonía (Con Ose e Inma)', 'https://www.letras.com/sfdk/610732/'],
#  ['La cazadora', 'https://www.letras.com/sfdk/610733/'],
#  ['La Drina', 'https://www.letras.com/sfdk/367324/'],
#  ['La Habitación Que Mas Me Gusta de Mi Keli',
#   'https://www.letras.com/sfdk/367325/'],
#  ['La vida son problemas', 'https://www.letras.com/sfdk/610734/'],
#  ['Las Vocales', 'https://www.letras.com/sfdk/367326/'],
#  ['Llamalo Como Quieras', 'https://www.letras.com/sfdk/llamalo-como-quieras/'],
#  ['Los peliculistas', 'https://www.letras.com/sfdk/610735/'],
#  ['Mal Dia', 'https://www.letras.com/sfdk/367327/'],
#  ['Microphone Fenomeno', 'https://www.letras.com/sfdk/367328/'],
#  ['Modas son las que van y vienen', 'https://www.letras.com/sfdk/610736/'],
#  ['Mudanzas', 'https://www.letras.com/sfdk/mudanzas/'],
#  ['Next Level', 'https://www.letras.com/sfdk/367329/'],
#  ['No Eres Feo Ni Ná', 'https://www.letras.com/sfdk/367330/'],
#  ['Nunca', 'https://www.letras.com/sfdk/558106/'],
#  ['Ojos Tristes', 'https://www.letras.com/sfdk/367331/'],
#  ['Oskar Domina', 'https://www.letras.com/sfdk/oskar-domina/'],
#  ['Ovarios y Pelotas', 'https://www.letras.com/sfdk/ovarios-y-pelotas/'],
#  ['Pompa (part. Bejo)', 'https://www.letras.com/sfdk/pompa-part-bejo/'],
#  ['Pontelo, ponselo', 'https://www.letras.com/sfdk/610737/'],
#  ['Pruébalo', 'https://www.letras.com/sfdk/1031446/'],
#  ['¿Que Tienes Tú?', 'https://www.letras.com/sfdk/que-tienes-tu/'],
#  ['Que Te Lo Jumah!', 'https://www.letras.com/sfdk/367332/'],
#  ['Querer Es Poder', 'https://www.letras.com/sfdk/367333/'],
#  ['Racismo', 'https://www.letras.com/sfdk/610738/'],
#  ['Rap Romántico', 'https://www.letras.com/sfdk/367334/'],
#  ['Raper Tonto de Ciudad',
#   'https://www.letras.com/sfdk/raper-tonto-de-ciudad/'],
#  ['Seguimos En Linea', 'https://www.letras.com/sfdk/268536/'],
#  ['Señores En El Brunch (part. Kase O.)',
#   'https://www.letras.com/sfdk/senores-en-el-brunch-part-kase-o/'],
#  ['Siempre Fuertes', 'https://www.letras.com/sfdk/610739/'],
#  ['Siguiendo El Curso', 'https://www.letras.com/sfdk/siguiendo-el-curso/'],
#  ['Sin-Ceros (part. Natos y Waor)',
#   'https://www.letras.com/sfdk/sin-ceros-part-natos-y-waor/'],
#  ['Un Pobre Con Dinero', 'https://www.letras.com/sfdk/un-pobre-con-dinero/'],
#  ['Xxtra', 'https://www.letras.com/sfdk/610740/'],
#  ['¿Yo Que Hago Aquí?', 'https://www.letras.com/sfdk/606697/'],
#  ['Yo Contra Todos', 'https://www.letras.com/sfdk/268537/'],
#  ['Yo creo', 'https://www.letras.com/sfdk/1025184/'],
#  ['Yo Estuve Allí', 'https://www.letras.com/sfdk/yo-estuve-alli/'],
#  ['Yo soy el cabron', 'https://www.letras.com/sfdk/610741/']]

# %% [markdown]
# Con esto y la función que definimos al principio del documento podríamos exportar si quisiéramos todas las letras y sus nombres a un archivo

# %%
all_links[74]
# Out:
# ['Un Pobre Con Dinero', 'https://www.letras.com/sfdk/un-pobre-con-dinero/']

# %%
export_list_to_csv(all_links, ['cancion', 'direccion'], GRUPO)

# %% [markdown]
# Extraigamos ahora la letra de una canción utilizando su dirección web

# %%
y = requests.get(all_links[74][1])
parsed_song = BeautifulSoup(y.text, "html.parser")

# %% [markdown]
# Seleccionemos los párrafos con las letras

# %%
song_lyrics_nodes = parsed_song.css.select(".lyric p")

# %% [markdown]
# Reemplacemos los saltos de línea de HTML (\</br>) con espacios en blanco

# %%
for el in song_lyrics_nodes:
    [br.replace_with("\n").text for br in el.select("br")]

# %% [markdown]
# Transformemos ahora la canción de un objeto parseado de beautiful soup a texto

# %%
song_lyrics_nodes = [p.text for p in song_lyrics_nodes]
song_lyrics_nodes = "\n".join(song_lyrics_nodes)

# %% [markdown]
# Comprobemos como queda la canción

# %%
print(song_lyrics_nodes)
# Out:
# Vuelvo a tener seis añitos de edad
# Mi madre recién separá
# Los vecinos tuvieron pa mi buenos gestos na ma'
# Vacaciones invitaá'
# Estate despierto tienes que trabajar
# Era otro tiempo, otra mentalidad
# Aún me despierto de noche jartito e sudar
# Soñando a mi madre es lo má'
# Recibitos que pagar
# Papelitos Panamá, tu casa es la mía, primo, sí
# Solo si vengo a currar
# "Trabaja pa'l niño pijo", ya lo dijo mi mamá
# Mi abuela cuidó un cortijo, y antes de ella su mamá
# Un paseo mirando al mar
# Casas que no pueo pagar
# Y en el caso que pudiese
# ¿Quién coño las va a limpiar?
# Sueña un niño en la barriá
# Que un día lloverá el maná
# Y el pantanal no se estaba tan mal
# No se estaba tan mal
# No se estaba tan mal
# No se estaba tan mal
# No se estaba tan mal
# No se estaba tan mal
# No sé lo que quiero ejercer
# Pero sí lo que no quiero ser
# He nacido sin miedo a perder
# Lo que gané, lo aposté
# Me da seis frutos cada dos por tres, yo apenas disfruto, me da mucho corte
# Me dejé lo mejor para el postre
# Ya que nunca jamás me postré
# ¿Qué tan señorito?, una mierda pa usté
# Mi dinero tal vez no le guste
# Sonríe y le veo la boca toa llena de embuste'
# Me ha visto los tattoos, normal que se asuste
# Con la vara que diste, los balones al poste y el bigote de Shuster
# En mi lengua hay cuchillas de Oster
# Un paseo mirando al mar
# Casas que no puedo pagar
# En el caso que pudiese
# ¿Quién coño las va a limpiar?
# Sueña un niño en la barriá
# Que un día lloverá el maná
# Y el pantanal no se estaba tan mal
# No se estaba tan mal
# No se estaba tan mal
# No se estaba tan mal
# No se estaba tan mal
# No se estaba tan mal
# Tú no eres de barrio obrero, hermano, te lo huelo
# Por eso le tienes miedo al pobre con dinero
# Yo te friego el suelo
# Te ordeno el trastero
# Cojo lo que puedo
# Soy un bandolero
# Una fuga de gas y fuego
# Préndelo to, no le tengo apego
# Todo es falso y todo es de fuego, sí, delinquir sin comer talego
# No estudié en tu colegio, hasta luego, encantao de verte
# Vete por la sombra, no vaya' a caerte
# Así soy, seguiré hasta la muerte
# Un pobre y un golpe de suerte
# Un paseo mirando al mar
# Casas que no pueo pagar
# Y en el caso que pudiese
# ¿Quién coño la' va a limpiar?
# Sueña un niño en la barriá
# Que un día lloverá el maná
# Y el pantanal no se estaba tan mal
# No se estaba tan mal
# No se estaba tan mal
# No se estaba tan mal
# No se estaba tan mal
# No se estaba tan mal

# %% [markdown]
# Con esto podemos contar el número de palabras distintas que hay en la letra

# %%
len(set(song_lyrics_nodes.replace("\n", " ").split(" ")))
# Out:
# 222

# %% [markdown]
# Definamos ahora una función que haga todos estos pasos

# %%
def get_lyrics(url):

    y = requests.get(url)
    parsed_song = BeautifulSoup(y.text, "html.parser")

    song_lyrics_nodes = parsed_song.css.select(".lyric p")

    for el in song_lyrics_nodes:
        [br.replace_with("\n").text for br in el.select("br")]

    song_lyrics_nodes = [p.text for p in song_lyrics_nodes]
    song_lyrics_nodes = "\n".join(song_lyrics_nodes)

    palabras_diferentes = set(song_lyrics_nodes.replace("\n", " ").split(" "))

    return len(palabras_diferentes)

# %% [markdown]
# Podemos ahora ver cuantas palabras distintas tiene cada canción del artista

# %%
canciones = {all_links[i][0] : get_lyrics(all_links[i][1]) for i in range(len(all_links))}
canciones
# Out:
# {'2005': 224,
#  '3 Hombres Y Un Destino': 435,
#  '35 Rimas': 115,
#  '41.008 (nivel Pino Montano)': 286,
#  'A Donde Van': 262,
#  'A mi no me lo cuentes': 491,
#  'Abuchea!!': 266,
#  'Ahora Yo Les Traigo El Sabor': 285,
#  'Al Filo': 268,
#  'Bailes de Salón (con Juaninacka)': 418,
#  'Baobab (part. Escoberito)': 230,
#  'Crossover': 454,
#  'Cruzcampo': 306,
#  'Cuarta Sinfonia': 382,
#  'Defectos y Taras': 231,
#  'Del Barrio Para El Barrio (part. El Límite y Karvoh)': 188,
#  'Desafío Total': 488,
#  'Desde Los Chiqueros': 218,
#  'Desde Pinomontano Hasta Los Vestuarios': 492,
#  'Desde Sevilla Hasta Tu Tierra': 406,
#  'Despedida Y Cierre (que Os Follen': 265,
#  'Después de...': 338,
#  'Diana Fácil': 308,
#  'Dolar Mas Euro (con Tote King)': 475,
#  'Donde Esta Wifly': 235,
#  'Duelo de Vikingos': 193,
#  'El Blues Del Condenado (part. Lia Kali)': 197,
#  'El despreocupado': 182,
#  'El Diablo de Alma Buena': 276,
#  'El Doctor': 292,
#  'El Liricista En El Tejado': 377,
#  'El Niño Güei': 365,
#  'El Perro Anda Suelto': 225,
#  'En La Oscuridad (con Legendario)': 341,
#  'Esta Canción Va Dedicada (Odisea En El Lodo)': 323,
#  'Esta cancion va dedicada Feat Morodo': 373,
#  'Fuera de Lugar': 393,
#  'Fuera, Cuantos Miran Por Mi': 373,
#  'Fumar Cagando': 394,
#  'Hoy no... (con el Loko de H Mafia)': 351,
#  'Instituto de Bup de Pinomontano': 166,
#  'Interludio': 241,
#  'La 4ª sinfonía (Con Ose e Inma)': 404,
#  'La cazadora': 161,
#  'La Drina': 269,
#  'La Habitación Que Mas Me Gusta de Mi Keli': 318,
#  'La vida son problemas': 213,
#  'Las Vocales': 120,
#  'Llamalo Como Quieras': 218,
#  'Los peliculistas': 343,
#  'Mal Dia': 276,
#  'Microphone Fenomeno': 324,
#  'Modas son las que van y vienen': 232,
#  'Mudanzas': 318,
#  'Next Level': 311,
#  'No Eres Feo Ni Ná': 410,
#  'Nunca': 341,
#  'Ojos Tristes': 240,
#  'Oskar Domina': 119,
#  'Ovarios y Pelotas': 200,
#  'Pompa (part. Bejo)': 355,
#  'Pontelo, ponselo': 159,
#  'Pruébalo': 270,
#  '¿Que Tienes Tú?': 183,
#  'Que Te Lo Jumah!': 184,
#  'Querer Es Poder': 236,
#  'Racismo': 213,
#  'Rap Romántico': 408,
#  'Raper Tonto de Ciudad': 352,
#  'Seguimos En Linea': 462,
#  'Señores En El Brunch (part. Kase O.)': 314,
#  'Siempre Fuertes': 214,
#  'Siguiendo El Curso': 226,
#  'Sin-Ceros (part. Natos y Waor)': 278,
#  'Un Pobre Con Dinero': 222,
#  'Xxtra': 223,
#  '¿Yo Que Hago Aquí?': 316,
#  'Yo Contra Todos': 441,
#  'Yo creo': 317,
#  'Yo Estuve Allí': 278,
#  'Yo soy el cabron': 210}

# %% [markdown]
# Podemos ahora calcular el número medio de palabras distintas de cada artista

# %%
print(statistics.mean([canciones[key] for key in canciones.keys()]))
# Out:
# 293.9012345679012
