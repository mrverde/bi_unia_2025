# %% [markdown]
# # Apuntes rápidos sobre APIs
#
# Cuando queremos extraer datos de internet la forma más complicada es mediante el scraping y éste debe ser el último recurso.
#
# Antes de eso lo ideal es comprobar si la web o servicio del que queremos extraer datos dispone de una API. API significa "interfaz de programación de aplicaciones" y son protocolos y mecanismos que permiten a los softwares intercambiar información.
#
# Las APIs pueden ser públicas o de pago. Algunas además necesitan registro y autenticación.
#
# La información además puede venir en diferentes formatos. El formato mas común actualmente es [JSON](https://developer.mozilla.org/es/docs/Learn/JavaScript/Objects/JSON), aunque antes se usaba más [XML](https://es.wikipedia.org/wiki/Extensible_Markup_Language).
#
# En github podemos encontrar el repositorio [public-apis](https://github.com/public-apis/public-apis) donde podremos consultar cientos de APIs donde obtener datos.
#
# Existen diferentes tipos de APIs: Soap, WPC, Websocket, REST... Vamos a entrar sólo en las REST que son las más populares.
#
#
# ## REST
#
# REST significa transferencia de estado representacional y es la forma más popular de comunicación de APIs hoy en día. Esta forma de comunicación consiste en que un cliente realiza una una solicitud a un servidor como datos, el servidor realiza un conjunto de funciones definidas y devuelve unos datos de salida.
#
# REST define un conjunto de funciones. Las más importantes son GET, PUT, PATCH, POST y DELETE.
#
# Vamos a centrarnos en las peticiones GET.
#
# ## Peticiones GET
#
# Las peticiones GET sirven para pedir información. Si la petición ha ido bien el servidor devuelve un [código 200](https://developer.mozilla.org/es/docs/Web/HTTP/Status) y la información que hemos pedido.
#
# Tomemos ahora el ejemplo de un navegador web. Cuando en un navegador le indicamos una dirección web lo que está pasando es que nuestro navegador está haciendo una petición GET a esa página. Si todo va bien, el servidor al que le hacemos la petición devolverá el código HTML que usará el navegador para construir la web.
#
# Veamos como hacer esto con Python usando la [librería requests](https://requests.readthedocs.io):

# %%
import requests

x = requests.get("https://www.google.es")

# %% [markdown]
# Si hacemos un print de la petición que hemos hecho nos devolverá el código de nuestra petición.

# %%
print(x)
# Out:
# <Response [200]>

# %% [markdown]
# Y si imprimiemos la propiedad text nos devolverá en formato texto lo que nos ha devuelto el servidor.

# %%
print(x.text)
# Out:
# <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="es"><head><meta content="Google.es permite acceder a la información mundial en castellano, catalán, gallego, euskara e inglés." name="description"><meta content="noodp, " name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="-PjB3Z4kEJG3dto0zlxMog">(function(){var _g={kEI:'dpA4abyMH8Tm2roP8suFmAo',kEXPI:'0,203049,1101175,6,3030733,344796,270476,5249861,12355,52,67,16,35,4,3,36811499,25228681,152388,65157,30636,9140,4598,328,6226,63456,708,15098,8167,66131,48902,997,29413,7714,14750,15984,2651,4719,24338,22764,5683,3605,590,36461,21893,1,4375,6292,655,15524,2747,2,4,1,1164,11982,3656,2305,14623,4914,792,590,4,1378,136,2227,1128,195,572,2863,826,1554,2,4205,4,1790,7,8486,1430,4384,2,3105,5089,19,3008,21,774,368,424,14253,6,8203,2386,3,6725,3216,1039,5337,845,2047,1,1,6,14,424,1128,3,2842,9,27,8,3055,2757,4,14371,2997,29,12,3,23,1,244,297,5,1113,389,4,298,2265,84,5,4210,1,608,15,164,570,298,2415,1397,497,1947,1648,1349,1275,7,1785,1055,2,1994,340,93,82,4,2244,1174,3780,4,82,2572,2,3466,1902,4,963,741,908,4,1616,4295,1536,478,745,5,438,4,1391,1,2,482,18,4,299,3,516,363,238,206,36,3,2135,5,3,2760,88,10,204,441,797,1008,191,4,28,1443,457,2,1636,16,4,555,2575,731,81,484,5,97,187,208,655,804,438,5,259,5,197,2366,19,694,752,94,4,235,139,1050,127,81,392,4,133,203,138,27,202,1996,5,262,313,6,147,5,48,95,1192,219,4,443,24,49,27,1615,207,466,797,141,398,4,93,1088,3,2,2,2,340,359,273,245,5,1660,714,13,92,4,604,4,2,130,55,267,561,36,100,87,93,148,351,225,1443,147,8,99,4,32,4,394,54,310,27,59,10,4,1009,122,21,234,459,4,1,39,4,801,1155,10,8,552,4,6,16,141,182,1,1940,407,416,312,544,2,134,225,4,307,173,195,735,142,1041,3,2,2,2,56,5,958,1239,2,1314,82,2,944,131,1,911,538,71,423,438,30,102,1863,3148,1571,3,510,3,194,21011159,18489,5,2992,4,2960,3,2022,6469,2,1558,3,13178,1670,25,52,1143,3,746,6,2462,2,4,2,545,2469,2,1244,4,396,318,87,275,282,3,88,650,6492526,119,1777,2555261,1077914,210234,10844221,1,450961,4,540768,65432,1,112,8175,1,3,7,1876',kBL:'kJ20',kOPI:89978449};(function(){var a;((a=window.google)==null?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn='webhp';google.kHL='es';google.rdn=false;})();(function(){
# var g=this||self;function k(){return window.google&&window.google.kOPI||null};var l,m=[];function n(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||l}function p(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}function q(a){/^http:/i.test(a)&&window.location.protocol==="https:"&&(google.ml&&google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a}
# function r(a,b,d,c,h){var e="";b.search("&ei=")===-1&&(e="&ei="+n(c),b.search("&lei=")===-1&&(c=p(c))&&(e+="&lei="+c));var f=b.search("&cshid=")===-1&&a!=="slh";c="&zx="+Date.now().toString();g._cshid&&f&&(c+="&cshid="+g._cshid);(d=d())&&(c+="&opi="+d);return"/"+(h||"gen_204")+"?atyp=i&ct="+String(a)+"&cad="+(b+e+c)};l=google.kEI;google.getEI=n;google.getLEI=p;google.ml=function(){return null};google.log=function(a,b,d,c,h,e){e=e===void 0?k:e;d||(d=r(a,b,e,c,h));if(d=q(d)){a=new Image;var f=m.length;m[f]=a;a.onerror=a.onload=a.onabort=function(){delete m[f]};a.src=d}};google.logUrl=function(a,b){b=b===void 0?k:b;return r("",a,b)};}).call(this);(function(){google.y={};google.sy={};function e(a,b,c){if(a)var d=a.id;else{do d=Math.random();while(c[d])}c[d]=[a,b]}var f;(f=google).x||(f.x=function(a,b){e(a,b,google.y)});var g;(g=google).sx||(g.sx=function(a,b){e(a,b,google.sy)});google.lm=[];var h;(h=google).plm||(h.plm=function(a){google.lm.push.apply(google.lm,a)});google.lq=[];var k;(k=google).load||(k.load=function(a,b,c){google.lq.push([[a],b,c])});var l;(l=google).loadAll||(l.loadAll=function(a,b){google.lq.push([a,b])});google.bx=!1;var m;(m=google).lx||(m.lx=function(){});var n=[],p;(p=google).fce||(p.fce=function(a,b,c,d){n.push([a,b,c,d])});google.qce=n;google.adl=[];}).call(this);google.f={};(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a=c==="1"||c==="q"&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if(a.tagName==="A"){a=a.getAttribute("data-nohref")==="1";break a}a=!1}a&&b.preventDefault()},!0);}).call(this);</script><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}
# </style><style>body,td,a,p,.h{font-family:sans-serif}body{margin:0;overflow-y:scroll}#gog{padding:3px 8px 0}td{line-height:.8em}.gac_m td{line-height:17px}form{margin-bottom:20px}.h{color:#1967d2}em{font-weight:bold;font-style:normal}.lst{height:25px;width:496px}.gsfi,.lst{font:18px sans-serif}.gsfs{font:17px sans-serif}.ds{display:inline-box;display:inline-block;margin:3px 0 4px;margin-left:4px}input{font-family:inherit}body{background:#fff;color:#1f1f1f}a{color:#681da8;text-decoration:none}a:hover,a:active{text-decoration:underline}.fl a{color:#1967d2}a:visited{color:#681da8}.sblc{padding-top:5px}.sblc a{display:block;margin:2px 0;margin-left:13px;font-size:11px}.lsbb{background:#ecedee;border:solid 1px;border-color:#d2d2d2 #70757a #70757a #d2d2d2;height:30px}.lsbb{display:block}#WqQANb a{display:inline-block;margin:0 12px}.lsb{background:url(/images/nav_logo229.png) 0 -261px repeat-x;color:#1f1f1f;border:none;cursor:pointer;height:30px;margin:0;outline:0;font:15px sans-serif;vertical-align:top}.lsb:active{background:#dadce0}.lst:focus{outline:none}</style><script nonce="-PjB3Z4kEJG3dto0zlxMog">(function(){window.google.erd={jsr:1,bv:2339,de:true,dpf:'VnbvJLHQ3F-dcB57qKOlHYNRI_5zA3U6uGFC7CUxP8g'};
# var g=this||self;var k,l=(k=g.mei)!=null?k:1,m,p=(m=g.diel)!=null?m:0,q,r=(q=g.sdo)!=null?q:!0,t=0,u,w=google.erd,x=w.jsr;google.ml=function(a,b,d,n,e){e=e===void 0?2:e;b&&(u=a&&a.message);d===void 0&&(d={});d.cad="ple_"+google.ple+".aple_"+google.aple;if(google.dl)return google.dl(a,e,d,!0),null;b=d;if(x<0){window.console&&console.error(a,b);if(x===-2)throw a;b=!1}else b=!a||!a.message||a.message==="Error loading script"||t>=l&&!n?!1:!0;if(!b)return null;t++;d=d||{};b=encodeURIComponent;var c="/gen_204?atyp=i&ei="+b(google.kEI);google.kEXPI&&(c+="&jexpid="+b(google.kEXPI));c+="&srcpg="+b(google.sn)+"&jsr="+b(w.jsr)+
# "&bver="+b(w.bv);w.dpf&&(c+="&dpf="+b(w.dpf));var f=a.lineNumber;f!==void 0&&(c+="&line="+f);var h=a.fileName;h&&(h.indexOf("-extension:/")>0&&(e=3),c+="&script="+b(h),f&&h===window.location.href&&(f=document.documentElement.outerHTML.split("\n")[f],c+="&cad="+b(f?f.substring(0,300):"No script found.")));google.ple&&google.ple===1&&(e=2);c+="&jsel="+e;for(var v in d)c+="&",c+=b(v),c+="=",c+=b(d[v]);c=c+"&emsg="+b(a.name+": "+a.message);c=c+"&jsst="+b(a.stack||"N/A");c.length>=12288&&(c=c.substring(0,12288));a=c;n||google.log(0,"",a);return a};window.onerror=function(a,b,d,n,e){u!==a&&(a=e instanceof Error?e:Error(a),d===void 0||"lineNumber"in a||(a.lineNumber=d),b===void 0||"fileName"in a||(a.fileName=b),google.ml(a,!1,void 0,!1,a.name==="SyntaxError"||a.message.substring(0,11)==="SyntaxError"||a.message.indexOf("Script error")!==-1?3:p));u=null;r&&t>=l&&(window.onerror=null)};})();</script></head><body bgcolor="#fff"><script nonce="-PjB3Z4kEJG3dto0zlxMog">(function(){var src='/images/nav_logo229.png';var iesg=false;document.body.onload = function(){window.n && window.n();if (document.images){new Image().src=src;}
# if (!iesg){document.f&&document.f.q.focus();document.gbqf&&document.gbqf.q.focus();}
# }
# })();</script><div id="mngb"><div id=gbar><nobr><b class=gb1>Búsqueda</b> <a class=gb1 href="https://www.google.com/imghp?hl=es&tab=wi">Imágenes</a> <a class=gb1 href="https://maps.google.es/maps?hl=es&tab=wl">Maps</a> <a class=gb1 href="https://play.google.com/?hl=es&tab=w8">Play</a> <a class=gb1 href="https://www.youtube.com/?tab=w1">YouTube</a> <a class=gb1 href="https://news.google.com/?tab=wn">Noticias</a> <a class=gb1 href="https://mail.google.com/mail/?tab=wm">Gmail</a> <a class=gb1 href="https://drive.google.com/?tab=wo">Drive</a> <a class=gb1 style="text-decoration:none" href="https://www.google.es/intl/es/about/products?tab=wh"><u>Más</u> &raquo;</a></nobr></div><div id=guser width=100%><nobr><span id=gbn class=gbi></span><span id=gbf class=gbf></span><span id=gbe></span><a href="http://www.google.es/history/optout?hl=es" class=gb4>Historial web</a> | <a  href="/preferences?hl=es" class=gb4>Ajustes</a> | <a target=_top id=gb_70 href="https://accounts.google.com/ServiceLogin?hl=es&passive=true&continue=https://www.google.com/&ec=GAZAAQ" class=gb4>Iniciar sesión</a></nobr></div><div class=gbh style=left:0></div><div class=gbh style=right:0></div></div><center><br clear="all" id="lgpd"><div><img alt="Google" height="92" src="/images/branding/googlelogo/1x/googlelogo_white_background_color_272x92dp.png" style="padding:28px 0 14px" width="272" id="hplogo"><br><br></div><form action="/search" name="f"><table cellpadding="0" cellspacing="0"><tr valign="top"><td width="25%">&nbsp;</td><td align="center" nowrap=""><input name="ie" value="ISO-8859-1" type="hidden"><input value="es" name="hl" type="hidden"><input name="source" type="hidden" value="hp"><input name="biw" type="hidden"><input name="bih" type="hidden"><div class="ds" style="height:32px;margin:4px 0"><input class="lst" style="margin:0;padding:5px 8px 0 6px;vertical-align:top;color:#1f1f1f" autocomplete="off" value="" title="Buscar con Google" maxlength="2048" name="q" size="57"></div><br style="line-height:0"><span class="ds"><span class="lsbb"><input class="lsb" value="Buscar con Google" name="btnG" type="submit"></span></span><span class="ds"><span class="lsbb"><input class="lsb" id="tsuid_dpA4abyMH8Tm2roP8suFmAo_1" value="Voy a tener suerte" name="btnI" type="submit"><script nonce="-PjB3Z4kEJG3dto0zlxMog">(function(){var id='tsuid_dpA4abyMH8Tm2roP8suFmAo_1';document.getElementById(id).onclick = function(){if (this.form.q.value){this.checked = 1;if (this.form.iflsig)this.form.iflsig.disabled = false;}
# else top.location='/doodles/';};})();</script><input value="AOw8s4IAAAAAaTiehtKvgePX9Grx7ExYQSuAtzS1ksB6" name="iflsig" type="hidden"></span></span></td><td class="fl sblc" align="left" nowrap="" width="25%"><a href="/advanced_search?hl=es&amp;authuser=0">Búsqueda avanzada</a></td></tr></table><input id="gbv" name="gbv" type="hidden" value="1"><script nonce="-PjB3Z4kEJG3dto0zlxMog">(function(){var a,b="1";if(document&&document.getElementById)if(typeof XMLHttpRequest!="undefined")b="2";else if(typeof ActiveXObject!="undefined"){var c,d,e=["MSXML2.XMLHTTP.6.0","MSXML2.XMLHTTP.3.0","MSXML2.XMLHTTP","Microsoft.XMLHTTP"];for(c=0;d=e[c++];)try{new ActiveXObject(d),b="2"}catch(h){}}a=b;if(a=="2"&&location.search.indexOf("&gbv=2")==-1){var f=google.gbvu,g=document.getElementById("gbv");g&&(g.value=a);f&&window.setTimeout(function(){location.href=f},0)};}).call(this);</script></form><div style="font-size:83%;min-height:3.5em"><br><div id="gws-output-pages-elements-homepage_additional_languages__als"><style>#gws-output-pages-elements-homepage_additional_languages__als{font-size:small;margin-bottom:24px}#SIvCob{color:#545454;display:inline-block;line-height:28px;}#SIvCob a{}.H6sW5{display:inline-block;margin:0 2px;white-space:nowrap}.z4hgWe{display:inline-block;margin:0 2px}</style><div id="SIvCob">Ofrecido por Google en:  <a href="https://www.google.com/setprefs?sig=0_4ZJCpWD3TWj16vOYMb0dRFmwqXs%3D&amp;hl=ca&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwi8n9HStbGRAxVEs1YBHfJlAaMQ2ZgBCAY">català</a>    <a href="https://www.google.com/setprefs?sig=0_4ZJCpWD3TWj16vOYMb0dRFmwqXs%3D&amp;hl=gl&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwi8n9HStbGRAxVEs1YBHfJlAaMQ2ZgBCAc">galego</a>    <a href="https://www.google.com/setprefs?sig=0_4ZJCpWD3TWj16vOYMb0dRFmwqXs%3D&amp;hl=eu&amp;source=homepage&amp;sa=X&amp;ved=0ahUKEwi8n9HStbGRAxVEs1YBHfJlAaMQ2ZgBCAg">euskara</a>  </div></div></div><span id="footer"><div style="font-size:10pt"><div style="margin:19px auto;text-align:center" id="WqQANb"><a href="/intl/es/ads/">Publicidad</a><a href="http://www.google.es/intl/es/services/">Soluciones Empresariales</a><a href="/intl/es/about.html">Todo acerca de Google</a><a href="https://www.google.com/setprefdomain?prefdom=ES&amp;prev=https://www.google.es/&amp;sig=K_Z2AjcOkRW7NDDjfU7hln4tLHoBU%3D">Google.es</a></div></div><p style="font-size:8pt;color:#636363">&copy; 2025 - <a href="/intl/es/policies/privacy/">Privacidad</a> - <a href="/intl/es/policies/terms/">Términos</a></p></span></center><script nonce="-PjB3Z4kEJG3dto0zlxMog">(function(){window.google.cdo={height:757,width:1440};(function(){var a=window.innerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d=c.compatMode=="CSS1Compat"?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}if(a&&b&&(a!=google.cdo.width||b!=google.cdo.height)){var e=google,f=e.log,g="/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI,h="",k=window.google&&window.google.kOPI||null;k&&(h+="&opi="+k);f.call(e,"","",g+h)};}).call(this);})();(function(){google.xjs={basecomb:'/xjs/_/js/k\x3dxjs.hp.en.wMBWoW7LOqs.es5.O/ck\x3dxjs.hp.8oEeNtCKV4w.L.X.O/am\x3dACEAAAAAAAAAAAEAAAAAAAAAAAAAAAAAAAAAAAAAAAACAAAAAAgIBAAAAAAAAAAAAAAAAAAAAEAAAAAAABEMAACgAIAQAAAAAAAIAAACAAAAAAASAAABCAAAIL4jAAAAAAJgEQAAAACAFw/d\x3d1/ed\x3d1/dg\x3d0/ujg\x3d1/rs\x3dACT90oF3u4f5bLvV3P-J_h7Rw1XLj6KVLQ',basecss:'/xjs/_/ss/k\x3dxjs.hp.8oEeNtCKV4w.L.X.O/am\x3dACEAAAAAAAAAAAEAAAAAAAAAAAAAAAAAAAAAAAAAAAACAAAAAAgABAAAAAAAAAAAAAAAAAAAAAAAAAAAAAEAAACgAIAQAAAAAAAIAAACAAAAAAASAAABCA/rs\x3dACT90oFDjInEXTJtwAwGKgVYXZHv2q8zrg',basejs:'/xjs/_/js/k\x3dxjs.hp.en.wMBWoW7LOqs.es5.O/am\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAIAAAAAAAAAAAAAAAAAAAAAEAAAAAAABAMAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAIL4jAAAAAAJgEQAAAACAFw/dg\x3d0/rs\x3dACT90oH91YCq2IdmLnVwmQ0aEKXaILZyVQ',excm:[]};})();(function(){var u='/xjs/_/js/k\x3dxjs.hp.en.wMBWoW7LOqs.es5.O/am\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAIAAAAAAAAAAAAAAAAAAAAAEAAAAAAABAMAAAAAAAAAAAAAAAAAAAAAAAAAAAA ...
# var f=this||self;function g(){var a=google.ia&&google.ia.r.B2Jtyd;return a&&[1,5,6].indexOf(a.m)>=0&&a.cbfd&&a.cbvi?a:void 0};function h(a){var b=document.createElement("link");b.as="script";b.href=a;b.rel="preload";document.body.appendChild(b)}function k(){var a=[l];google.dp||(a.forEach(h),google.dp=!0)};google.ps=google.ps||[];function m(a){var b=l,c=function(){};google.lx=google.stvsc?c:function(){n(b,a);google.lx=c};google.bx||google.lx()}function p(a,b){b&&(a.src=b);fp&&google.caft&&google.caft(function(){a.fetchPriority=fp});var c=a.onload;a.onload=function(e){c&&c(e);google.ps=google.ps.filter(function(d){return a!==d})};google.ps.push(a);document.body.appendChild(a)}function q(a,b,c){b?requestAnimationFrame(function(){p(a,c)}):p(a,c)}google.as=p;function n(a,b){google.tick&&google.tick("load","xjsls");var c=document.createElement("script");c.onerror=function(){google.ple=1};c.onload=function(){google.ple=0};google.xjsus=void 0;q(c,b,a);google.aple=-1;google.dp=!0};function r(){for(var a=document.getElementsByTagName("img"),b=0,c=a.length;b<c;b++){var e=a[b],d;if(d=e.hasAttribute("data-lzy_")&&Number(e.getAttribute("data-atf"))&1)d=e.getAttribute("jscontroller"),d=!((d==="UBXHI"||d==="R3fhkb"||d==="TSZEqd")&&e.hasAttribute("data-src"));if(d)return!0}return!1};var l,t,w,x,y,z,A,B,C,D,E="";function F(){l=pxp&&google.xjsup||u;var a=l.match("/cb=(loaded_h_\\d+)");a&&a[1]&&(E=a[1]);google.xjsu=l;f._F_jsUrl=l;z=function(c){m(c)};t=!1;w=(st===1||st===3)&&!!google.caft&&!r();x=g();y=!E&&(st===2||st===3)&&!!x&&!r();if(E){var b=(st===2||st===3)&&!!x;f[E]=function(c){var e=!1,d=function(){e||(e=!0,cst?setTimeout(function(){return void c.call(window,window._)},0):c.call(window,window._))};b&&google.ia.adls?(x.cbvi.push(function(){delete google.ia.adls}),x.cbvi.push(d),setTimeout(d,mmd)):d()}}A=
# pop;B=povp;C=A&&document.prerendering||B&&document.hidden;D=B?"visibilitychange":"prerenderingchange"}function G(a){t||w||y||C||(z(a),t=!0)}
# setTimeout(function(){google.tick&&google.tick("load","xjspls");F();if(w||y||C){if(w){var a=function(){w=!1;G()};google.caft(a);setTimeout(a,amd)}y&&(a=function(){y=!1;G()},x.cbvi.push(a),setTimeout(a,mmd));if(C){var b=function(){(B?document.hidden:document.prerendering)||(C=!1,G(!B&&!1),document.removeEventListener(D,b))};document.addEventListener(D,b,{passive:!0})}t||k()}else z()},0);})();window._ = window._ || {};window._DumpException = _._DumpException = function(e){throw e;};window._s = window._s || {};_s._DumpException = _._DumpException;window._qs = window._qs || {};_qs._DumpException = _._DumpException;window.loaded_h_0 = function(cb){cb.call(window,window._);};(function(){var t=[8448,0,1048576,0,0,0,0,0,655360,536870912,8405184,0,32,0,67108864,129171456,548147460,163844,268435720,33689696,131072,0,268435744,512,2342432,134217728,71200,536870912,23];window._F_toggles = window._xjs_toggles = t;})();window._F_installCss = window._F_installCss || function(css){};(function(){google.jl={bfl:0,dw:false,eli:false,ine:false,ubm:false,uwp:true,vs:false};})();(function(){var pmc='{\x22d\x22:{},\x22sb_he\x22:{\x22client\x22:\x22heirloom-hp\x22,\x22dh\x22:true,\x22ds\x22:\x22\x22,\x22host\x22:\x22google.com\x22,\x22jsonp\x22:true,\x22lm\x22:true,\x22msgs\x22:{\x22cibl\x22:\x22Borrar b\\u00fasqueda\x22,\x22dym\x22:\x22Quiz\\u00e1s quisiste decir:\x22,\x22lcky\x22:\x22Voy a tener suerte\x22,\x22lml\x22:\x22M\\u00e1s informaci\\u00f3n\x22,\x22psrc\x22:\x22Esta b\\u00fasqueda se ha eliminado de tu \\u003Ca href\x3d\\\x22/history\\\x22\\u003Ehistorial web\\u003C/a\\u003E.\x22,\x22psrl\x22:\x22Eliminar\x22,\x22sbit\x22:\x22Buscar por imagen\x22,\x22srch\x22:\x22Buscar con Google\x22},\x22ovr\x22:{},\x22pq\x22:\x22\x22,\x22rfs\x22:[],\x22stok\x22:\x22XgeBUpc0OlZLWl7_WlsoNRH8aqs\x22}}';google.pmc=JSON.parse(pmc);})();</script></body></html>

# %% [markdown]
# Vamos ahora a ver como trabajar con una API de internet para extraer datos. Tras examinar el repositorio de [public-apis](https://github.com/public-apis/public-apis) vamos a usar por ejemplo la API de [arbeitnow](http://www.arbeitnow.com), un buscador de empleo alemán.
#
# La documentación de la API la podemos encontrar en la dirección https://documenter.getpostman.com/view/18545278/UVJbJdKh
#
# Vamos ahora a hacer la petición utilizando la librería requests.

# %%
x = requests.get("https://www.arbeitnow.com/api/job-board-api")

# %% [markdown]
# Para ver el JSON con los datos que recibimos tendremos que utilizar el método json.

# %%
x.json()
# Out:
# {'data': [{'slug': 'buchhalter-teilzeit-gross-gerau-414464',
#    'company_name': 'Jakob Winter GmbH',
#    'title': 'Buchhalter - Teilzeit (m/w/d)',
#    'description': '<p>Als Unternehmen machen wir vieles, aber alles dreht sich um das Thema Koffer und Formteile. Wir arbeiten für weltweit erfolgreiche Marken und agieren für diese als Produktionspartner. Zudem entwickeln wir auch unsere eigenen Marken und vertreiben diese über Händler oder im Direct-to-Consumer eCommerce. Das geschieht alles unter unserem Motto „Manufacturing Brands“.</p>\n<p>Unsere Unternehmensbereiche sind so abwechslungsreich wie wir selbst und alle Fachabteilungen arbeiten Hand in Hand zusammen. Unser super nettes und internationales Team arbeitet über unsere beiden Standorte Marienberg und Groß-Gerau eng zusammen. Du wirst Teil eines wachsenden Umfelds sein und hast die Chance, durch Eigeninitiative und Motivation unsere Zukunft mitzugestalten. Bist du dabei?</p>\n<h2>Aufgaben</h2>\n<ul>\n<li>Debitoren &#x26; Kreditorenbuchhaltung</li>\n<li>Abwicklung und Betreuung laufender Geschäftsvorfälle</li>\n<li>Vorbereitung der Lohnbuchhaltung</li>\n<li>Verwaltung des Zahlungsverkehrs und des Abrechnungswesens</li>\n<li>Erstellung von Meldungen und Statistiken an verschiedene externe Institutionen</li>\n<li>Kontakt mit Steuerbüro</li>\n</ul>\n<h2>Qualifikation</h2>\n<ul>\n<li>Du bist ein absoluter Self-Starter. Du siehst deine Motivation in eigenständigen Arbeiten sodass du Dinge wirklich bewegen kannst. Du liebst es Ideen zu entwickeln und diese einfach mal auszuprobieren</li>\n<li>Wir sind ein mittelständiges Unternehmen und bei uns zählt jeder Mitarbeiter. Du arbeitest zu bewegen und uns voranzubringen. Du arbeitest zudem sehr sorgfältig und zuverlässig.</li>\n</ul>\n<p>Außerdem sind noch folgende Qualifikationen hilfreich:</p>\n<ul>\n<li>Studium oder abgeschlossene kfm. Ausbildung mit dem Schwerpunkt Finanzen/ Rechnungswesen bzw. Steuerfachangestellte/r</li>\n<li>Einschlägige, mehrjährige Erfahrung im Rechnungswesen</li>\n<li>Professioneller Umgang mit den MS-Office-Produkten und einem ERP-Programm</li>\n<li>Sehr gute Deutsch- und gute Englischkenntnisse in Wort und Schrift</li>\n<li>Eigenständige Arbeitsweise offene Persönlichkeit</li>\n<li>Hohes Maß an Sorgfältigkeit, Zuverlässigkeit und Diskretion</li>\n</ul>\n<h2>Benefits</h2>\n<p><em>Bei uns bist du Teil eines wachsenden &#x26; motivierten Teams sein und kannst die Zukunft des Unternehmens und unserer Marken mitgestalten. Du willst dich immer weiterentwickeln und schätzt es sehr eigenständig zu arbeiten, Verantwortung zu übernehmen und dazu beizutragen, dass wir uns kontinuierlich verbessern? Klasse dann suchen wir dich! Bei uns bekommst du auch:</em></p>\n<ul>\n<li>30 Urlaubstage (berechnet auf Vollzeitbasis)</li>\n<li>Ein abwechslungsreicher Arbeitsplatz in einem mittelständigen Familienunternehmen</li>\n<li>Die Mitarbeit in einem wachstumsstarken und ambitionierten Unternehmen mit langfristigen Chancen für deine Talente und deine Weiterentwicklung</li>\n<li>Motivierte &#x26; engagierte Teamkultur mit extrem netten Kollegen</li>\n<li>Möglichkeit dich immer weiterzuentwickeln, egal ob durch on-the-job Training, Wissen deiner Kollegen oder eLearnings</li>\n<li>Vorteile wie Lunch &#x26; Learn Sessions und steuerfreie Zulagen</li>\n<li>Regelmäßiges Feedback und Planung deiner Karriereentwicklung</li>\n</ul>\n<p>Find more <a href="https://www.arbeitnow.com/english-speaking-jobs">English Speaking Jobs in Germany</a> on Arbeitnow</a>',
#    'remote': False,
#    'url': 'https://www.arbeitnow.com/jobs/companies/jakob-winter-gmbh/buchhalter-teilzeit-gross-gerau-414464',
#    'tags': ['Finance'],
#    'job_types': [],
#    'location': 'Groß-Gerau',
#    'created_at': 1765308707},
#   {'slug': 'senior-inhouse-consultant-ki-projekte-gn-dortmund-35180',
#    'company_name': 'Projekt 3T GmbH',
#    'title': 'Senior Inhouse Consultant KI-Projekte (gn)',
#    'description': '<p>Mein Mandant – ein modernes Dienstleistungsunternehmen mit über 20.000 Mitarbeitenden - befindet sich mitten in einer umfassenden digitalen Transformation, in der <strong>High Code KI-Lösungen</strong> ein zentraler Hebel für Effizienz, Automation und neue Wertschöpfung werden. Das Unternehmen baut dafür eine professionelle und skalierbare KI-Organisation auf – mit klaren Strukturen für <strong>AI Strategy, Portfolio-Management, Data- &#x26; Tech Enablement sowie Delivery</strong>.</p>\n<p>Im Herzen dieser Struktur steht ein <strong>AI Hub</strong>, der gemeinsam mit den Fachbereichen und technischen Einheiten <strong>High Code Use Cases</strong> identifiziert und realisiert – also KI-Lösungen, die echte Modellarchitektur, Datenpipelines, Integrationen in Kernsysteme und produktive Deployments erfordern. Darauf aufbauend entstehen <strong>Leuchtturmprojekte</strong>, die die Organisation technologisch wie fachlich weiterentwickeln – und genau hier setzt Deine Rolle an.</p>\n<h2>Aufgaben</h2>\n<p>Als <strong>Senior Inhouse Consultant KI-Projekte</strong> gestaltest Du die strategisch relevantesten High Code KI-Initiativen von Anfang an mit. Du bringst Struktur, Klarheit und Entscheidungsfähigkeit in Projekte, deren technologische und fachliche Komplexität deutlich über einfache Automationen hinausgeht.</p>\n<p>Deine Aufgaben umfassen:</p>\n<ul>\n<li>Analyse und Strukturierung anspruchsvoller High Code Use Cases (z. B. komplexe ML-Modelle, KI-gestützte Entscheidungslogiken, Prozesse mit Systemintegration)</li>\n<li>Verantwortung für ausgewählte <strong>Leuchtturmprojekte</strong>: Zielbild, Business Case, Roadmap, Steuerung und Erfolgsmessung</li>\n<li>Strategische Beratung von Führungskräften zu Potenzialen und Grenzen technisch anspruchsvoller KI-Lösungen</li>\n<li>Moderation von Workshops, Priorisierungen und Portfolio-Entscheidungen</li>\n<li>Steuerung interdisziplinärer Projektteams aus Data Scientists, Data Engineers, Architekt*innen, IT und Fachbereichen</li>\n<li>Übersetzung technischer Anforderungen in klare, verständliche Business-Storylines für das Management</li>\n<li>Mitgestaltung des <strong>KI-Operating Models</strong>: Standards, Methodik, Governance, Verantwortlichkeiten</li>\n<li>Sicherstellung eines strukturierten End-to-End-Ansatzes – von der Idee über das MVP bis zur produktiven Nutzung</li>\n</ul>\n<h2>Qualifikation</h2>\n<p><strong>Erfahrungshintergrund (zielgerichtet breit):</strong></p>\n<ul>\n<li>Tier-1 oder Tier-2 Strategieberatung</li>\n<li>Inhouse Consulting, Corporate Strategy oder Transformationseinheiten</li>\n<li>Alternativ: Product Owner / Product Manager mit Erfahrung in datenintensiven oder KI-nahen Produkten</li>\n<li>Erfahrung in der Steuerung komplexer Digital- oder Analytics-Projekte von Vorteil</li>\n</ul>\n<p><strong>Fachlich-methodische Kernkompetenzen:</strong></p>\n<ul>\n<li>Ausgezeichnete Konzeptions- und Strukturierungsfähigkeit</li>\n<li>Fundiertes Verständnis dafür, <strong>wie High Code KI-Lösungen entstehen</strong><br>\n(z. B. Datenpipelines, Modelltraining, Evaluation, Deployment, Integration)<br>\n– ohne selbst technisch entwickeln zu müssen</li>\n<li>Fähigkeit, Use Cases hinsichtlich Wertbeitrag, Machbarkeit und Risiken einzuschätzen</li>\n<li>Starkes Stakeholder-Management im Umgang mit Tech-Teams und Business-Stakeholdern</li>\n<li>Souveränes Storylining und Vorbereitung von Entscheidungen auf Management-Level</li>\n</ul>\n<p><strong>Persönliche Stärken:</strong></p>\n<ul>\n<li>Beratungs-typischer Drive, analytische Schärfe und hohe Präzision</li>\n<li>Freude an komplexen Problemstellungen und innovativen Technologien</li>\n<li>Kommunikationsstärke und Fähigkeit, verschiedene Perspektiven zu integrieren</li>\n<li>Ownership, Neugier und Gestaltungswille</li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li>Verantwortung für <strong>strategische Leuchtturmprojekte</strong>, die den Weg für weitere KI-Initiativen ebnen und mit denen Du Dich weiterentwickelst</li>\n< ...
#    'remote': True,
#    'url': 'https://www.arbeitnow.com/jobs/companies/projekt-3t-gmbh/senior-inhouse-consultant-ki-projekte-gn-dortmund-35180',
#    'tags': ['Remote', 'Business Consulting'],
#    'job_types': ['berufserfahren'],
#    'location': 'Dortmund',
#    'created_at': 1765306923},
#   {'slug': 'marketingassistentin-mit-weiteren-kaufmannischen-aufgaben-in-tz-freiburg-im-breisgau-45837',
#    'company_name': 'PAV Christa Thielking',
#    'title': 'Marketingassistent:in - mit weiteren kaufmännischen Aufgaben in TZ',
#    'description': '<p>Immobilien-Finanzierungen-Unternehmensentwicklung-Versicherungen-Kapitalanlagen - für 12-20 Std./Wo.</p>\n<p>Für ein Unternehmen in Freiburg suche ich jetzt oder später eine Unterstützung.</p>\n<h2>Aufgaben</h2>\n<p>Als zentrale Stütze des Teams übernehmen Sie wichtige Aufgaben:</p>\n<ul>\n<li><strong>Digitales Dokumentenmanagement:</strong> Organisation, Verwaltung und Pflege unserer digitalen Unterlagen (z.B. rund um Immobilien und Finanzierungen).</li>\n<li><strong>Daten-Expertise</strong>: Erstellung, Pflege und Auswertung von Excel-Tabellen.</li>\n<li><strong>Kunden- &#x26; Datenbankpflege</strong>: Sorgfältige Verwaltung der Kundendaten in unserer internen Datenbank.</li>\n<li><strong>Vertriebs-Suppor</strong>t: Aktive Unterstützung unseres Vertriebsteams im Tagesgeschäft.</li>\n<li><strong>Exposé-Erstellung</strong>: Gestaltung ansprechender Immobilien-Exposés.</li>\n</ul>\n<p>Mit Interesse und Erfahrung können Sie sich zusätzlich in folgenden Bereichen einbringen:</p>\n<ul>\n<li><strong>Objekt-Präsentation</strong>: Durchführung der Objektfotografie zur optimalen Darstellung unserer Immobilien.</li>\n<li><strong>Unternehmensauftritt</strong>: Mitarbeit an unserem digitalen Unternehmensauftritt (z.B. Website/Social Media-Support).</li>\n</ul>\n<h2>Qualifikation</h2>\n<ul>\n<li><strong>Digitale Affinität</strong>: Sie sind sicher im Umgang mit Microsoft Excel und digitalen Tools.</li>\n<li><strong>Kreativität &#x26; Auge fürs Detail</strong>: Idealerweise ein gutes Auge für Gestaltung, Bildmaterial und Ästhetik.</li>\n<li><strong>Arbeitsweise</strong>: Sie arbeiten sorgfältig, strukturiert und selbstständig.</li>\n<li><strong>Interesse</strong>: Sie bringen ein Grundinteresse an den Themen Immobilien und Finanzierung mit.</li>\n<li><strong>Persönlichkeit</strong>: Sie sind teamfähig, zuverlässig und kommunikationsstark.</li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li><strong>Modernität</strong>: Ein digitales Arbeitsumfeld mit moderner Ausstattung.</li>\n<li><strong>Verantwortung</strong>: Abwechslungsreiche Aufgaben mit der Möglichkeit, eigene Verantwortung zu übernehmen – von Verwaltung bis hin zur kreativen Gestaltung.</li>\n<li><strong>Kultur</strong>: Ein freundliches Team und ein angenehmes Betriebsklima.</li>\n<li><strong>Flexibilität &#x26; Entwicklung</strong>: Flexible Arbeitszeiten und individuelle Entwicklungsmöglichkeiten.</li>\n</ul>\n<p>Sie können sich in dieser <strong>interessanten und abwechslungsreichen Tätigkeit</strong> sehen? <strong>Marketing und Assistenz</strong> ist genau das, worin Sie Erfahrung haben? Bitte bewerben Sie sich zunächst mit Ihrem Lebenslauf, gerne können Sie aber auch ein Anschreiben und Ihre Zeugnisse beifügen.</p>\n<p><strong>Frau Thielking</strong> wird sich kurzfristig bei Ihnen melden und bei Eignung einen Termin für ein erstes Onlinegespräch mit Ihnen führen. Das Folgegespräch findet dann vor Ort beim Arbeitgeber statt.</p>\n<p>Find more <a href="https://www.arbeitnow.com/english-speaking-jobs">English Speaking Jobs in Germany</a> on Arbeitnow</a>',
#    'remote': False,
#    'url': 'https://www.arbeitnow.com/jobs/companies/pav-christa-thielking/marketingassistentin-mit-weiteren-kaufmannischen-aufgaben-in-tz-freiburg-im-breisgau-45837',
#    'tags': ['Marketing Assistant'],
#    'job_types': ['berufserfahren'],
#    'location': 'Freiburg im Breisgau',
#    'created_at': 1765303314},
#   {'slug': 'werkstudent-marketing-heilbronn-35707',
#    'company_name': 'reo GmbH',
#    'title': 'Werkstudent (m/w/d) Marketing',
#    'description': '<p><strong>Gestalte die Zukunft der Kreislaufwirtschaft mit uns.</strong></p>\n<h2>Aufgaben</h2>\n<p><strong>Komplette eigenständige Erstellung unseres Social-Media-Contents</strong> (Posts, Reels, Stories, Layouts, Texte)</p>\n<p>Planung und Umsetzung des monatlichen Contentplans</p>\n<p>Gestaltung aller Inhalte in <strong>Canva</strong> (bzw. vergleichbaren Tools)</p>\n<p>Kontinuierliche Weiterentwicklung unserer visuellen Content-Sprache</p>\n<p>Community-Management: Antworten auf Nachrichten &#x26; Kommentare</p>\n<p>Trend-Research und kreative Weiterentwicklung unserer Kanäle</p>\n<p>Optional: Durchführung von kleinen Foto- und Videoshootingsg</p>\n<h2>Qualifikation</h2>\n<p>Eingeschriebene:r Student:in im Bereich Marketing, Medien, Kommunikation, Design o. Ä.</p>\n<p>Sehr gute <strong>Canva-Skills</strong> und ein starkes Gespür für Design, Ästhetik und visuelle Markenführung</p>\n<p>Erfahrung im Erstellen von Social-Media-Content (v. a. Instagram &#x26; TikTok)</p>\n<p>Kreative Ideen, hohe Eigenverantwortung und Lust, „Owner“ unserer Social-Media-Kanäle zu sein</p>\n<p>Zuverlässige, strukturierte Arbeitsweise</p>\n<p>Sehr gute Deutschkenntnisse</p>\n<p><strong>Wohnort bzw. regelmäßige Verfügbarkeit in München oder Heilbronn</strong></p>\n<h2>Benefits</h2>\n<p><strong>Was wir dir bieten</strong></p>\n<ul>\n<li><strong>Impact pur:</strong> Deine Arbeit zahlt direkt auf ein nachhaltigeres Wirtschaftssystem ein</li>\n<li><strong>Viel Verantwortung &#x26; echte Lernkurve</strong> – du bist Teil des Teams, nicht nur dabei</li>\n<li><strong>Modernes Arbeiten</strong> mit flexiblen Remote-Anteilen und Start-up-Mentalität</li>\n<li><strong>Netzwerkzugang</strong> in die Circular Economy, Kosmetikbranche und Start-up-Welt</li>\n</ul>\n<p>Bewirb Dich einfach mit einer knackigen Email "warum du Lust hast dabei zu sein ?"</p>\n<p>Find <a href="https://www.arbeitnow.com/">Jobs in Germany</a> on Arbeitnow</a>',
#    'remote': False,
#    'url': 'https://www.arbeitnow.com/jobs/companies/reo-gmbh/werkstudent-marketing-heilbronn-35707',
#    'tags': ['Marketing and Communication'],
#    'job_types': ['Working student'],
#    'location': 'Heilbronn',
#    'created_at': 1765303314},
#   {'slug': 'head-of-leiter-bess-batteriespeicher-agri-pv-munich-163065',
#    'company_name': 'feld.energy GmbH',
#    'title': 'Head of / Leiter BESS Batteriespeicher (m/w/d) Agri PV',
#    'description': '<h2>Über uns</h2>\n<p>Unser Ziel: Die Landwirtschaft in Europa resilient und zukunftssicher machen. Mit innovativen Agri-PV-Lösungen schaffen wir Flächen, die gleichzeitig Strom produzieren und Lebensmittel sichern.<br>\nUnser nächster Schritt: Der strategische Aufbau eines BESS-Bereichs (Battery Energy Storage Systems), um gemeinsam mit Landwirten und Energieversorgern Speicherkapazität für ein stabiles, dezentrales Energiesystem zu schaffen. Dafür suchen wir dich.</p>\n<h2>Deine Mission</h2>\n<p>Du baust den Bereich für Batteriespeicherlösungen (BESS) von Grund auf auf – strategisch, technisch und operativ. Gemeinsam mit dem Gründungsteam entwickelst du skalierbare Modelle für Speicherprojekte auf landwirtschaftlichen Flächen.</p>\n<h2>Deine Aufgaben</h2>\n<ul>\n<li>Strategie: Entwicklung der BESS-Vision &#x26; Roadmap in enger Abstimmung mit Gründern und Investoren</li>\n<li>Business Development: Identifikation und Bewertung geeigneter Standorte, Partnerschaften mit Herstellern, Aggregatoren und Direktvermarktern</li>\n<li>Projektentwicklung: Technische und wirtschaftliche Machbarkeitsanalysen, Integration mit Agri-PV und VPP</li>\n<li>Regulatorik &#x26; Marktanalyse: Beobachtung relevanter Gesetze, Förderprogramme und Ausschreibungen (z. B. §14a EnWG, Speicher im EEG, Strommarkt 2.0)</li>\n<li>Teamaufbau: Auswahl und Führung eines interdisziplinären Teams aus Technik, Operations und Finance</li>\n<li>Kommunikation: Interner Sparringspartner für Management &#x26; externe Schnittstelle zu Behörden, Netzbetreibern und Investoren</li>\n</ul>\n<h2>Dein Profil</h2>\n<ul>\n<li>Erfahrung im Aufbau von Energiespeicherprojekten</li>\n<li>Tiefe Kenntnisse im Bereich BESS, Strommarktdesign, Flexibilitätsvermarktung und Netzthemen</li>\n<li>Unternehmerisches Mindset und ausgeprägte Umsetzungsstärke</li>\n<li>Verständnis für technische Planung, Projektentwicklung und regulatorische Anforderungen</li>\n<li>Kommunikationsstärke in Deutsch &#x26; Englisch</li>\n<li>Hands-on-Mentalität und Lust, ein neues Geschäftsfeld in einem Startup mit aufzubauen</li>\n</ul>\n<h2>Warum wir?</h2>\n<ul>\n<li>Echte Anteile am Unternehmenserfolg durch Mitarbeiterbeteiligungen.</li>\n<li>Zusammenarbeit mit erfolgreichen Serienunternehmern und innovativen Experten.</li>\n<li>27 Tage für deine persönliche Erholung.</li>\n<li>Regelmäßige Team-Events und gemeinsame Feiern der Erfolge.</li>\n<li>Kostenlose Getränke und frisches Obst im Büro für deinen Energie-Boost.</li>\n<li>Neueste technische Ausstattung und innovative Software, die deinen Arbeitsalltag erleichtert.</li>\n<li>Top-Weiterbildungsmöglichkeiten im Bereich erneuerbare Energien und nachhaltige Geschäftsführung</li>\n<li>Eine Unternehmenskultur, die auf Nachhaltigkeit, Innovation und Zusammenarbeit setzt.</li>\n</ul>\n<p>Find more <a href="https://www.arbeitnow.com/english-speaking-jobs">English Speaking Jobs in Germany</a> on Arbeitnow</a>',
#    'remote': False,
#    'url': 'https://www.arbeitnow.com/jobs/companies/feldenergy-gmbh/head-of-leiter-bess-batteriespeicher-agri-pv-munich-163065',
#    'tags': ['Business Development'],
#    'job_types': ['berufserfahren'],
#    'location': 'Munich',
#    'created_at': 1765301515},
#   {'slug': 'customer-service-spezialist-berlin-171687',
#    'company_name': 'The Bike Club',
#    'title': 'Customer Service Spezialist',
#    'description': '<p><strong>Über Bike Club:</strong><br>\nBike Club ist ein Abo-Service für hochwertige Kinderfahrräder: Das Fahrrad wird einfach gegen ein größeres Modell eingetauscht, wenn das Kind wächst. So entsteht eine ressourcenschonende Kreislaufwirtschaft.</p>\n<p>Mit über 80.000 Fahrrädern sind wir weltweit das zweitgrößte Fahrradverleihnetzwerk, und das größte für Kinderfahrräder. Unser Ursprungsmarkt ist Großbritannien, aber mittlerweile sind wir auch in Deutschland und Österreich vertreten.</p>\n<p><strong>Zu deiner Rolle:</strong></p>\n<p>Bei Bike Club stehen unsere Mitglieder im Mittelpunkt unseres Handelns, und unser Kundenservice-Team ist entscheidend dafür, dass dies gelingt. Als Customer Service Specialist sorgst du dafür, dass unsere Community zufrieden bleibt, indem du einen herausragenden Service per E-Mail, Telefon und über soziale Medien bietest.</p>\n<p>Dein Arbeitsalltag kann alles beinhalten – von der Unterstützung von Eltern bei der Auswahl des richtigen Fahrrads bis hin zur Klärung von Fragen zu Lieferungen, Zahlungen oder Fahrradproblemen. Kein Tag ist wie der andere, und genau das mögen wir.</p>\n<p>Da wir ein internationales Team sind, kommunizieren wir intern oftmals auf Englisch. Bitte teile deinen Lebenslauf daher auf Englisch.</p>\n<h2>Aufgaben</h2>\n<ul>\n<li>Bearbeitung von Mitgliederanfragen über verschiedene Kanäle, darunter E-Mails, Telefon und soziale Medien.</li>\n<li>Aufbau eines fundierten Produktwissens über unser Fahrradsortiment, um unseren Mitgliedern eine individuelle Beratung und Empfehlungen bieten zu können.</li>\n<li>Als Stimme der Kunden auftreten, indem du Feedback sammelst und Erkenntnisse mit deinem Team teilst.</li>\n<li>Klar und effektiv kommunizieren, sodass Informationen stets verständlich und präzise vermittelt werden.</li>\n<li>Einen lösungsorientierten Ansatz zeigen, indem du Anliegen nach Möglichkeit bereits beim ersten Kontakt klärst.</li>\n</ul>\n<h2>Qualifikation</h2>\n<ul>\n<li>Echtes Interesse daran, den bestmöglichen Kundensupport zu bieten.</li>\n<li>Ausgezeichnete schriftliche und mündliche Kommunikationsfähigkeiten.</li>\n<li>Vorkenntnisse mit CRM-Tools, idealerweise Salesforce.</li>\n<li>Starke Problemlösungsfähigkeiten, kombiniert mit natürlicher Neugier und Lernbereitschaft.</li>\n<li>Ein hohes Maß an Empathie und die Bereitschaft, die Erwartungen der Kunden zu übertreffen.</li>\n<li>Du holst dir aktiv Feedback ein, um persönlich zu wachsen und dich weiterzuentwickeln.</li>\n<li>Du liebst die Dynamik eines Teamumfelds, arbeitest aber ebenso gut eigenständig.</li>\n<li>Du bleibst positiv, auch wenn es herausfordernd wird oder du unter Druck stehst.</li>\n<li>Ein zuverlässiger, organisierter und engagierter Teamplayer.</li>\n<li>Mindestens ein Jahr praktische Erfahrung in einer ähnlichen Kundenservice-Rolle.</li>\n<li>Fließendes Englisch</li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li>Übernahme von 100% der Kosten für das Deutschlandticket</li>\n<li>Familienfreundliches Unternehmen</li>\n<li>Hybridrolle mit drei Homeoffice-Tagen</li>\n<li>Zentrales Büro in Berlin Schöneberg</li>\n<li>Ein kleines, internationales Team mit großer Begeisterung für Bikes und Nachhaltigkeit</li>\n<li>Viel Entwicklungspotenzial</li>\n<li>Mitarbeiterrabatt auf unsere Abonnements</li>\n</ul>\n<p>Da wir ein internationales Team sind, kommunizieren wir intern oftmals auf Englisch. Bitte teile deinen Lebenslauf daher auf Englisch.</p>\n<p>Find <a href="https://www.arbeitnow.com/">Jobs in Germany</a> on Arbeitnow</a>',
#    'remote': False,
#    'url': 'https://www.arbeitnow.com/jobs/companies/the-bike-club/customer-service-spezialist-berlin-171687',
#    'tags': ['Customer Service'],
#    'job_types': ['berufseinstieg'],
#    'location': 'Berlin',
#    'created_at': 1765299729},
#   {'slug': 'head-of-controlling-nuremberg-299852',
#    'company_name': 'Schaffmann Consultants Executive Search',
#    'title': 'Head of Controlling (m/w/d)',
#    'description': '<p><strong>Eine Schlüsselrolle für Kandidat*innen, die gestalten wollen</strong></p>\n<p>Für ein dynamisches Handelsunternehmen suchen wir einen <strong>Head of Controlling (m/w/d)</strong>,</p>\n<p>der deutlich mehr macht als „nur Zahlen drehen“.</p>\n<p>Gesucht wird <strong>eine Persönlichkeit</strong>, die Controlling als Steuerungsinstrument versteht,</p>\n<p>Transparenz schafft und die Geschäftsführung strategisch begleitet.</p>\n<p>Diese Rolle ist ideal, wenn Sie eine analytische Stärke mit unternehmerischem Denken</p>\n<p>verbinden möchten– und den Anspruch haben, Strukturen nachhaltig zu prägen.</p>\n<p><strong>Die Rolle – worum es wirklich geht</strong></p>\n<p>In dieser Funktion verantworten Sie die Weiterentwicklung des gesamten Controllings</p>\n<p>inklusive Finanzsteuerung. Sie werden zum Sparringspartner auf Augenhöhe für die</p>\n<p>Geschäftsführung und gestalten aktiv die Zukunft des Unternehmens mit.</p>\n<h2>Aufgaben</h2>\n<p><strong>Was Sie inhaltlich erwarten können</strong></p>\n<p>• Weiterentwicklung des Controllings und der finanziellen Steuerungsmechanismen</p>\n<p>• Weiterentwicklung eines modernen, datenbasierten Reportings (inkl. Automatisierung</p>\n<p>&#x26; Dashboarding)</p>\n<p>• Analyse und Steuerung zentraler KPIs (Umsatz, Margen, Nachfrage etc.)</p>\n<p>• Ableitung klarer Handlungs-Empfehlungen für Geschäftsführung &#x26; Fachbereiche</p>\n<p>• Operative Verantwortung im Tagesgeschäft</p>\n<p>• Führung und Weiterentwicklung des bestehenden Teams</p>\n<h2>Qualifikation</h2>\n<p><strong>Fachlich</strong></p>\n<ul>\n<li>Mehrjährige Controlling-Erfahrung im B2C Bereich, idealerweise in einem</li>\n<li>Handelsunternehmen</li>\n<li>Sicherer Umgang mit KPIs und betriebswirtschaftlichen Zusammenhängen in einem</li>\n<li>Handelsunternehmen</li>\n<li>Ausgezeichnete analytische und konzeptionelle Fähigkeiten</li>\n<li>Sehr gute Excel- und Reporting-Skills</li>\n<li>Erfahrung in Prozessoptimierung und Automatisierung</li>\n<li>Klarer Führungsstil und Ownership-Mentalität</li>\n</ul>\n<p><strong>Persönlich</strong></p>\n<ul>\n<li>Begeisterung für Zahlen und echte Leidenschaft für Controlling</li>\n<li>Fähigkeit, Themen zu challengen und Klarheit zu schaffen</li>\n<li>Empathische, teamorientierte Arbeitsweise</li>\n<li>Proaktive, vorausschauende Haltung</li>\n<li>Hohe Belastbarkeit und strukturiertes Vorgehen</li>\n<li>Interesse an neuen Technologien (KI, Automatisierung etc.)</li>\n<li>Bereitschaft, Verantwortung zu übernehmen und die Extra-Meile zu gehen</li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li>Einen Top Arbeitgeber (Auch Kununu sieht es so)</li>\n<li>Work-Life-Balance</li>\n<li>Firmenfeiern und Aktivitäten</li>\n<li>Büro Hunde möglich</li>\n<li>Flexible Arbeitsplätze</li>\n<li>Fahrradleasing</li>\n<li>Zuschuss zum Deutschlandticket</li>\n<li>Massagen &#x26; Physiotherapie</li>\n</ul>\n<p>Wir freuen uns auf Ihre Bewerbung.</p>\n<p>Find <a href="https://www.arbeitnow.com/">Jobs in Germany</a> on Arbeitnow</a>',
#    'remote': False,
#    'url': 'https://www.arbeitnow.com/jobs/companies/schaffmann-consultants-executive-search/head-of-controlling-nuremberg-299852',
#    'tags': ['Controlling'],
#    'job_types': ['teamleitung'],
#    'location': 'Nuremberg',
#    'created_at': 1765297924},
#   {'slug': 'hr-business-partner-performance-management-vergutung-frankfurt-173807',
#    'company_name': 'HR-CONSULTANTS GmbH',
#    'title': 'HR Business Partner (m/w/d) Performance Management & Vergütung',
#    'description': '<p>Unser Kunde ist ein führendes mittelständisches Dienstleistungsunternehmen. Er ist Teil einer weltweit agierenden Gruppe und gehört damit zu den globalen Playern der Branche. Es erwartet Sie eine verantwortungsvolle und spannende Aufgabe in einem internationalen und dynamischen Arbeitsumfeld mit viel Gestaltungsspielraum.</p>\n<h2>Aufgaben</h2>\n<ul>\n<li>Systemische und analytische Betreuung der konzernweiten Performance-Management-Prozesse (Zielvereinbarungen, Beurteilungen)</li>\n<li>Weiterentwicklung und Umsetzung einer marktgerechten, strategiekonformen und mitarbeiterorientierten Vergütungssystematik</li>\n<li>Beratung der lokalen HR Business Partner zur Anwendung von SAP SuccessFactors und zum Ablauf der Performance-Prozesse</li>\n<li>Analyse und Reporting von Leistungsdaten zur Ableitung strategischer Entwicklungsmaßnahmen</li>\n<li>Koordination und Umsetzung von Gehaltsrunden und Bonusprozessen</li>\n<li>Durchführung von Marktanalysen und Benchmarking zur Sicherstellung wettbewerbsfähiger Vergütung</li>\n<li>Sicherstellung der Einhaltung interner Richtlinien und gesetzlicher Vorgaben (u. a.<br>\nEntgelttransparenz, Compliance, Audit-Vorbereitung)</li>\n</ul>\n<h2>Qualifikation</h2>\n<ul>\n<li>Abgeschlossenes Studium der Betriebswirtschaft, idealerweise mit Schwerpunkt Personal oder Finanzen</li>\n<li>Mindestens 5 Jahre Berufserfahrung im Bereich Compensation &#x26; Benefits oder<br>\nPerformance Management, bevorzugt im internationalen Umfeld</li>\n<li>Fundierte Kenntnisse in Vergütungssystemen, Grading-Modellen sowie Performance-Management-Prozessen</li>\n<li>Sehr gute arbeitsrechtliche Kenntnisse, insbesondere im Mitbestimmungsrecht</li>\n<li>Erfahrung im Umgang mit SAP SuccessFactors (insb. Compensation und Performance Module)</li>\n<li>Projektleitungserfahrung im Transformationskontext sowie hohe Teamorientierung und Beratungskompetenz</li>\n<li>Hohes Maß an Diskretion, Integrität und Kommunikationsstärke im Umgang mit sensiblen Daten und Führungskräften</li>\n<li>Verhandlungssichere Deutsch- und Englischkenntnisse</li>\n</ul>\n<p>Find <a href="https://www.arbeitnow.com/">Jobs in Germany</a> on Arbeitnow</a>',
#    'remote': False,
#    'url': 'https://www.arbeitnow.com/jobs/companies/hr-consultants-gmbh/hr-business-partner-performance-management-vergutung-frankfurt-173807',
#    'tags': ['Compensation and Benefits'],
#    'job_types': ['berufserfahren'],
#    'location': 'Frankfurt',
#    'created_at': 1765297923},
#   {'slug': 'senior-qa-engineer-test-automation-hamburg-961',
#    'company_name': 'bits&birds GmbH',
#    'title': 'Senior QA Engineer & Test Automation (m/w/d)',
#    'description': '<p>Wir suchen für ein Unternehmen in <strong>Lüneburg</strong> einen <strong>Senior QA Engineer &#x26; Test Automation (m/w/d)</strong>.</p>\n<p>Das Unternehmen entwickelt seit über 25 Jahren Softwarelösungen für Hochschulen, Unternehmen und Krankenhäuser. Die Tools sind etabliert, krisensicher und gleichzeitig offen für Innovation.</p>\n<p>Der QA-Bereich wächst zusammen, nachdem er bisher in Silos gearbeitet hat. Gesucht wird eine Persönlichkeit, die Struktur schafft, Teams verbindet und Testautomation als gemeinsamen Nenner etabliert. Das vierköpfige Team soll in eine neue Phase geführt werden – klare Prozesse, saubere Dokumentation und starkes Zusammenspiel über drei Produkte hinweg.</p>\n<h2>Aufgaben</h2>\n<ul>\n<li><strong>Ein Framework für Qualität</strong>: DoR/DoD, Testarten, Testumgebungen, Abnahme- und Release-Kriterien – alles in einer gemeinsamen Linie.</li>\n<li><strong>Testautomation weiterdenken</strong>: Cypress ausbauen, API-Tests stärken, CI/CD sauber verzahnen.</li>\n<li>Überblick behalten: Kapazitäten, Prioritäten und Produktbedarfe mit PO, Champion und Engineering Management abstimmen.</li>\n<li><strong>Qualität sichtbar machen:</strong> KPIs wie Lead Time to Fix, Escape Rate, Abdeckung oder Flakiness definieren und reporten.</li>\n<li><strong>Führung, die ankommt</strong>: Coaching, Entwicklung, Austausch – inklusive Recruiting-Impulsen und 1:1s</li>\n<li><strong>Enablement als Hebel</strong>: Guidelines, Reviews, Pairing-Sessions und Story-Checks für bessere Ergebnisse im gesamten Entwicklungsprozess.</li>\n<li><strong>Hands-on bleiben</strong>: Exploratives Testen, Testdesign, Ticketanalysen und Weiterentwicklung der automatisierten Suiten.</li>\n</ul>\n<h2>Qualifikation</h2>\n<ul>\n<li><strong>Quality Engineering</strong> ist dein Spielfeld: inklusive einem sicheren Blick für Teamdynamiken und optimalerweise Führungserfahrung.</li>\n<li><strong>Testautomation</strong> kannst du: UI, API, Integration und Cypress gern im Werkzeugkasten.</li>\n<li><strong>CI/CD, QA-Metriken</strong> und strukturiertes Arbeiten beherrschst du im Schlaf.</li>\n<li><strong>Kommunikation</strong>, die trägt: klar, direkt und das auf Deutsch und Englisch.</li>\n<li>Freude an standortübergreifender Zusammenarbeit.</li>\n<li>Bonus, aber kein Muss: ISTQB, Multi-Product-Erfahrung oder Know-how in Performance/Security/Accessibility.</li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li><strong>Flexibles Arbeiten</strong> – Remote in Deutschland, gelegentlich Reisen Absprache.</li>\n<li><strong>Zeit zum Auftanken</strong> – 30 Urlaubstage + ein halber Geburtstagstag.</li>\n<li><strong>Attraktives Gesamtpaket</strong> – inklusive Altersvorsorge und Gesundheitsförderung.</li>\n<li><strong>Mobil &#x26; entspannt</strong> – Jobrad, kostenlose Parkplätze, Office-Lieferungen ohne Wartezeit.</li>\n<li><strong>Weiterentwicklung</strong> – Trainings, Mentoring und eine strukturierte Einarbeitung.</li>\n<li><strong>Arbeitskultur</strong> – offene Atmosphäre, kurze Wege, Hund willkommen.</li>\n</ul>\n<p>Find more <a href="https://www.arbeitnow.com/english-speaking-jobs">English Speaking Jobs in Germany</a> on Arbeitnow</a>',
#    'remote': True,
#    'url': 'https://www.arbeitnow.com/jobs/companies/bitsbirds-gmbh/senior-qa-engineer-test-automation-hamburg-961',
#    'tags': ['Remote', 'Quality Assurance', 'Inspection'],
#    'job_types': ['berufserfahren'],
#    'location': 'Hamburg',
#    'created_at': 1765296118},
#   {'slug': 'controller-analytische-starke-trifft-operative-exzellenz-dresden-472246',
#    'company_name': 'Franke + Pahl GmbH',
#    'title': 'Controller (m/w/d) | Analytische Stärke trifft operative Exzellenz',
#    'description': '<p>Sie denken in Zusammenhängen, erkennen frühzeitig Trends und verstehen es, Komplexität in belastbare Entscheidungsgrundlagen zu übersetzen? Dann bietet diese Rolle Ihnen den passenden Wirkungsraum.</p>\n<p>Über die Position</p>\n<p>Im Auftrag eines etablierten, wachstumsorientierten Unternehmens im Großraum Hamburg suchen wir eine Persönlichkeit, die Controlling nicht als reine Zahlenarbeit begreift, sondern als strategischen Beitrag zur Unternehmenssteuerung.</p>\n<p>Unser Kunde legt Wert auf Transparenz, strukturiertes Arbeiten und einen professionellen Austausch auf Augenhöhe.</p>\n<h2>Aufgaben</h2>\n<ul>\n<li>Erstellung von Monats-, Quartals- und Jahresauswertungen inklusive Forecasts und Abweichungsanalysen</li>\n<li>Planung und Begleitung des Budgetierungsprozesses</li>\n<li>Aufbau und Weiterentwicklung von KPI-Systemen sowie Reportingstrukturen</li>\n<li>Durchdringen betriebswirtschaftlicher Fragestellungen und Ableitung konkreter Handlungsempfehlungen</li>\n<li>Enge Zusammenarbeit mit Fachbereichen zur Steuerung operativer und strategischer Zielgrößen</li>\n<li>Unterstützung von Digitalisierungsprojekten im Finanzbereich</li>\n</ul>\n<h2>Qualifikation</h2>\n<ul>\n<li>Abgeschlossenes Studium im Bereich Betriebswirtschaft, Controlling, Finance oder vergleichbar</li>\n<li>Solide Berufserfahrung im Controlling, idealerweise in einem mittelständischen oder produzierenden Umfeld</li>\n<li>Sehr gute Excel-Kenntnisse; Erfahrung mit BI-Tools oder ERP-Systemen von Vorteil</li>\n<li>Hohe analytische Kompetenz, strukturierte Arbeitsweise und ausgeprägtes Qualitätsbewusstsein</li>\n<li>Fähigkeit, komplexe Sachverhalte klar und adressatengerecht aufzubereiten</li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li>Ein wirtschaftlich stabiles Unternehmen mit klarer strategischer Ausrichtung</li>\n<li>Ein Umfeld, das Wert auf fundierte Analysen und professionelle Zusammenarbeit legt</li>\n<li>Flexible Arbeitszeitmodelle und die Möglichkeit für hybrides Arbeiten</li>\n<li>Weiterbildungsangebote im Bereich BI, Prozessoptimierung und Digitalisierung</li>\n<li>Attraktives Vergütungspaket und langfristige Entwicklungsperspektiven</li>\n</ul>\n<p>Warum diese Rolle?</p>\n<p>Weil Sie hier einen Bereich mitgestalten, statt nur Zahlen zu verwalten.</p>\n<p>Weil Ihre Analysen unmittelbare Wirkung entfalten.</p>\n<p>Weil Sie ein Umfeld vorfinden, das Präzision, Professionalität und Verlässlichkeit schätzt.</p>\n<p>Interesse geweckt?</p>\n<p>Dann freuen wir uns über Ihre Kontaktaufnahme.</p>\n<p>Wir suchen im Auftrag unseres Kunden und begleiten Sie vertraulich durch den gesamten Auswahlprozess.</p>\n<p>Find more <a href="https://www.arbeitnow.com/english-speaking-jobs">English Speaking Jobs in Germany</a> on Arbeitnow</a>',
#    'remote': False,
#    'url': 'https://www.arbeitnow.com/jobs/companies/franke-pahl-gmbh/controller-analytische-starke-trifft-operative-exzellenz-dresden-472246',
#    'tags': ['Controlling'],
#    'job_types': ['berufserfahren'],
#    'location': 'Dresden',
#    'created_at': 1765296117},
#   {'slug': 'ai-voice-copywriting-specialist-bremen-361711',
#    'company_name': 'Interlead GmbH',
#    'title': 'AI Voice & Copywriting Specialist (m/w/d)',
#    'description': '<p>Hi, wir von Interlead wollen bis Ende 2026 die #1 Lead Company im deutschsprachigen Raum aufgebaut haben. Damit lösen wir das größte Problem unserer Partner: Laufend neue Leads, Termine und Aufträge!</p>\n<p>Nicht nur das Thema Neukunden ist komplex. Unsere AI-Infrastruktur will ausgebaut und professionell erweitert werden.</p>\n<p>Zum nächstmöglichen Zeitpunkt suchen wir daher einen <strong>AI Voice &#x26; Copywriting Specialist (m/w/d)</strong> für unser Operations Team (hybrid/remote).</p>\n<h2>Aufgaben</h2>\n<p><strong>Skripting und Prompting</strong></p>\n<ul>\n<li>Sehr gutes <strong>Sprachgefühl</strong> und strukturiertes Schreiben (Deutsch; Englisch von Vorteil).</li>\n<li>Definition und Konstanthaltung von <strong>Tonalität und Verhaltensweise</strong>n.</li>\n</ul>\n<p><strong>Analyse &#x26; Optimierung:</strong></p>\n<ul>\n<li>Auswertung von <strong>Call-Logs, Transkripten und KPIs</strong> (z. B. Abbruchraten, Erfolgsquoten, Gesprächsdauer).</li>\n<li>Bildung von <strong>Hypothesen, Planung von A/B-Tests</strong> und Umsetzung iterativer Verbesserungen.</li>\n</ul>\n<p><strong>Qualitätsmanagement:</strong></p>\n<ul>\n<li><strong>Identifikation</strong> von Fehlerfällen (Missverständnisse, Eskalationen) und Entwicklung robuster Fallbacks.</li>\n<li>Dokumentation von <strong>Guidelines und Best Practices</strong>.</li>\n</ul>\n<p><strong>Zusammenarbeit:</strong></p>\n<ul>\n<li>Enge <strong>Abstimmung mit Vertrieb/Call Center/Business Unit Management</strong> (Controlling) für Produkt-Ziele, Angebots-Spezifika und Qualifizierungsmerkmale.</li>\n<li><strong>Schnittstelle zu IT/Tech</strong> (kein tiefes Coding nötig; jedoch die Bereitschaft, sich in Tools einzuarbeiten und täglich mit diesen zu beschäftigen).</li>\n</ul>\n<p><strong>Betrieb:</strong></p>\n<ul>\n<li>Rollout-Planung, Versionierung und <strong>Change-Management für Agent-Updates</strong>.</li>\n<li><strong>Monitoring und Alerting</strong> für kritische Metriken.</li>\n</ul>\n<h2>Qualifikation</h2>\n<p><strong>Must-haves:</strong></p>\n<ul>\n<li>Sehr gutes <strong>Sprachgefühl</strong> und strukturiertes Schreiben (Deutsch; Englisch von Vorteil).</li>\n<li>Analytische <strong>Denkweise</strong>, hohes <strong>Qualitätsbewusstsein</strong> und <strong>Detailtreue</strong>.</li>\n<li>Technische <strong>Neugier und Tool-Affinität</strong> (z. B. Arbeit mit Telli, Prompting, einfache Logiken/Flows).</li>\n<li>Erfahrung im <strong>Copywriting, Content und/oder Prompting</strong> - idealerweise mit Voice Agents.</li>\n</ul>\n<p><strong>Nice-to-haves:</strong></p>\n<ul>\n<li>Umgang mit <strong>KPIs/Dashboards</strong>, A/B-Testing und Hypothesen-getriebener Optimierung.</li>\n<li>Erfahrung mit <strong>Callcenter-/Sales-Prozessen</strong>.</li>\n<li>Grundverständnis von <strong>Datenstrukturen/Regeln</strong> (wenn-dann-Logik, Variablen, Tags).</li>\n</ul>\n<p><strong>Mindset:</strong></p>\n<ul>\n<li><strong>Ownership</strong>, pragmatisch, experimentierfreudig.</li>\n<li><strong>Teamplayer</strong> mit klarer Kommunikation und Spaß an iterativer Verbesserung.</li>\n</ul>\n<h2>Benefits</h2>\n<p>Diese Stelle kann zu <strong>100% im Home Office</strong> erledigt werden (d.h. freie Wahl, ob Office oder Home Office)</p>\n<ul>\n<li>Ein <strong>dynamisches Marketing- und Tech-Umfeld</strong> und die Möglichkeit, zusammen “The Lead Company” zu bauen</li>\n<li>Ein riesiger Markt und viele interne <strong>Wachstumsmöglichkeiten</strong>, da wir das größte Problem unserer Partner lösen: Wir automatisieren die Neukundengewinnung</li>\n<li>Volle <strong>Flexibilität im Arbeitsort</strong> (arbeite je nach Position entweder remote oder aus unserem Headquarter in der Bremer Überseestadt, auch Arbeiten aus dem Ausland ist nach Absprache möglich)</li>\n<li>Volle <strong>Flexibilität in der Arbeitszeit</strong> (die du individuell mit deinem Team besprichst)</li>\n<li><strong>30 Tage Urlaub</strong> im Jahr und jederzeit die Möglichkeit, unbezahlt Urlaub zu n ...
#    'remote': True,
#    'url': 'https://www.arbeitnow.com/jobs/companies/interlead-gmbh/ai-voice-copywriting-specialist-bremen-361711',
#    'tags': ['Remote', 'IT'],
#    'job_types': ['berufserfahren'],
#    'location': 'Bremen',
#    'created_at': 1765296116},
#   {'slug': 'linux-systemadministratorin-kiel-160964',
#    'company_name': 'Franke + Pahl GmbH',
#    'title': 'Linux - Systemadministrator:in',
#    'description': '<p>Im Auftrag eines technischen Systemhauses mit Schwerpunkt auf Systementwicklung, technischer Dokumentation und logistischem Datenmanagement suchen wir eine erfahrene Persönlichkeit im Bereich Linux-Systemadministration. Unser Mandant ist ein etabliertes, wachsendes Unternehmen mit langfristiger Perspektive, das anspruchsvolle Projekte für Industrie- und Behördenkunden realisiert. Aufgrund der sensiblen Themenstellung ist die Tätigkeit vor Ort am Standort Kiel vorgesehen. Wenn Sie Freude an anspruchsvollen IT-Umgebungen haben und Verantwortung übernehmen möchten, erwartet Sie hier eine sichere und zukunftsorientierte Aufgabe.</p>\n<h2>Aufgaben</h2>\n<ul>\n<li>Administration, Wartung und Optimierung von Red Hat Enterprise Linux Systemen</li>\n<li>Sicherstellung von Datenintegrität, -sicherheit und -verfügbarkeit durch geeignete Maßnahmen und Monitoring</li>\n<li>Verwaltung und Pflege der Virtualisierungsumgebung</li>\n<li>Performance-Analyse, Fehlerdiagnose und -behebung</li>\n<li>Erstellung und Pflege technischer Dokumentationen sowie Backup- und Recoverystrategien</li>\n</ul>\n<h2>Qualifikation</h2>\n<ul>\n<li>Abgeschlossenes Studium der Informatik oder Ausbildung im IT-Bereich</li>\n<li>Mehrjährige Erfahrung in der Administration von Linux-Systemen, idealerweise im Enterprise-Umfeld</li>\n<li>Gute Kenntnisse in Virtualisierung, Netzwerkgrundlagen und IT-Security</li>\n<li>Strukturierte, lösungsorientierte Arbeitsweise und Freude an neuen Technologien</li>\n<li>Sehr gute Deutsch- und gute Englischkenntnisse in Wort und Schrift</li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li>Unbefristete Festanstellung in einem stabilen, wachsenden Unternehmen mit hervorragender Zukunftsperspektive</li>\n<li>Kollegiales Team mit offener, wertschätzender Arbeitskultur</li>\n<li>Flexible Gleitzeitregelung und bis zu zwei Tage mobiles Arbeiten pro Woche</li>\n<li>30 Tage Urlaub, Urlaubs- und Weihnachtsgeld</li>\n<li>Individuelle Fort- und Weiterbildungsmöglichkeiten</li>\n<li>Betriebliche Altersvorsorge, vermögenswirksame Leistungen und Bike-Leasing</li>\n<li>Ergonomische Arbeitsplätze und Firmenfitness-Angebote</li>\n<li>Flache Hierarchien und kurze Entscheidungswege</li>\n</ul>\n<p>Vertragsart: Vollzeit, unbefristet</p>\n<p>Wir freuen uns auf Ihre Bewerbung und ein erstes persönliches Kennenlernen. Bitte senden Sie uns Ihre Unterlagen ganz einfach über das Bewerbungsformular oder nehmen Sie bei Fragen vorab Kontakt mit uns auf – wir melden uns zeitnah bei Ihnen.</p>\n<p>Sascha Pascal Sternheimer | Leiter technische Personalvermittlung<br>\nFranke + Pahl GmbH | Berzeliusstrasse 87 | 22113 Hamburg</p>\n<p>Find <a href="https://www.arbeitnow.com/">Jobs in Germany</a> on Arbeitnow</a>',
#    'remote': False,
#    'url': 'https://www.arbeitnow.com/jobs/companies/franke-pahl-gmbh/linux-systemadministratorin-kiel-160964',
#    'tags': ['System and Network Administration'],
#    'job_types': ['berufserfahren'],
#    'location': 'Kiel',
#    'created_at': 1765296116},
#   {'slug': 'video-creator-hamburg-285673',
#    'company_name': 'Emotion Home GmbH',
#    'title': 'Video Creator (m/w/d)',
#    'description': '<p>Emotion Home ist ein modernes Immobilienunternehmen, spezialisiert auf hochwertige Immobilienvermarktung, Projektentwicklung und Neubau.</p>\n<p>Wir wachsen stark – und suchen eine kreative Person, die unsere Marke mit aufgebauten Bildern &#x26; Videos sichtbar macht und unseren visuellen Auftritt auf das nächste Level hebt.</p>\n<p>Wir möchten Menschen emotional abholen – durch eindrucksvolle Bildsprache, packendes Storytelling und starke, innovative Video-Formate, die begeistern.</p>\n<h2>Aufgaben</h2>\n<p>Du begleitest uns bei Terminen, Objektbegehungen, Baustellen und im Daily Business – und setzt daraus spannenden Content um:</p>\n<p><strong>Deine Aufgaben</strong></p>\n<ul>\n<li>Dreh von Immobilienvideos, Kurzclips, Social-Media-Reels &#x26; Interviews</li>\n<li>Kreative Begleitung bei Objekt-Terminen &#x26; Baustellen</li>\n<li>Planung und Entwicklung neuer Video-Formate</li>\n<li>Schnitt &#x26; Post-Production (Premiere, Final Cut, DaVinci o. Ä.)</li>\n<li>Erstellung von Storytelling-Reels, Brand-Videos &#x26; Behind-the-Scenes</li>\n<li>Kontinuierliche Content-Produktion für Instagram, TikTok &#x26; YouTube</li>\n</ul>\n<h2>Qualifikation</h2>\n<p><strong>Was du mitbringen solltest</strong></p>\n<ul>\n<li>Leidenschaft für Kameraarbeit, Storytelling &#x26; Social Media</li>\n<li>Erfahrung im Filmen &#x26; Schneiden von Videos (Hobby oder professionell)</li>\n<li>Kreative Ideen, modernes Auge für Design &#x26; Bildsprache</li>\n<li>Lust, ein wachsendes Immobilienunternehmen aktiv mitzugestalten</li>\n<li>Selbstständiges &#x26; zuverlässiges Arbeiten</li>\n<li>Flexibilität – wir drehen oft spontan und projektbezogen</li>\n</ul>\n<h2>Benefits</h2>\n<p><strong>Was dich erwartet</strong></p>\n<ul>\n<li>Mitarbeit in einem jungen, ambitionierten und wachsenden Unternehmen</li>\n<li>Flexible Zeiten, perfekt für Studium oder Nebentätigkeit</li>\n<li>Kreative Freiheit &#x26; viel Platz für eigene Ideen</li>\n<li>Ein professionelles Umfeld in der Immobilienbranche</li>\n<li>Viele unterschiedliche Motive: Luxuswohnungen, Mehrfamilienhäuser, Sanierungen, Teamaktivitäten, Marketingkampagnen</li>\n<li>Gute Bezahlung (je nach Erfahrung)</li>\n</ul>\n<p>Bereichern Sie Emotion Home als Kameramann/Kamerafrau &#x26; Video Creator (m/w/d) und entfalten Sie Ihre Kreativität in einem innovativen, wachstumsorientierten Umfeld, das Immobiliengeschäfte neu definiert.</p>\n<p>Egal wie alt als Nebenjob, Minijob, in Teilzeit oder als Werkstudium.</p>\n<p>Find <a href="https://www.arbeitnow.com/">Jobs in Germany</a> on Arbeitnow</a>',
#    'remote': False,
#    'url': 'https://www.arbeitnow.com/jobs/companies/emotion-home-gmbh/video-creator-hamburg-285673',
#    'tags': ['Social Media Manager'],
#    'job_types': ['Side', 'berufserfahren'],
#    'location': 'Hamburg',
#    'created_at': 1765296112},
#   {'slug': 'teamlead-creative-team-all-genders-karlsruhe-80877',
#    'company_name': 'Starface GmbH',
#    'title': 'Teamlead Creative Team (all genders)',
# ...
#    'remote': False,
#    'url': 'https://www.arbeitnow.com/jobs/companies/rugamer-steiner-consulting-gmbh/marketing-manager-qa-dusseldorf-206383',
#    'tags': ['Marketing Manager'],
#    'job_types': ['berufseinstieg'],
#    'location': 'Düsseldorf',
#    'created_at': 1765278116},
#   {'slug': 'head-of-leiter-bess-batteriespeicher-agri-pv-weissenburg-in-bayern-256345',
#    'company_name': 'feld.energy GmbH',
#    'title': 'Head of / Leiter BESS Batteriespeicher (m/w/d) Agri PV',
#    'description': '<h2>Über uns</h2>\n<p>Unser Ziel: Die Landwirtschaft in Europa resilient und zukunftssicher machen. Mit innovativen Agri-PV-Lösungen schaffen wir Flächen, die gleichzeitig Strom produzieren und Lebensmittel sichern.<br>\nUnser nächster Schritt: Der strategische Aufbau eines BESS-Bereichs (Battery Energy Storage Systems), um gemeinsam mit Landwirten und Energieversorgern Speicherkapazität für ein stabiles, dezentrales Energiesystem zu schaffen. Dafür suchen wir dich.</p>\n<h2>Deine Mission</h2>\n<p>Du baust den Bereich für Batteriespeicherlösungen (BESS) von Grund auf auf – strategisch, technisch und operativ. Gemeinsam mit dem Gründungsteam entwickelst du skalierbare Modelle für Speicherprojekte auf landwirtschaftlichen Flächen.</p>\n<h2>Deine Aufgaben</h2>\n<ul>\n<li>Strategie: Entwicklung der BESS-Vision &#x26; Roadmap in enger Abstimmung mit Gründern und Investoren</li>\n<li>Business Development: Identifikation und Bewertung geeigneter Standorte, Partnerschaften mit Herstellern, Aggregatoren und Direktvermarktern</li>\n<li>Projektentwicklung: Technische und wirtschaftliche Machbarkeitsanalysen, Integration mit Agri-PV und VPP</li>\n<li>Regulatorik &#x26; Marktanalyse: Beobachtung relevanter Gesetze, Förderprogramme und Ausschreibungen (z. B. §14a EnWG, Speicher im EEG, Strommarkt 2.0)</li>\n<li>Teamaufbau: Auswahl und Führung eines interdisziplinären Teams aus Technik, Operations und Finance</li>\n<li>Kommunikation: Interner Sparringspartner für Management &#x26; externe Schnittstelle zu Behörden, Netzbetreibern und Investoren</li>\n</ul>\n<h2>Dein Profil</h2>\n<ul>\n<li>Erfahrung im Aufbau von Energiespeicherprojekten</li>\n<li>Tiefe Kenntnisse im Bereich BESS, Strommarktdesign, Flexibilitätsvermarktung und Netzthemen</li>\n<li>Unternehmerisches Mindset und ausgeprägte Umsetzungsstärke</li>\n<li>Verständnis für technische Planung, Projektentwicklung und regulatorische Anforderungen</li>\n<li>Kommunikationsstärke in Deutsch &#x26; Englisch</li>\n<li>Hands-on-Mentalität und Lust, ein neues Geschäftsfeld in einem Startup mit aufzubauen</li>\n</ul>\n<h2>Warum wir?</h2>\n<ul>\n<li>Echte Anteile am Unternehmenserfolg durch Mitarbeiterbeteiligungen.</li>\n<li>Zusammenarbeit mit erfolgreichen Serienunternehmern und innovativen Experten.</li>\n<li>27 Tage für deine persönliche Erholung.</li>\n<li>Regelmäßige Team-Events und gemeinsame Feiern der Erfolge.</li>\n<li>Kostenlose Getränke und frisches Obst im Büro für deinen Energie-Boost.</li>\n<li>Neueste technische Ausstattung und innovative Software, die deinen Arbeitsalltag erleichtert.</li>\n<li>Top-Weiterbildungsmöglichkeiten im Bereich erneuerbare Energien und nachhaltige Geschäftsführung</li>\n<li>Eine Unternehmenskultur, die auf Nachhaltigkeit, Innovation und Zusammenarbeit setzt.</li>\n</ul>\n<p>Find more <a href="https://www.arbeitnow.com/english-speaking-jobs">English Speaking Jobs in Germany</a> on Arbeitnow</a>',
#    'remote': False,
#    'url': 'https://www.arbeitnow.com/jobs/companies/feldenergy-gmbh/head-of-leiter-bess-batteriespeicher-agri-pv-weissenburg-in-bayern-256345',
#    'tags': ['Business Development'],
#    'job_types': ['berufserfahren'],
#    'location': 'Weissenburg in Bayern',
#    'created_at': 1765278113},
#   {'slug': 'social-media-grafikerin-gn-berlin-295570',
#    'company_name': 'Intermate Media GmbH',
#    'title': 'Social Media Grafiker:in (gn)',
#    'description': '<h2>Jobbeschreibung</h2>\n<h2>Intermate x SAMY – Shaping the State of Social</h2>\n<p>Intermate gehört zu den größten Social-Media- und Influencer-Agenturen im DACH-Raum. Mit mehr als 250 Mates in Berlin, Hamburg, Köln und Remote entwickeln wir Social-First-Strategien, produzieren Content in eigenen Studios, arbeiten eng mit Creator:innen zusammen und steuern Kampagnen datengetrieben über unsere eigene Technologie. Unsere Kund:innen sind einige der bekanntesten Marken der Welt – von Lifestyle über FMCG bis hin zu Tech.</p>\n<p>Als Teil von SAMY, einem globalen Agenturnetzwerk für Social Media und Creator Marketing, sind wir mit über 970 Expert:innen an 20 Standorten vernetzt. Das eröffnet internationale Perspektiven, Projekte in rund 55 Märkten und die Möglichkeit, dich weit über Ländergrenzen hinweg weiterzuentwickeln.</p>\n<p>💡 👉 Hinweis: Unser Bewerbungsprozess wird teilweise von einem KI-gestützten Assistenten begleitet, der das erste Kennenlerngespräch führt. Weitere Informationen erhältst du im Verlauf deiner Bewerbung.</p>\n<h2>WAS DU MACHST</h2>\n<ul>\n<li>Du gestaltest und schneidest Content für verschiedene Marken auf Basis von Storyboards zu Social Media Video-Ads</li>\n<li>Du bist selbst auf TikTok und Instagram und gibst proaktiv Input zu Trends und Neuigkeiten in den Kanälen</li>\n<li>Du arbeitest eng mit deinen Kolleg:innen aus unseren Performance**-<strong>, Media</strong>-** und UGC-Services zusammen und kommunizierst proaktiv innerhalb der Teams</li>\n<li>Als Teil des Visual Content Teams entwickelst du unser Leistungsportfolio weiter</li>\n<li>Du unterstützt unser Marketing Team mit aktuellem Content</li>\n<li>Gegebenenfalls entwickelst und gestaltest kreative Assets in Videoform für Paid Social Kampagnen</li>\n</ul>\n<h2>Stellenanforderungen</h2>\n<h2>WAS DU BRAUCHST</h2>\n<ul>\n<li>Du hast ein abgeschlossenes Studium oder eine Ausbildung im Bereich Grafikdesign, Kommunikationsdesign, Mediendesign oder eine vergleichbare Qualifikation</li>\n<li>Du konntest bereits 2 Jahre Erfahrung in der Produktion sowie der Gestaltung und im Editing von Social Media Content sammeln</li>\n<li>Du verfügst über erste Erfahrungen im Online-Marketing, optimalerweise bringst du Basiswissen im Performance Marketing mit</li>\n<li>Du kannst gut mit Bildern Geschichten erzählen, hast einen Sinn für Spannung und Ästhetik</li>\n<li>Du hast ein gutes Auge für Ästhetik, Typografie und plattformgerechte Gestaltung</li>\n<li>Du bist Social Media Native und hast ein gutes Gespür für Trends</li>\n<li>Du kennst dich bestens mit der Adobe Creative Suite (Photoshop, Illustrator, After Effects, Premiere Pro) aus – idealerweise auch mit Tools wie Figma oder Canva</li>\n<li>Du arbeitest strukturiert und selbstverantwortlich , findest dich in Tools, Prozessen und Methoden gut zurecht</li>\n<li>Du bist fähig unter Zeitdruck präzise, zuverlässig und ergebnisorientiert zu arbeiten</li>\n<li>Sehr gute Deutsch- und Englischkenntnisse in Wort und Schrift runden dein Profil ab</li>\n</ul>\n<h2></h2>\n<h2>WAS WIR DIR BIETEN</h2>\n<ul>\n<li><strong>Onboarding &#x26; Support</strong><br>\nNo one likes to be the new kid. Mit strukturiertem Onboarding, einem persönlichen Mate und Zugang zu Lernmaterialien bist du ab Tag eine:r von uns.</li>\n<li><strong>Erstklassige Ausstattung</strong><br>\nCan’t work without my iPhone. Mit MacBook, iPhone und aktueller Apple-Tech arbeitest du flexibel und effizient. Das gilt für unsere Altbau-Offices genauso wie zuhause oder unterwegs.</li>\n<li><strong>Wachstum &#x26; Weiterentwicklung</strong><br>\nRise &#x26; shine, darling! Dein jährliches Weiterbildungsbudget gibt dir die Freiheit, in Workshops, Seminare, zertifizierte Kurse oder Coachings zu investieren. So entwickelst du dich genau in die Richtung, die zu deinen Zielen passt.</li>\n<li><strong>Flexibel arbeiten</strong><br>\n„Ob das bei euch gerade genauso ist? I doubt it!” Bis zu sechs Wochen im Jahr kannst du innerhalb der EU remote arbeiten. Un ...
#    'remote': False,
#    'url': 'https://www.arbeitnow.com/jobs/companies/intermate-media-gmbh/social-media-grafikerin-gn-berlin-295570',
#    'tags': ['Marketing and Communication'],
#    'job_types': ['berufserfahren'],
#    'location': 'Berlin',
#    'created_at': 1765278113},
#   {'slug': 'terminal-engineer-lng-terminal-wilhelmshaven-486151',
#    'company_name': 'Gasfin',
#    'title': 'Terminal Engineer (m/w/d) / LNG Terminal Wilhelmshaven',
#    'description': '<p>Gasfin is where engineering meets impact. Since 2009, we’ve been building and managing world-class LNG infrastructure projects across the globe—from the drawing board to real-world delivery. Our clients include governments, energy companies, and infrastructure operators, all working toward the same goal: secure, stable, and sustainable energy.<br>\nIn 2023, we became the lead consultant and On-Site Operations Manager for Deutsche Energy Terminal GmbH (DET)—Germany’s state-owned terminal operator, created to respond to the national energy supply challenges triggered by the Ukraine crisis.<br>\nWe believe energy should be reliable, affordable, and future-ready. That’s why we view LNG as a powerful transition fuel on the path to greener energy systems.</p>\n<h2>Aufgaben</h2>\n<ul>\n<li>Supporting the Terminal Manager in the safe, reliable and efficient operation of the LNG terminal</li>\n<li>Planning and implementing the integrated operation and maintenance plan for the terminal</li>\n<li>Coordinating daily work processes at the terminal (including permit-to-work, maintenance and external services)</li>\n<li>Acting as an interface for internal departments and operational partners</li>\n<li>Ensuring compliance with all safety, emergency and environmental requirements as well as legal regulations</li>\n<li>Conducting audits, inspections and safety inspections and assisting in the investigation of incidents</li>\n<li>Representing the Terminal Manager during his/her absence</li>\n<li>Preparation of reports and technical document management</li>\n</ul>\n<h2>Qualifikation</h2>\n<ul>\n<li>Degree in process engineering, chemical engineering, industrial engineering or similar</li>\n<li>At least 3 years of experience in terminal operations or 5 years in the chemical/energy-related process industry</li>\n<li>In-depth knowledge of process safety – ideally in the field of LNG or natural gas</li>\n<li>Experience with safety and quality management systems (e.g. ISO, IMO, SIGTTO)</li>\n<li>Knowledge of project management is an advantage</li>\n<li>Strong problem-solving and communication skills</li>\n<li>Confident use of MS Office</li>\n<li>Very good written and spoken German and English</li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li>The opportunity to play an active role in shaping the operation of a pioneering LNG terminal</li>\n<li>Responsible tasks in a technically demanding environment</li>\n<li>A dedicated team with open communication and flat hierarchies</li>\n<li>Competitive compensation and long-term development opportunities</li>\n</ul>\n<p>We are looking forward to your applycation, even if you might not fulfill all requirements.</p>\n<p>Find more <a href="https://www.arbeitnow.com/english-speaking-jobs">English Speaking Jobs in Germany</a> on Arbeitnow</a>',
#    'remote': False,
#    'url': 'https://www.arbeitnow.com/jobs/companies/gasfin/terminal-engineer-lng-terminal-wilhelmshaven-486151',
#    'tags': ['Power Engineering and Environmental Engineering'],
#    'job_types': [],
#    'location': 'Wilhelmshaven',
#    'created_at': 1765276339},
#   {'slug': 'qlik-senior-bi-consultant-in-karlsruhe-hybrid-71902',
#    'company_name': 'iodata GmbH',
#    'title': 'Qlik Senior BI-Consultant (m/w/d) in Karlsruhe (Hybrid)',
#    'description': '<p><strong>Dein Start bei uns...</strong></p>\n<p>Zusammen mit unseren Kunden erarbeitest Du als Qlik Senior<br>\nBI-Consultant die Prioritäten und Anwendungsfälle für digitale<br>\nTransformation, Datenintegration und -harmonisierung sowie Analytics.</p>\n<h2>Aufgaben</h2>\n<p><strong>Deine Aufgaben</strong></p>\n<ul>\n<li>Du übernimmst eigenverantwortlich die Umsetzung von Kundenprojekten im Bereich Data-Analytics mit Qlik.</li>\n<li>Du arbeitest eng mit unseren Kunden zusammen, um ihre individuellen<br>\nAnforderungen zu verstehen und maßgeschneiderte Lösungen zu entwickeln.</li>\n<li>Du erstellst Datenmodelle, analysierst und visualisierst Daten, um aussagekräftige Dashboards und Apps zu erstellen.</li>\n<li>Du kümmerst Dich um die Wartung, Betreuung und Administration von<br>\nKundensystemen auf Basis von Qlik, einschließlich Installation und<br>\nUpgrades.</li>\n<li>Du beantwortest und löst Kundenanfragen über unser Support Center und sorgst für einen reibungslosen Ablauf.</li>\n<li>Du führst Schulungen für unsere Kunden durch und unterstützt bei Presales-Aktivitäten.</li>\n</ul>\n<h2>Qualifikation</h2>\n<p><strong>Um in dieser Rolle erfolgreich zu sein, bringst Du folgende Fähigkeiten und Erfahrungen mit:</strong></p>\n<ul>\n<li>Du hast eine abgeschlossene informationstechnische<br>\n(betriebswirtschaftliche) Ausbildung oder ein abgeschlossenes Studium in<br>\ndiesem Bereich. Außerdem verfügst du mindestens 3-5 Jahre Erfahrung im<br>\nBereich Analytics / Business Intelligence.</li>\n<li>Du begeisterst Dich für Zahlen, Daten, Analyse und Visualisierung.</li>\n<li>Du hast Erfahrung im Qlik-Produktportfolio (Qlik Sense, Qlik Saas, QlikView, NPrinting).</li>\n<li>Sichere Deutsch- und Englischkenntnisse</li>\n<li>Generelle Reisebereitschaft (50%)</li>\n<li>Hohe Eigenmotivation und Interesse an wechselnden Herausforderungen</li>\n<li>Datenbankkenntnisse (MS SQL Server, Azure, AWS, Oracle) sind von Vorteil.</li>\n<li>IT-Kenntnisse (Netzwerke, Entra, Ports, Zertifikate) sind von Vorteil.</li>\n<li>Kenntnisse eines Business Intelligence-Tools wie Qlik, Power BI oder Tableau sind von Vorteil.</li>\n<li>Erfahrung als Consultant zum Beispiel in der Strategie und Prozessberatung sind von Vorteil.</li>\n</ul>\n<h2>Benefits</h2>\n<p><strong>Wir bieten</strong></p>\n<ul>\n<li>Unbefristete Festanstellung und attraktives Vergütungsmodell</li>\n<li>Selbständiges, eigenverantwortliches Arbeiten</li>\n<li>Spannende Projekte und interessante Entwicklungsmöglichkeiten</li>\n<li>Zahlreiche Benefits (JobRad, Flex-Work, etc.)</li>\n<li>Angenehmes Unternehmensklima, nette Kolleg:innen und flache Führungsstrukturen</li>\n<li>Mitgestaltung einer dynamisch wachsenden Organisation</li>\n</ul>\n<p>Gestalte mit uns die datengetriebene Zukunft im Mittelstand als Qlik Senior BI-Consultant (m/w/d) in Karlsruhe. Bringe Deine Expertise ein und erziele messbare Erfolge mit iodata!</p>\n<p>Find <a href="https://www.arbeitnow.com/">Jobs in Germany</a> on Arbeitnow</a>',
#    'remote': False,
#    'url': 'https://www.arbeitnow.com/jobs/companies/iodata-gmbh/qlik-senior-bi-consultant-in-karlsruhe-hybrid-71902',
#    'tags': ['Data Scientist'],
#    'job_types': ['berufserfahren'],
#    'location': 'Karlsruhe',
#    'created_at': 1765276338}],
#  'links': {'first': 'https://www.arbeitnow.com/api/job-board-api?search=Graphics%20Designs%20Creativity%20Art&page=1',
#   'last': None,
#   'prev': None,
#   'next': 'https://www.arbeitnow.com/api/job-board-api?search=Graphics%20Designs%20Creativity%20Art&page=2'},
#  'meta': {'current_page': 1,
#   'current_page_url': 'https://www.arbeitnow.com/api/job-board-api?search=Graphics%20Designs%20Creativity%20Art&page=1',
#   'from': 1,
#   'path': 'https://www.arbeitnow.com/api/job-board-api',
#   'per_page': 100,
#   'to': 100,
#   'terms': 'This is a free public API for jobs, please do not abuse. I would appreciate linking back to the site. By using the API, you agree to the terms of service present on Arbeitnow.com',
#   'info': 'Jobs are updated every hour and order by the `created_at` timestamp. Use `?page=` to paginate. Read more information here: https://www.arbeitnow.com/blog/job-board-api'}}

# %% [markdown]
# El método json nos devuelve un diccionario

# %%
type(x.json())
# Out:
# dict

# %% [markdown]
# Así que podremos usar los métodos de los diccionarios para manipular los datos:

# %%
x.json().keys()
# Out:
# dict_keys(['data', 'links', 'meta'])

# %%
x.json()["data"][0]
# Out:
# {'slug': 'buchhalter-teilzeit-gross-gerau-414464',
#  'company_name': 'Jakob Winter GmbH',
#  'title': 'Buchhalter - Teilzeit (m/w/d)',
#  'description': '<p>Als Unternehmen machen wir vieles, aber alles dreht sich um das Thema Koffer und Formteile. Wir arbeiten für weltweit erfolgreiche Marken und agieren für diese als Produktionspartner. Zudem entwickeln wir auch unsere eigenen Marken und vertreiben diese über Händler oder im Direct-to-Consumer eCommerce. Das geschieht alles unter unserem Motto „Manufacturing Brands“.</p>\n<p>Unsere Unternehmensbereiche sind so abwechslungsreich wie wir selbst und alle Fachabteilungen arbeiten Hand in Hand zusammen. Unser super nettes und internationales Team arbeitet über unsere beiden Standorte Marienberg und Groß-Gerau eng zusammen. Du wirst Teil eines wachsenden Umfelds sein und hast die Chance, durch Eigeninitiative und Motivation unsere Zukunft mitzugestalten. Bist du dabei?</p>\n<h2>Aufgaben</h2>\n<ul>\n<li>Debitoren &#x26; Kreditorenbuchhaltung</li>\n<li>Abwicklung und Betreuung laufender Geschäftsvorfälle</li>\n<li>Vorbereitung der Lohnbuchhaltung</li>\n<li>Verwaltung des Zahlungsverkehrs und des Abrechnungswesens</li>\n<li>Erstellung von Meldungen und Statistiken an verschiedene externe Institutionen</li>\n<li>Kontakt mit Steuerbüro</li>\n</ul>\n<h2>Qualifikation</h2>\n<ul>\n<li>Du bist ein absoluter Self-Starter. Du siehst deine Motivation in eigenständigen Arbeiten sodass du Dinge wirklich bewegen kannst. Du liebst es Ideen zu entwickeln und diese einfach mal auszuprobieren</li>\n<li>Wir sind ein mittelständiges Unternehmen und bei uns zählt jeder Mitarbeiter. Du arbeitest zu bewegen und uns voranzubringen. Du arbeitest zudem sehr sorgfältig und zuverlässig.</li>\n</ul>\n<p>Außerdem sind noch folgende Qualifikationen hilfreich:</p>\n<ul>\n<li>Studium oder abgeschlossene kfm. Ausbildung mit dem Schwerpunkt Finanzen/ Rechnungswesen bzw. Steuerfachangestellte/r</li>\n<li>Einschlägige, mehrjährige Erfahrung im Rechnungswesen</li>\n<li>Professioneller Umgang mit den MS-Office-Produkten und einem ERP-Programm</li>\n<li>Sehr gute Deutsch- und gute Englischkenntnisse in Wort und Schrift</li>\n<li>Eigenständige Arbeitsweise offene Persönlichkeit</li>\n<li>Hohes Maß an Sorgfältigkeit, Zuverlässigkeit und Diskretion</li>\n</ul>\n<h2>Benefits</h2>\n<p><em>Bei uns bist du Teil eines wachsenden &#x26; motivierten Teams sein und kannst die Zukunft des Unternehmens und unserer Marken mitgestalten. Du willst dich immer weiterentwickeln und schätzt es sehr eigenständig zu arbeiten, Verantwortung zu übernehmen und dazu beizutragen, dass wir uns kontinuierlich verbessern? Klasse dann suchen wir dich! Bei uns bekommst du auch:</em></p>\n<ul>\n<li>30 Urlaubstage (berechnet auf Vollzeitbasis)</li>\n<li>Ein abwechslungsreicher Arbeitsplatz in einem mittelständigen Familienunternehmen</li>\n<li>Die Mitarbeit in einem wachstumsstarken und ambitionierten Unternehmen mit langfristigen Chancen für deine Talente und deine Weiterentwicklung</li>\n<li>Motivierte &#x26; engagierte Teamkultur mit extrem netten Kollegen</li>\n<li>Möglichkeit dich immer weiterzuentwickeln, egal ob durch on-the-job Training, Wissen deiner Kollegen oder eLearnings</li>\n<li>Vorteile wie Lunch &#x26; Learn Sessions und steuerfreie Zulagen</li>\n<li>Regelmäßiges Feedback und Planung deiner Karriereentwicklung</li>\n</ul>\n<p>Find more <a href="https://www.arbeitnow.com/english-speaking-jobs">English Speaking Jobs in Germany</a> on Arbeitnow</a>',
#  'remote': False,
#  'url': 'https://www.arbeitnow.com/jobs/companies/jakob-winter-gmbh/buchhalter-teilzeit-gross-gerau-414464',
#  'tags': ['Finance'],
#  'job_types': [],
#  'location': 'Groß-Gerau',
#  'created_at': 1765308707}

# %% [markdown]
# La clave "data" contiene una lista con los datos de cada uno de los empleos. Hagamos un mini análisis con los datos, veamos en que ciudad surgen más empleos y si el número de habitantes tiene algo que ver.
#
# Vamos a iterar por cada uno de los elementos de data, veamos la localización y contemos cuantas veces se repite cada una de ellas.

# %%
towns = {}

for job in x.json()["data"]:
    location_job = job.get("location")
    if location_job:
        if location_job in towns.keys():
            towns[location_job] += 1
        else:
            towns[location_job] = 1

# %%
towns
# Out:
# {'Groß-Gerau': 1,
#  'Dortmund': 3,
#  'Freiburg im Breisgau': 3,
#  'Heilbronn': 1,
#  'Munich': 6,
#  'Berlin': 24,
#  'Nuremberg': 1,
#  'Frankfurt': 3,
#  'Hamburg': 5,
#  'Dresden': 1,
#  'Bremen': 1,
#  'Kiel': 1,
#  'Karlsruhe': 2,
#  'Hanover': 4,
#  'Münster': 2,
#  'Cologne': 4,
#  'Düsseldorf': 4,
#  'Wolfenbüttel': 1,
#  'Aschheim': 1,
#  'Ottobrunn': 1,
#  'Mönchengladbach': 1,
#  'Leipzig, Saxony, Germany': 1,
#  'Gütersloh': 1,
#  'Wangen im Allgäu': 1,
#  'Friedrichshafen': 1,
#  'Koblenz': 2,
#  'Bielefeld': 1,
#  'Reutlingen': 1,
#  'Erfurt': 1,
#  'Essen': 1,
#  'Leipzig': 4,
#  'Darmstadt': 1,
#  'Kronshagen': 1,
#  'Duisburg': 1,
#  'Stuttgart': 5,
#  'Fürth': 1,
#  'Ravensburg': 1,
#  'Böblingen': 1,
#  'Starnberg': 1,
#  'Weissenburg in Bayern': 2,
#  'Geesthacht': 1,
#  'Wilhelmshaven': 1}

# %% [markdown]
# Ahora tenemos que ver los habitantes de cada una de las ciudades. Vamos a extraer los datos de población de un [artículo](https://es.wikipedia.org/wiki/Anexo:Ciudades_de_Alemania_por_poblaci%C3%B3n) de la wikipedia, utilizando para ello la librería pandas.

# %%
import pandas as pd

url = "https://es.wikipedia.org/wiki/Anexo:Ciudades_de_Alemania_por_poblaci%C3%B3n"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
                  "(KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)

data = pd.read_html(response.text)

data
# Out:
# /var/folders/3t/d2zbs9zj1nqgx7s3vhrpvbw40000gn/T/ipykernel_91990/2963881148.py:12: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data = pd.read_html(response.text)
# [    0                           1
#  0 NaN             Capital Federal
#  1 NaN  Capital de Estado Federado,
#      Rango  Escudo          Nombre Población en 1990 Población en 2000  \
#  0       1     NaN          Berlín         3 433 695         3 382 169
#  1       2     NaN        Hamburgo         1 652 363         1 715 392
#  2       3     NaN          Múnich         1 229 026         1 210 223
#  3       4     NaN         Colonia           953 551           962 884
#  4       5     NaN       Fráncfort           644 865           646 550
#  ..    ...     ...             ...               ...               ...
#  77     78     NaN          Siegen           109 174           108 476
#  78     79     NaN       Gütersloh            86 807            95 156
#  79     80     NaN      Hildesheim           105 291           103 909
#  80     81     NaN           Hanau            88 294            88 637
#  81     82     NaN  Kaiserslautern            99 351            99 825
#
#     Población en 2005 Población en 2010[1]​ Población en 2020  \
#  0          3 395 189             3 460 725         3 664 088
#  1          1 743 627             1 786 448         1 852 478
#  2          1 259 677             1 353 186         1 488 202
#  3            983 347             1 007 119         1 083 498
#  4            651 899               679 664           764 104
#  ..               ...                   ...               ...
#  77           106 293               103 424           101 943
#  78                 -                 96404           100 664
#  79           102 575               102 794           101 055
#  80                 -                88.637            97 137
#  81                 -                99.184            99 662
#
#     Población en 2022  Área (km²)  Pob. por km²  Crecimiento %  \
#  0          3 755 251       89182        3807.0            6.0
#  1          1 892 122       75524        2309.0           27.0
#  2          1 512 491       31046        4057.0           68.0
#  3          1 084 831       40515        2427.0           35.0
#  4            773 068       24831        2625.0           14.0
#  ..               ...         ...           ...            ...
#  77           102 560       11467         927.0          -34.0
#  78           102 393       11202           NaN            NaN
#  79           101 858        9257        1108.0          -21.0
#  80           101 364        7674           NaN            NaN
#  81           101 228       13970           NaN            NaN
#
#              Estado (Bundesland)  Año en que superó 100 000 hab.
#  0                        Berlín                            1740
#  1                      Hamburgo                            1787
#  2                       Baviera                            1854
#  3   Renania del Norte-Westfalia                            1855
#  4                         Hesse                            1875
#  ..                          ...                             ...
#  77  Renania del Norte-Westfalia                            1975
#  78  Renania del Norte-Westfalia                            2018
#  79                 Baja Sajonia                            1974
#  80                        Hesse                            2022
#  81           Renania-Palatinado                            1970
#
#  [82 rows x 14 columns],
#                          0                                     1
#  0  Control de autoridades  Proyectos Wikimedia  Datos: Q4242225]

# %% [markdown]
# Podemos ver como son extraídas cada una de las tablas. La que nos interesa es la segunda, que es la que contiene los datos de población.

# %%
data[1]
# Out:
#     Rango  Escudo          Nombre Población en 1990 Población en 2000  \
# 0       1     NaN          Berlín         3 433 695         3 382 169
# 1       2     NaN        Hamburgo         1 652 363         1 715 392
# 2       3     NaN          Múnich         1 229 026         1 210 223
# 3       4     NaN         Colonia           953 551           962 884
# 4       5     NaN       Fráncfort           644 865           646 550
# ..    ...     ...             ...               ...               ...
# 77     78     NaN          Siegen           109 174           108 476
# 78     79     NaN       Gütersloh            86 807            95 156
# 79     80     NaN      Hildesheim           105 291           103 909
# 80     81     NaN           Hanau            88 294            88 637
# 81     82     NaN  Kaiserslautern            99 351            99 825
#
#    Población en 2005 Población en 2010[1]​ Población en 2020  \
# 0          3 395 189             3 460 725         3 664 088
# 1          1 743 627             1 786 448         1 852 478
# 2          1 259 677             1 353 186         1 488 202
# 3            983 347             1 007 119         1 083 498
# 4            651 899               679 664           764 104
# ..               ...                   ...               ...
# 77           106 293               103 424           101 943
# 78                 -                 96404           100 664
# 79           102 575               102 794           101 055
# 80                 -                88.637            97 137
# 81                 -                99.184            99 662
#
#    Población en 2022  Área (km²)  Pob. por km²  Crecimiento %  \
# 0          3 755 251       89182        3807.0            6.0
# 1          1 892 122       75524        2309.0           27.0
# 2          1 512 491       31046        4057.0           68.0
# 3          1 084 831       40515        2427.0           35.0
# 4            773 068       24831        2625.0           14.0
# ..               ...         ...           ...            ...
# 77           102 560       11467         927.0          -34.0
# 78           102 393       11202           NaN            NaN
# 79           101 858        9257        1108.0          -21.0
# 80           101 364        7674           NaN            NaN
# 81           101 228       13970           NaN            NaN
#
#             Estado (Bundesland)  Año en que superó 100 000 hab.
# 0                        Berlín                            1740
# 1                      Hamburgo                            1787
# 2                       Baviera                            1854
# 3   Renania del Norte-Westfalia                            1855
# 4                         Hesse                            1875
# ..                          ...                             ...
# 77  Renania del Norte-Westfalia                            1975
# 78  Renania del Norte-Westfalia                            2018
# 79                 Baja Sajonia                            1974
# 80                        Hesse                            2022
# 81           Renania-Palatinado                            1970
#
# [82 rows x 14 columns]

# %% [markdown]
# Y veamos el nombre de sus columnas

# %%
data[1].columns
# Out:
# Index(['Rango', 'Escudo', 'Nombre', 'Población en 1990', 'Población en 2000',
#        'Población en 2005', 'Población en 2010[1]​', 'Población en 2020',
#        'Población en 2022', 'Área (km²)', 'Pob. por km²', 'Crecimiento %',
#        'Estado (Bundesland)', 'Año en que superó 100 000 hab.'],
#       dtype='object')

# %% [markdown]
# Vamos a quedarnos con la tabla con los datos que queremos y vamos a renombrar las columnas con unos nombres con los que sea más fácil de trabajar.

# %%
data = data[1]

# %%
data = data[["Nombre", "Población en 2022"]]
data.columns = ["nombre", "poblacion"]

# %% [markdown]
# Para poder unir las tablas necesitamos que los nombres de las ciudades de la tabla de wikipedia y los de la API coincidan. Vamos a intentar estandarizar los valores eliminando los caracteres extraños. Para ello utilizaremos la librería unidecode.

# %%
from unidecode import unidecode
data["normalized_nombre"] = data["nombre"].apply(unidecode)
# Out:
# /var/folders/3t/d2zbs9zj1nqgx7s3vhrpvbw40000gn/T/ipykernel_91990/3388093331.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["normalized_nombre"] = data["nombre"].apply(unidecode)

# %%
data
# Out:
#             nombre  poblacion normalized_nombre
# 0           Berlín  3 755 251            Berlin
# 1         Hamburgo  1 892 122          Hamburgo
# 2           Múnich  1 512 491            Munich
# 3          Colonia  1 084 831           Colonia
# 4        Fráncfort    773 068         Francfort
# ..             ...        ...               ...
# 77          Siegen    102 560            Siegen
# 78       Gütersloh    102 393         Gutersloh
# 79      Hildesheim    101 858        Hildesheim
# 80           Hanau    101 364             Hanau
# 81  Kaiserslautern    101 228    Kaiserslautern
#
# [82 rows x 3 columns]

# %% [markdown]
# Creemos ahora un dataframe con los datos que hemos obtenido de la API.

# %%
data_jobs = pd.DataFrame(towns.items(), columns=["nombre", "n_jobs"])
print(data_jobs)
# Out:
#                       nombre  n_jobs
# 0                 Groß-Gerau       1
# 1                   Dortmund       3
# 2       Freiburg im Breisgau       3
# 3                  Heilbronn       1
# 4                     Munich       6
# 5                     Berlin      24
# 6                  Nuremberg       1
# 7                  Frankfurt       3
# 8                    Hamburg       5
# 9                    Dresden       1
# 10                    Bremen       1
# 11                      Kiel       1
# 12                 Karlsruhe       2
# 13                   Hanover       4
# 14                   Münster       2
# 15                   Cologne       4
# 16                Düsseldorf       4
# 17              Wolfenbüttel       1
# 18                  Aschheim       1
# 19                 Ottobrunn       1
# 20           Mönchengladbach       1
# 21  Leipzig, Saxony, Germany       1
# 22                 Gütersloh       1
# 23          Wangen im Allgäu       1
# 24           Friedrichshafen       1
# 25                   Koblenz       2
# 26                 Bielefeld       1
# 27                Reutlingen       1
# 28                    Erfurt       1
# 29                     Essen       1
# 30                   Leipzig       4
# 31                 Darmstadt       1
# 32                Kronshagen       1
# 33                  Duisburg       1
# 34                 Stuttgart       5
# 35                     Fürth       1
# 36                Ravensburg       1
# 37                 Böblingen       1
# 38                 Starnberg       1
# 39     Weissenburg in Bayern       2
# 40                Geesthacht       1
# 41             Wilhelmshaven       1

# %% [markdown]
# Eliminemos los caracteres raros de los datos de la API.

# %%
data_jobs["normalized_nombre"] = data_jobs["nombre"].apply(unidecode)

# %% [markdown]
# Y ahora unamos los dos DFs usando los nombres sin carateres raros

# %%
data_joined = data_jobs.merge(data, on="normalized_nombre")
data_joined
# Out:
#            nombre_x  n_jobs normalized_nombre         nombre_y  poblacion
# 0          Dortmund       3          Dortmund         Dortmund    593 317
# 1         Heilbronn       1         Heilbronn        Heilbronn    128 334
# 2            Munich       6            Munich           Múnich  1 512 491
# 3            Berlin      24            Berlin           Berlín  3 755 251
# 4         Nuremberg       1         Nuremberg        Núremberg    523 026
# 5            Bremen       1            Bremen           Bremen    569 396
# 6              Kiel       1              Kiel             Kiel    247 717
# 7         Karlsruhe       2         Karlsruhe        Karlsruhe    308 707
# 8           Hanover       4           Hanover          Hanóver    545 045
# 9           Münster       2           Munster          Münster    320 946
# 10       Düsseldorf       4        Dusseldorf       Düsseldorf    629 047
# 11  Mönchengladbach       1   Monchengladbach  Mönchengladbach    268 465
# 12        Gütersloh       1         Gutersloh        Gütersloh    102 393
# 13        Bielefeld       1         Bielefeld        Bielefeld    338 332
# 14       Reutlingen       1        Reutlingen       Reutlingen    117 547
# 15           Erfurt       1            Erfurt           Erfurt    214 969
# 16            Essen       1             Essen            Essen    584 580
# 17          Leipzig       4           Leipzig          Leipzig    616 093
# 18        Darmstadt       1         Darmstadt        Darmstadt    162 243
# 19        Stuttgart       5         Stuttgart        Stuttgart    632 865
# 20            Fürth       1             Furth            Fürth    131 433

# %%
data_joined["poblacion"] = data_joined["poblacion"].str.replace(" ", "")
data_joined["poblacion"] = data_joined["poblacion"].astype(int)
data_joined.sort_values("poblacion", ascending=True, inplace=True)
data_joined
# Out:
#            nombre_x  n_jobs normalized_nombre         nombre_y  poblacion
# 12        Gütersloh       1         Gutersloh        Gütersloh     102393
# 14       Reutlingen       1        Reutlingen       Reutlingen     117547
# 1         Heilbronn       1         Heilbronn        Heilbronn     128334
# 20            Fürth       1             Furth            Fürth     131433
# 18        Darmstadt       1         Darmstadt        Darmstadt     162243
# 15           Erfurt       1            Erfurt           Erfurt     214969
# 6              Kiel       1              Kiel             Kiel     247717
# 11  Mönchengladbach       1   Monchengladbach  Mönchengladbach     268465
# 7         Karlsruhe       2         Karlsruhe        Karlsruhe     308707
# 9           Münster       2           Munster          Münster     320946
# 13        Bielefeld       1         Bielefeld        Bielefeld     338332
# 4         Nuremberg       1         Nuremberg        Núremberg     523026
# 8           Hanover       4           Hanover          Hanóver     545045
# 5            Bremen       1            Bremen           Bremen     569396
# 16            Essen       1             Essen            Essen     584580
# 0          Dortmund       3          Dortmund         Dortmund     593317
# 17          Leipzig       4           Leipzig          Leipzig     616093
# 10       Düsseldorf       4        Dusseldorf       Düsseldorf     629047
# 19        Stuttgart       5         Stuttgart        Stuttgart     632865
# 2            Munich       6            Munich           Múnich    1512491
# 3            Berlin      24            Berlin           Berlín    3755251

# %%
data_joined.plot.scatter("poblacion", "n_jobs")
# Out:
# <Axes: xlabel='poblacion', ylabel='n_jobs'>

# %% [markdown]
# ## Comando para instalar librerías

# %%
# %%capture
import sys

if 'lxml' not in sys.modules:
    # !{sys.executable} -m pip install lxml
    
if 'html5lib' not in sys.modules:
    # !{sys.executable} -m pip install html5lib

# %% [markdown]
# # Ejercicios
#
# 1) Extraer las ciudades de las 1200 primeras ofertas de arbeitnow
#
# 2) Buscar una API en public-apis y hacer un pequeño script que extraiga los datos. Si quieres un reto puedes intentar utilizar una API con contraseña
